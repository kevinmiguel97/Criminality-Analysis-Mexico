# %% [markdown]
# ## Crimes by municipality Mexico
# Focus crimes: Secuestro, Extorsión, Robo a negocio

# %%
# Importing libraries
import pandas as pd 
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import seaborn as sns
import regex as re

# %matplotlib inline

# %%
### Select if you want to limit the type of crimes

# %%
limit_crimes = False

# %% [markdown]
# ### 1.- Importing data

# %%
# Database with crimes information
df = pd.read_csv('data/delitos-datos-abiertos.csv')
# Database with population information
pop = pd.read_csv('data/poblaciones_2015.csv', skiprows=4, encoding='latin-1', skipfooter=6, engine='python')
# Database with cp information
cp = pd.read_excel('data/codigos-postales-mexico.xlsx')

# Formatting column names
df.columns = [x.lower().strip() for x in df.columns]
pop.columns = [x.lower().strip() for x in pop.columns]
cp.columns = [x.lower().strip() for x in cp.columns]

# Formatting date columns
df['fecha'] = pd.to_datetime(df['fecha'], infer_datetime_format=True)

# Renaming columns
df.rename(columns={'inegi_entidad': 'id_entidad',
                    'inegi_municipio': 'id_municipio'}, inplace=True)

pop.drop(columns='id_municipio', inplace=True)

pop.rename(columns={'estado': 'entidad',
                    'cve_inegi': 'id_municipio',
                    'id_estado': 'id_entidad'}, inplace=True)
                    
cp.rename(columns={'estado': 'entidad'}, inplace=True)

df.head()
# Out:
#    id_entidad         entidad  id_municipio        municipio  id_delito  \
# 0           1  Aguascalientes          1001   Aguascalientes       1100
# 1           1  Aguascalientes          1002         Asientos       1100
# 2           1  Aguascalientes          1010         El Llano       1100
# 3           1  Aguascalientes          1009         Tepezala       1100
# 4           1  Aguascalientes          1007  Rincon De Romos       1100
#
#              delito  carpetas      tasa      fecha
# 0  Homicidio doloso         3  0.323526 2021-01-01
# 1  Homicidio doloso         0  0.000000 2021-01-01
# 2  Homicidio doloso         0  0.000000 2021-01-01
# 3  Homicidio doloso         0  0.000000 2021-01-01
# 4  Homicidio doloso         0  0.000000 2021-01-01

# %%
pop.head()
# Out:
#           entidad       municipio  id_municipio  id_entidad  hombres  mujeres  \
# 0  Aguascalientes  Aguascalientes          1001           1   425731   451459
# 1  Aguascalientes        Asientos          1002           1    22745    23719
# 2  Aguascalientes        Calvillo          1003           1    27298    28750
# 3  Aguascalientes           Cosío          1004           1     7552     8025
# 4  Aguascalientes     Jesús María          1005           1    60135    60270
#
#     total
# 0  877190
# 1   46464
# 2   56048
# 3   15577
# 4  120405

# %%
df.tail()
# Out:
#         id_entidad    entidad  id_municipio                municipio  \
# 471739          32  Zacatecas         32047  Teul De Gonzalez Ortega
# 471740          32  Zacatecas         32007       Concepcion Del Oro
# 471741          32  Zacatecas         32008               Cuauhtemoc
# 471742          32  Zacatecas         32016   General Panfilo Natera
# 471743          32  Zacatecas         32056                Zacatecas
#
#         id_delito            delito  carpetas       tasa      fecha
# 471739       9000  Lesiones dolosas         1  17.430714 2021-12-01
# 471740       9000  Lesiones dolosas         1   7.334067 2021-12-01
# 471741       9000  Lesiones dolosas         0   0.000000 2021-12-01
# 471742       9000  Lesiones dolosas         1   4.203977 2021-12-01
# 471743       9000  Lesiones dolosas        23  15.266466 2021-12-01

# %%
pop.tail()
# Out:
#         entidad                municipio  id_municipio  id_entidad  hombres  \
# 2452  Zacatecas            Villa Hidalgo         32054          32     9433
# 2453  Zacatecas               Villanueva         32055          32    14793
# 2454  Zacatecas                Zacatecas         32056          32    70855
# 2455  Zacatecas                 Trancoso         32057          32     9505
# 2456  Zacatecas  Santa María de la Paz *         32058          32     1305
#
#       mujeres   total
# 2452     9722   19155
# 2453    15447   30240
# 2454    75292  146147
# 2455     9908   19413
# 2456     1351    2656

# %%
cp.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio            ciudad           entidad
# 0  Álvaro Obregón  Ciudad de México  Distrito Federal
# 1  Álvaro Obregón  Ciudad de México  Distrito Federal
# 2  Álvaro Obregón  Ciudad de México  Distrito Federal
# 3  Álvaro Obregón  Ciudad de México  Distrito Federal
# 4  Álvaro Obregón  Ciudad de México  Distrito Federal

# %% [markdown]
# ### 1.1 Cleaning data

# %%
# Cleaning  * from names in pop df
pop['municipio'] = pop['municipio'].replace(' *', '', regex=True)
pop['municipio'] = pop['municipio'].replace('\*', '', regex=True)

# Changing Distrito Federal for CDMX
pop['entidad'] = pop['entidad'].replace('Distrito Federal', 'Ciudad de México')
df['entidad'] = df['entidad'].replace('Distrito Federal', 'Ciudad de México')
cp['entidad'] = cp['entidad'].replace('Distrito Federal', 'Ciudad de México')

pop.tail()
# Out:
#         entidad          municipio  id_municipio  id_entidad  hombres  \
# 2452  Zacatecas       VillaHidalgo         32054          32     9433
# 2453  Zacatecas         Villanueva         32055          32    14793
# 2454  Zacatecas          Zacatecas         32056          32    70855
# 2455  Zacatecas           Trancoso         32057          32     9505
# 2456  Zacatecas  SantaMaríadelaPaz         32058          32     1305
#
#       mujeres   total
# 2452     9722   19155
# 2453    15447   30240
# 2454    75292  146147
# 2455     9908   19413
# 2456     1351    2656

# %%
# Separating words in pop df
string = 'VillaHidalgo'
words = re.findall('[A-Z][a-z]*', string)
string2 = ' '.join(words)
print(string2)

# Deleting spaces
string = 'Villa Hidalgo'
string3 = string.replace(' ', '')
string3
# Out:
# Villa Hidalgo
# 'VillaHidalgo'

# %%
# Applying functions
# pop['municipio_sep'] = pop['municipio'].apply(lambda x: ' '.join(re.findall('[A-Z][a-zÀ-ÿ]*', x)))
cp['municipio_strip'] = cp['municipio'].apply(lambda x: x.replace(' ', ''))

# %%
cp
# Out:
#         código                                       asentamiento  \
# 0         1000                                          San Angel
# 1         1010                                          Los Alpes
# 2         1020                                      Guadalupe Inn
# 3         1028  Secretaria de Contraloría y Desarrollo Adminis...
# 4         1029                                          INFONAVIT
# ...        ...                                                ...
# 143219   99993                                            Cuxpala
# 143220   99994                                   Vicente Guerrero
# 143221   99998                                          Palmarejo
# 143222   99998                                        Jesús Maria
# 143223   99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 1            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 2            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 3       Gran usuario      Álvaro Obregón  Ciudad de México  Ciudad de México
# 4       Gran usuario      Álvaro Obregón  Ciudad de México  Ciudad de México
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Ranchería  Moyahua de Estrada               NaN         Zacatecas
# 143222     Ranchería  Moyahua de Estrada               NaN         Zacatecas
# 143223     Ranchería  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip
# 0          ÁlvaroObregón
# 1          ÁlvaroObregón
# 2          ÁlvaroObregón
# 3          ÁlvaroObregón
# 4          ÁlvaroObregón
# ...                  ...
# 143219  MoyahuadeEstrada
# 143220  MoyahuadeEstrada
# 143221  MoyahuadeEstrada
# 143222  MoyahuadeEstrada
# 143223  MoyahuadeEstrada
#
# [143224 rows x 7 columns]

# %% [markdown]
# ### 2.- Exploring data

# %% [markdown]
# #### 2.1.- Exploring datatypes

# %%
df.dtypes
# Out:
# id_entidad               int64
# entidad                 object
# id_municipio             int64
# municipio               object
# id_delito                int64
# delito                  object
# carpetas                 int64
# tasa                   float64
# fecha           datetime64[ns]
# dtype: object

# %%
pop.dtypes
# Out:
# entidad         object
# municipio       object
# id_municipio     int64
# id_entidad       int64
# hombres          int64
# mujeres          int64
# total            int64
# dtype: object

# %%
cp.dtypes
# Out:
# código              int64
# asentamiento       object
# tipo               object
# municipio          object
# ciudad             object
# entidad            object
# municipio_strip    object
# dtype: object

# %% [markdown]
# #### 2.2.- Cleaning data to merge

# %% [markdown]
# Checking id_municipio

# %%
# Creating list of unique ids in each dataset
unique_id_df = df['id_municipio'].unique()
unique_id_pop = pop['id_municipio'].unique()

# Len of the lists
len_id_df = len(df['id_municipio'].unique())
len_id_pop = len(pop['id_municipio'].unique())

print(len_id_df)
print(len_id_pop)

for i in unique_id_df:
    if i not in unique_id_pop:
        m = df[df['id_municipio'] == i].iloc[0]['municipio']
        print('id {} ({}) does not exist in pop data'.format(i, m))

print('\n')
# Out:
# 2457
# 2457
# id 7101 (Tuxtla Gutierrez) does not exist in pop data
# id 7109 (Yajalon) does not exist in pop data
# id 7110 (San Lucas) does not exist in pop data
# id 7119 (Santiago El Pinar) does not exist in pop data
# id 7114 (Benemerito De Las Americas) does not exist in pop data
# id 7107 (Villa Corzo) does not exist in pop data
# id 7117 (Montecristo De Guerrero) does not exist in pop data
# id 7105 (Union Juarez) does not exist in pop data
# id 7111 (Zinacantan) does not exist in pop data
# id 7118 (San Andres Duraznal) does not exist in pop data
# id 7102 (Tuxtla Chico) does not exist in pop data
# id 7116 (Marques De Comillas) does not exist in pop data
# id 7100 (Tumbala) does not exist in pop data
# id 7108 (Villaflores) does not exist in pop data
# id 7103 (Tuzantan) does not exist in pop data
# id 7104 (Tzimol) does not exist in pop data
# id 7113 (Aldama) does not exist in pop data
# id 7112 (San Juan Cancuc) does not exist in pop data
# id 7115 (Maravilla Tenejapa) does not exist in pop data
# id 7106 (Venustiano Carranza) does not exist in pop data

# %%
for i in unique_id_pop:
    if i not in unique_id_df:
        m = pop[pop['id_municipio'] == i].iloc[0]['municipio']
        print('id {} ({}) does not exist in crimes data'.format(i, m))
# Out:
# id 70100 (Tumbalá) does not exist in crimes data
# id 70101 (TuxtlaGutiérrez) does not exist in crimes data
# id 70102 (TuxtlaChico) does not exist in crimes data
# id 70103 (Tuzantán) does not exist in crimes data
# id 70104 (Tzimol) does not exist in crimes data
# id 70105 (UniónJuárez) does not exist in crimes data
# id 70106 (VenustianoCarranza) does not exist in crimes data
# id 70107 (VillaCorzo) does not exist in crimes data
# id 70108 (Villaflores) does not exist in crimes data
# id 70109 (Yajalón) does not exist in crimes data
# id 70110 (SanLucas) does not exist in crimes data
# id 70111 (Zinacantán) does not exist in crimes data
# id 70112 (SanJuanCancuc) does not exist in crimes data
# id 70113 (Aldama) does not exist in crimes data
# id 70114 (BeneméritodelasAméricas) does not exist in crimes data
# id 70115 (MaravillaTenejapa) does not exist in crimes data
# id 70116 (MarquésdeComillas) does not exist in crimes data
# id 70117 (MontecristodeGuerrero) does not exist in crimes data
# id 70118 (SanAndrésDuraznal) does not exist in crimes data
# id 70119 (SantiagoelPinar) does not exist in crimes data

# %%
# Fixing misslabeled data
for i in unique_id_pop:
    if i not in unique_id_df:
        to_replace_with = i - 70000 + 7000
        print('{} replaced with {}'.format(i, to_replace_with))
        pop['id_municipio'] = pop['id_municipio'].replace(i, to_replace_with)
# Out:
# 70100 replaced with 7100
# 70101 replaced with 7101
# 70102 replaced with 7102
# 70103 replaced with 7103
# 70104 replaced with 7104
# 70105 replaced with 7105
# 70106 replaced with 7106
# 70107 replaced with 7107
# 70108 replaced with 7108
# 70109 replaced with 7109
# 70110 replaced with 7110
# 70111 replaced with 7111
# 70112 replaced with 7112
# 70113 replaced with 7113
# 70114 replaced with 7114
# 70115 replaced with 7115
# 70116 replaced with 7116
# 70117 replaced with 7117
# 70118 replaced with 7118
# 70119 replaced with 7119

# %%
# Creating list of unique ids in each dataset
unique_id_df = df['id_municipio'].unique()
unique_id_pop = pop['id_municipio'].unique()

# Len of the lists
len_id_df = len(df['id_municipio'].unique())
len_id_pop = len(pop['id_municipio'].unique())

for i in unique_id_pop:
    if i not in unique_id_df:
        print('id {} does not exist in crimes data'.format(i))

for i in unique_id_df:
    if i not in unique_id_pop:
        print('id {} does not exist in crimes data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# Checking municipio column

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {}  does not exist in pop data'.format(i))
# Out:
# 2318
# 2317
# -1
#
#
# Municipio TezoatlándeSegurayLuna  does not exist in pop data
# Municipio SanJuanMixtepec-Dto.08-  does not exist in pop data
# Municipio SanJuanMixtepec-Dto.26-  does not exist in pop data
# Municipio SanPedroMixtepec-Dto.26-  does not exist in pop data
# Municipio SanPedroMixtepec-Dto.22-  does not exist in pop data
# Municipio Medellín  does not exist in pop data

# %%
# Cleaning -Dto.xx- from name in cp database
cp['municipio_strip'] = cp['municipio_strip'].replace('\-.+\..+', '', regex=True)

# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {}  does not exist in pop data'.format(i))
# Out:
# 2316
# 2317
# 1
#
#
# Municipio TezoatlándeSegurayLuna  does not exist in pop data
# Municipio Medellín  does not exist in pop data

# %%
for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {}  does not exist in cp data'.format(i))
# Out:
# Municipio ZacualpandeAmilpas  does not exist in cp data
# Municipio HeroicaVillaTezoatlándeSegurayLuna,CunadelaIndependenciadeOaxaca  does not exist in cp data
# Municipio MedellíndeBravo  does not exist in cp data

# %%
# Replacing values manually
pop['municipio'] = pop['municipio'].replace('HeroicaVillaTezoatlándeSegurayLuna,CunadelaIndependenciadeOaxaca',
                                            'TezoatlándeSegurayLuna')

pop['municipio'] = pop['municipio'].replace('MedellíndeBravo', 'Medellín')

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {} does not exist in cp data'.format(i))

pop[pop['municipio'] == 'ZacualpandeAmilpas']
# Out:
# 2316
# 2317
# 1
#
#
# Municipio ZacualpandeAmilpas does not exist in cp data
#      entidad           municipio  id_municipio  id_entidad  hombres  mujeres  \
# 925  Morelos  ZacualpandeAmilpas         17032          17     4550     4820
#
#      total
# 925   9370

# %%
# Correcting last value
pop['municipio'] = pop['municipio'].replace('ZacualpandeAmilpas', 'Zacualpan')

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {} does not exist in cp data'.format(i))

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {} does not exist in cp data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# Checking entidad column

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['entidad'].unique()
unique_mun_pop = pop['entidad'].unique()

# Len of the lists
len_mun_cp = len(cp['entidad'].unique())
len_mun_pop = len(pop['entidad'].unique())

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('entidad {} does not exist in cp data'.format(i))

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('entidad {} does not exist in pop data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# ### 3.- Merging

# %% [markdown]
# #### 3.1 Merging zip code and population data

# %%
# Generating column entidad-municipio for pop
pop['entidad_municipio'] = pop['entidad'] + '-' + pop['municipio']

# Generating column entidad-municipio for cp
cp['entidad_municipio'] = cp['entidad'] + '-' + cp['municipio_strip']
cp.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio            ciudad           entidad municipio_strip  \
# 0  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 1  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 2  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 3  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 4  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
#
#                 entidad_municipio
# 0  Ciudad de México-ÁlvaroObregón
# 1  Ciudad de México-ÁlvaroObregón
# 2  Ciudad de México-ÁlvaroObregón
# 3  Ciudad de México-ÁlvaroObregón
# 4  Ciudad de México-ÁlvaroObregón

# %%
df.head()
# Out:
#    id_entidad         entidad  id_municipio        municipio  id_delito  \
# 0           1  Aguascalientes          1001   Aguascalientes       1100
# 1           1  Aguascalientes          1002         Asientos       1100
# 2           1  Aguascalientes          1010         El Llano       1100
# 3           1  Aguascalientes          1009         Tepezala       1100
# 4           1  Aguascalientes          1007  Rincon De Romos       1100
#
#              delito  carpetas      tasa      fecha
# 0  Homicidio doloso         3  0.323526 2021-01-01
# 1  Homicidio doloso         0  0.000000 2021-01-01
# 2  Homicidio doloso         0  0.000000 2021-01-01
# 3  Homicidio doloso         0  0.000000 2021-01-01
# 4  Homicidio doloso         0  0.000000 2021-01-01

# %%
pop.head()
# Out:
#           entidad       municipio  id_municipio  id_entidad  hombres  mujeres  \
# 0  Aguascalientes  Aguascalientes          1001           1   425731   451459
# 1  Aguascalientes        Asientos          1002           1    22745    23719
# 2  Aguascalientes        Calvillo          1003           1    27298    28750
# 3  Aguascalientes           Cosío          1004           1     7552     8025
# 4  Aguascalientes      JesúsMaría          1005           1    60135    60270
#
#     total              entidad_municipio
# 0  877190  Aguascalientes-Aguascalientes
# 1   46464        Aguascalientes-Asientos
# 2   56048        Aguascalientes-Calvillo
# 3   15577           Aguascalientes-Cosío
# 4  120405      Aguascalientes-JesúsMaría

# %%
# Merging pop and cp data
cols_cp = ['código', 'asentamiento', 'tipo', 'municipio', 'entidad_municipio']

cp_pop = pd.merge(cp[cols_cp], pop, how='left', left_on='entidad_municipio', right_on='entidad_municipio')
cp_pop.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#       municipio_x               entidad_municipio           entidad  \
# 0  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 1  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 2  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 3  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 4  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
#
#      municipio_y  id_municipio  id_entidad  hombres  mujeres   total
# 0  ÁlvaroObregón          9010           9   355754   394228  749982
# 1  ÁlvaroObregón          9010           9   355754   394228  749982
# 2  ÁlvaroObregón          9010           9   355754   394228  749982
# 3  ÁlvaroObregón          9010           9   355754   394228  749982
# 4  ÁlvaroObregón          9010           9   355754   394228  749982

# %%
len(cp) -len(cp_pop)
# Out:
# -213

# %%
# Difference comes from Districts different cp
cp[cp['municipio'].str.contains('\-.+\..+', regex=True)]
# Out:
#        código                       asentamiento       tipo  \
# 91558   69770                         Las Flores    Colonia
# 91559   69770                    San Miguel Lado     Barrio
# 91560   69770  San Juan Mixtepec - Dto.08 Centro    Colonia
# 91561   69770                 San Pedro Calvario     Barrio
# 91562   69770                           De Jesús     Barrio
# ...       ...                                ...        ...
# 95508   71998                         El Salitre  Ranchería
# 95509   71998                     Cerro Zopilote  Ranchería
# 95510   71998                          El Toledo  Ranchería
# 95511   71998                            Regadío  Ranchería
# 95512   71998                       Río Chiquito  Ranchería
#
#                            municipio ciudad entidad   municipio_strip  \
# 91558   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91559   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91560   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91561   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91562   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# ...                              ...    ...     ...               ...
# 95508  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95509  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95510  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95511  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95512  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
#
#              entidad_municipio
# 91558   Oaxaca-SanJuanMixtepec
# 91559   Oaxaca-SanJuanMixtepec
# 91560   Oaxaca-SanJuanMixtepec
# 91561   Oaxaca-SanJuanMixtepec
# 91562   Oaxaca-SanJuanMixtepec
# ...                        ...
# 95508  Oaxaca-SanPedroMixtepec
# 95509  Oaxaca-SanPedroMixtepec
# 95510  Oaxaca-SanPedroMixtepec
# 95511  Oaxaca-SanPedroMixtepec
# 95512  Oaxaca-SanPedroMixtepec
#
# [213 rows x 8 columns]

# %%
pop[pop['municipio'].str.contains('Mixtepec', regex=True)]
# Out:
#      entidad            municipio  id_municipio  id_entidad  hombres  mujeres  \
# 1045  Oaxaca    MagdalenaMixtepec         20048          20      662      713
# 1120  Oaxaca  SanBernardoMixtepec         20123          20     1313     1428
# 1150  Oaxaca   SanGabrielMixtepec         20153          20     2355     2481
# 1205  Oaxaca      SanJuanMixtepec         20208          20     3113     3567
# 1206  Oaxaca      SanJuanMixtepec         20209          20      285      375
# 1268  Oaxaca    SanMiguelMixtepec         20271          20     1295     1349
# 1315  Oaxaca     SanPedroMixtepec         20318          20    23381    24955
# 1316  Oaxaca     SanPedroMixtepec         20319          20      523      551
# 1375  Oaxaca    SantaCruzMixtepec         20378          20     1624     1801
#
#       total           entidad_municipio
# 1045   1375    Oaxaca-MagdalenaMixtepec
# 1120   2741  Oaxaca-SanBernardoMixtepec
# 1150   4836   Oaxaca-SanGabrielMixtepec
# 1205   6680      Oaxaca-SanJuanMixtepec
# 1206    660      Oaxaca-SanJuanMixtepec
# 1268   2644    Oaxaca-SanMiguelMixtepec
# 1315  48336     Oaxaca-SanPedroMixtepec
# 1316   1074     Oaxaca-SanPedroMixtepec
# 1375   3425    Oaxaca-SantaCruzMixtepec

# %%
# Dropping second repeated municipios
pop.drop([1206, 1316], inplace=True)
pop[pop['municipio'].str.contains('Mixtepec', regex=True)]
# Out:
#      entidad            municipio  id_municipio  id_entidad  hombres  mujeres  \
# 1045  Oaxaca    MagdalenaMixtepec         20048          20      662      713
# 1120  Oaxaca  SanBernardoMixtepec         20123          20     1313     1428
# 1150  Oaxaca   SanGabrielMixtepec         20153          20     2355     2481
# 1205  Oaxaca      SanJuanMixtepec         20208          20     3113     3567
# 1268  Oaxaca    SanMiguelMixtepec         20271          20     1295     1349
# 1315  Oaxaca     SanPedroMixtepec         20318          20    23381    24955
# 1375  Oaxaca    SantaCruzMixtepec         20378          20     1624     1801
#
#       total           entidad_municipio
# 1045   1375    Oaxaca-MagdalenaMixtepec
# 1120   2741  Oaxaca-SanBernardoMixtepec
# 1150   4836   Oaxaca-SanGabrielMixtepec
# 1205   6680      Oaxaca-SanJuanMixtepec
# 1268   2644    Oaxaca-SanMiguelMixtepec
# 1315  48336     Oaxaca-SanPedroMixtepec
# 1375   3425    Oaxaca-SantaCruzMixtepec

# %%
# Merging again
# Merging pop and cp data
cols_cp = ['código', 'asentamiento', 'tipo', 'municipio', 'entidad_municipio']

cp_pop = pd.merge(cp[cols_cp], pop, how='left', left_on='entidad_municipio', right_on='entidad_municipio')
if len(cp) -len(cp_pop) == 0:
    print('Same shapes!')

cp_pop.rename(columns={'municipio_x': 'municipio', 'municipio_y': 'municipio_strip'}, inplace=True)
cp_pop.head()
# Out:
# Same shapes!
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio               entidad_municipio           entidad  \
# 0  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 1  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 2  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 3  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 4  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
#
#   municipio_strip  id_municipio  id_entidad  hombres  mujeres   total
# 0   ÁlvaroObregón          9010           9   355754   394228  749982
# 1   ÁlvaroObregón          9010           9   355754   394228  749982
# 2   ÁlvaroObregón          9010           9   355754   394228  749982
# 3   ÁlvaroObregón          9010           9   355754   394228  749982
# 4   ÁlvaroObregón          9010           9   355754   394228  749982

# %%
# Exporting to csv
cp_pop.to_excel('output data/cp-population.xlsx')

# %% [markdown]
# #### 3.2.- Merging new dataframe with criminality dataframe

# %%
merged = pd.merge(cp_pop, df, on='id_municipio', how='left')

# %%
merged[merged['id_municipio'] == 1001]
# Out:
#         código asentamiento     tipo     municipio_x  \
# 400896   20000  Zona Centro  Colonia  Aguascalientes
# 400897   20000  Zona Centro  Colonia  Aguascalientes
# 400898   20000  Zona Centro  Colonia  Aguascalientes
# 400899   20000  Zona Centro  Colonia  Aguascalientes
# 400900   20000  Zona Centro  Colonia  Aguascalientes
# ...        ...          ...      ...             ...
# 542011   20399  El Turicate  Colonia  Aguascalientes
# 542012   20399  El Turicate  Colonia  Aguascalientes
# 542013   20399  El Turicate  Colonia  Aguascalientes
# 542014   20399  El Turicate  Colonia  Aguascalientes
# 542015   20399  El Turicate  Colonia  Aguascalientes
#
#                     entidad_municipio       entidad_x municipio_strip  \
# 400896  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 400897  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 400898  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 400899  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 400900  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# ...                               ...             ...             ...
# 542011  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 542012  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 542013  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 542014  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 542015  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
#
#         id_municipio  id_entidad_x  hombres  mujeres   total  id_entidad_y  \
# 400896          1001             1   425731   451459  877190             1
# 400897          1001             1   425731   451459  877190             1
# 400898          1001             1   425731   451459  877190             1
# 400899          1001             1   425731   451459  877190             1
# 400900          1001             1   425731   451459  877190             1
# ...              ...           ...      ...      ...     ...           ...
# 542011          1001             1   425731   451459  877190             1
# 542012          1001             1   425731   451459  877190             1
# 542013          1001             1   425731   451459  877190             1
# 542014          1001             1   425731   451459  877190             1
# 542015          1001             1   425731   451459  877190             1
#
#              entidad_y     municipio_y  id_delito              delito  \
# 400896  Aguascalientes  Aguascalientes       1100    Homicidio doloso
# 400897  Aguascalientes  Aguascalientes       1120         Feminicidio
# 400898  Aguascalientes  Aguascalientes       1200   Homicidio culposo
# 400899  Aguascalientes  Aguascalientes       2000           Secuestro
# 400900  Aguascalientes  Aguascalientes       3000           Extorsión
# ...                ...             ...        ...                 ...
# 542011  Aguascalientes  Aguascalientes       5000           Violación
# 542012  Aguascalientes  Aguascalientes       6000  Violencia familiar
# 542013  Aguascalientes  Aguascalientes       7000   Trata de personas
# 542014  Aguascalientes  Aguascalientes       8000        Narcomenudeo
# 542015  Aguascalientes  Aguascalientes       9000    Lesiones dolosas
#
#         carpetas       tasa      fecha
# 400896         3   0.323526 2021-01-01
# 400897         2   0.418447 2021-01-01
# 400898         5   0.539210 2021-01-01
# 400899         0   0.000000 2021-01-01
# 400900         5   0.539210 2021-01-01
# ...          ...        ...        ...
# 542011        25   2.696052 2021-12-01
# 542012       116  12.509679 2021-12-01
# 542013         0   0.000000 2021-12-01
# 542014        17   1.833315 2021-12-01
# 542015       206  22.215464 2021-12-01
#
# [112704 rows x 20 columns]

# %%
# Grouping population information by id_municipio
_ = cp_pop.groupby('id_municipio').agg({'hombres': np.mean,
                                    'mujeres': np.mean,
                                    'total': np.mean})

# Joining
df_pop = pd.merge(df, _, on='id_municipio', how='left')

# %%
df_pop.head()
# Out:
#    id_entidad         entidad  id_municipio        municipio  id_delito  \
# 0           1  Aguascalientes          1001   Aguascalientes       1100
# 1           1  Aguascalientes          1002         Asientos       1100
# 2           1  Aguascalientes          1010         El Llano       1100
# 3           1  Aguascalientes          1009         Tepezala       1100
# 4           1  Aguascalientes          1007  Rincon De Romos       1100
#
#              delito  carpetas      tasa      fecha   hombres   mujeres  \
# 0  Homicidio doloso         3  0.323526 2021-01-01  425731.0  451459.0
# 1  Homicidio doloso         0  0.000000 2021-01-01   22745.0   23719.0
# 2  Homicidio doloso         0  0.000000 2021-01-01    9982.0   10263.0
# 3  Homicidio doloso         0  0.000000 2021-01-01   10197.0   10729.0
# 4  Homicidio doloso         0  0.000000 2021-01-01   26693.0   27173.0
#
#       total
# 0  877190.0
# 1   46464.0
# 2   20245.0
# 3   20926.0
# 4   53866.0

# %% [markdown]
# ### 4.- Analysis

# %% [markdown]
# #### Select crimes

# %%
df_pop['delito'].unique()
# Out:
# array(['Homicidio doloso', 'Feminicidio', 'Homicidio culposo',
#        'Secuestro', 'Extorsión', 'Robo con violencia', 'Robo de vehículo',
#        'Robo a casa habitación', 'Robo a negocio',
#        'Robo a transeúnte total', 'Robo en transporte público',
#        'Violación', 'Violencia familiar', 'Trata de personas',
#        'Narcomenudeo', 'Lesiones dolosas'], dtype=object)

# %%
if limit_crimes == True:
    df_pop = df_pop[(df_pop['delito'] == 'Extorsión') |
                     (df_pop['delito'] == 'Robo a negocio') |
                     (df_pop['delito'] == 'Secuestro')]

# Aggregating crimes by id_municipio
crimes_by_municipio = df_pop.groupby('id_municipio').agg({'carpetas': np.sum, 'total': np.mean})

# Generating crimes per 10000 people
crimes_by_municipio['crimes_10k'] = (crimes_by_municipio['carpetas'] / crimes_by_municipio['total']) * 10000

# Adding names of places
crimes_by_municipio = pd.merge(crimes_by_municipio, df[['entidad', 'municipio', 'id_municipio']],
                                how='left', on='id_municipio')

# %%
crimes_by_municipio = crimes_by_municipio.groupby('id_municipio').agg({'carpetas': np.mean, 'total': np.mean,
                                                                        'crimes_10k': np.mean, 'entidad': stats.mode,
                                                                        'municipio':stats.mode})

# %%
# Extracting only value without frequency
crimes_by_municipio['entidad'] = crimes_by_municipio['entidad'].apply(lambda x: x[0][0])
crimes_by_municipio['municipio'] = crimes_by_municipio['municipio'].apply(lambda x: x[0][0])

# %%
# Rearanging columns
crimes_by_municipio = crimes_by_municipio[['entidad', 'municipio', 'carpetas', 'total', 'crimes_10k']]

# %% [markdown]
# #### *Clean dataset aggregated by id_municipio*

# %%
# Clean dataset
crimes_by_municipio
# Out:
#                      entidad              municipio  carpetas     total  \
# id_municipio
# 1001          Aguascalientes         Aguascalientes     11091  877190.0
# 1002          Aguascalientes               Asientos       411   46464.0
# 1003          Aguascalientes               Calvillo       304   56048.0
# 1004          Aguascalientes                  Cosio       148   15577.0
# 1005          Aguascalientes            Jesus Maria      1498  120405.0
# ...                      ...                    ...       ...       ...
# 32054              Zacatecas          Villa Hidalgo        45   19155.0
# 32055              Zacatecas             Villanueva       174   30240.0
# 32056              Zacatecas              Zacatecas      1942  146147.0
# 32057              Zacatecas               Trancoso       178   19413.0
# 32058              Zacatecas  Santa Maria De La Paz        15    2656.0
#
#               crimes_10k
# id_municipio
# 1001          126.437830
# 1002           88.455579
# 1003           54.239224
# 1004           95.011876
# 1005          124.413438
# ...                  ...
# 32054          23.492561
# 32055          57.539683
# 32056         132.879909
# 32057          91.691135
# 32058          56.475904
#
# [2457 rows x 5 columns]

# %% [markdown]
# ### X.- Coordinates data set

# %%
# Imoorting location lat, lon dataset
locations = pd.read_excel('data/coordenadas_municipios.xlsx')
locations.head()
# Out:
#    id_municipio        lat         lon
# 0          1001  21.879823 -102.296047
# 1          1002  22.238317 -102.089275
# 2          1003  21.846907 -102.718751
# 3          1004  22.366409 -102.300044
# 4          1005  21.961273 -102.343416

# %% [markdown]
# #### Coinciding id values

# %%
# Creating list of unique ids in each dataset
unique_id_crimes_by_municipio = crimes_by_municipio.index.unique()
unique_id_locations = locations['id_municipio'].unique()

# Len of the lists
len_id_crimes_by_municipio = len(crimes_by_municipio.index.unique())
len_id_locations = len(locations['id_municipio'].unique())

for i in unique_id_crimes_by_municipio:
    if i not in unique_id_locations:
        print('id_municipio {} does not exist in locations data'.format(i))

print('No missing values')

if len_id_df == len_id_locations:
    print('Equal lenghts')

print('Ready to merge crimes and locations')
# Out:
# No missing values
# Ready to merge crimes and locations

# %% [markdown]
# #### Merging location information

# %%
crimes_by_municipio = crimes_by_municipio.merge(locations, how='left', on='id_municipio')
crimes_by_municipio
# Out:
#       id_municipio         entidad              municipio  carpetas     total  \
# 0             1001  Aguascalientes         Aguascalientes     11091  877190.0
# 1             1002  Aguascalientes               Asientos       411   46464.0
# 2             1003  Aguascalientes               Calvillo       304   56048.0
# 3             1004  Aguascalientes                  Cosio       148   15577.0
# 4             1005  Aguascalientes            Jesus Maria      1498  120405.0
# ...            ...             ...                    ...       ...       ...
# 2452         32054       Zacatecas          Villa Hidalgo        45   19155.0
# 2453         32055       Zacatecas             Villanueva       174   30240.0
# 2454         32056       Zacatecas              Zacatecas      1942  146147.0
# 2455         32057       Zacatecas               Trancoso       178   19413.0
# 2456         32058       Zacatecas  Santa Maria De La Paz        15    2656.0
#
#       crimes_10k        lat         lon
# 0     126.437830  21.879823 -102.296047
# 1      88.455579  22.238317 -102.089275
# 2      54.239224  21.846907 -102.718751
# 3      95.011876  22.366409 -102.300044
# 4     124.413438  21.961273 -102.343416
# ...          ...        ...         ...
# 2452   23.492561  22.357088 -101.712599
# 2453   57.539683  22.354259 -102.883726
# 2454  132.879909  22.776096 -102.571836
# 2455   91.691135  22.735389 -102.366038
# 2456   56.475904  21.512178 -103.407042
#
# [2457 rows x 8 columns]

# %% [markdown]
# #### Creating scales

# %%
data_map_municipios = crimes_by_municipio
data_map_municipios = data_map_municipios.dropna()

limits = []
for x in range(0, 101, 20):
    limits.append(np.percentile(data_map_municipios['crimes_10k'], x))

data_map_municipios['class'] = data_map_municipios['crimes_10k'].apply(lambda x:
                                        0 if (x >= limits[0] and x < limits[1])
                                        else
                                        (1 if (x > limits[1] and x < limits[2]) 
                                        else 
                                        (2 if (x > limits[2] and x < limits[3])
                                        else 
                                        (3 if (x > limits[3] and x < limits[4])
                                        else 4))))
# Out:
# <ipython-input-51-7ba2dacff282>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_map_municipios['class'] = data_map_municipios['crimes_10k'].apply(lambda x:

# %%
data_map_municipios.head()
# Out:
#    id_municipio         entidad       municipio  carpetas     total  \
# 0          1001  Aguascalientes  Aguascalientes     11091  877190.0
# 1          1002  Aguascalientes        Asientos       411   46464.0
# 2          1003  Aguascalientes        Calvillo       304   56048.0
# 3          1004  Aguascalientes           Cosio       148   15577.0
# 4          1005  Aguascalientes     Jesus Maria      1498  120405.0
#
#    crimes_10k        lat         lon  class
# 0  126.437830  21.879823 -102.296047      4
# 1   88.455579  22.238317 -102.089275      4
# 2   54.239224  21.846907 -102.718751      3
# 3   95.011876  22.366409 -102.300044      4
# 4  124.413438  21.961273 -102.343416      4

# %% [markdown]
# #### Map

# %%
import folium

map = folium.Map(location = [20.693943, -100.985880], zoom_start=5.3)

data1 = data_map_municipios

data = data_map_municipios

for state in data1['entidad'].unique():
    data = data1[data1['entidad'] == state]

    colors = ['forestgreen', 'lime', 'yellow', 'lightcoral', 'firebrick']
    for cluster in range(5):
        color_cluster = colors[cluster]
        for point in range(len(data[data['class']==cluster])):
            folium.CircleMarker(location=[data.iloc[point]['lat'], data.iloc[point]['lon']],
            radius=8,
            color=color_cluster,
            fill_color=color_cluster,
            fill=True
            ).add_to(map)



map.save('map_colors.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_11946e189f8c448abb7568aed6eb44db%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_11946e189f8c448abb7568aed6eb44db%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_11946e189f8c448abb7568aed6eb44db%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_11946e189f8c448abb7568aed6eb44db%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B20.693943%2C%20-100.98588%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
data[data['municipio'] == 'Puebla']
# Out:
# Empty DataFrame
# Columns: [id_municipio, entidad, municipio, carpetas, total, crimes_10k, lat, lon, class]
# Index: []

# %%
import folium
from folium.plugins import HeatMap

data['map_input'] = data.apply(lambda x: [x['lat'], x['lon'], x['crimes_10k']], axis=1)
map_data = data['map_input']

# Create map object
map = folium.Map(location = [20.693943, -100.985880], zoom_start=5.3)

HeatMap(map_data).add_to(map)

map.save('map1.html')

map
# Out:
# <ipython-input-55-9ac1f43ab5de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['map_input'] = data.apply(lambda x: [x['lat'], x['lon'], x['crimes_10k']], axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_374f4e01363b43858a6885837e4ec10b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_374f4e01363b43858a6885837e4ec10b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_374f4e01363b43858a6885837e4ec10b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_374f4e01363b43858a6885837e4ec10b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Exporting data map to excel
data.to_csv('output data/data_map_mun.csv')

# %% [markdown]
# #### Aggregating on neighborhood scope

# %%
# Importing location of neighborhoods
locations = pd.read_excel('data/codigos-postales-mexico.xlsx')

# Cleaning
# Column names
locations.columns = [x.strip().lower() for x in locations.columns]
locations = locations.rename(columns={'código': 'código postal',
                                        'estado': 'entidad'})

# CDMX for DF
locations = locations.replace('Distrito Federal', 'Ciudad de México')

# Stripping municipio
locations['municipio_strip'] = locations['municipio'].replace(' ', '', regex=True)

# Generating municipio_entidad
locations['entidad_municipio'] = locations['entidad'] + '-' + locations['municipio']

# Converting into lowercase
locations['entidad_municipio'] = locations['entidad_municipio'].apply(lambda x: x.lower())

locations.head()
# Out:
#    código postal                                       asentamiento  \
# 0           1000                                          San Angel
# 1           1010                                          Los Alpes
# 2           1020                                      Guadalupe Inn
# 3           1028  Secretaria de Contraloría y Desarrollo Adminis...
# 4           1029                                          INFONAVIT
#
#            tipo       municipio            ciudad           entidad  \
# 0       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 1       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 2       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 3  Gran usuario  Álvaro Obregón  Ciudad de México  Ciudad de México
# 4  Gran usuario  Álvaro Obregón  Ciudad de México  Ciudad de México
#
#   municipio_strip                entidad_municipio
# 0   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 1   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 2   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 3   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 4   ÁlvaroObregón  ciudad de méxico-álvaro obregón

# %%
# Cleaning data dataset
data = data[['id_municipio', 'entidad', 'municipio', 'carpetas', 'total',
       'crimes_10k', 'class']]

# Changing abbreviations
data = data.replace({'Dr.': 'Doctor',
                    'Gral.': 'General'},
                    regex=True)

data['entidad_municipio'] = data['entidad'] + '-' + data['municipio']

data['entidad_municipio'] = data['entidad_municipio'].apply(lambda x: x.lower())


data
# Out:
#       id_municipio    entidad                     municipio  carpetas  \
# 2399         32001  Zacatecas                        Apozol        20
# 2400         32002  Zacatecas                        Apulco         5
# 2401         32003  Zacatecas                      Atolinga        12
# 2402         32004  Zacatecas                 Benito Juarez         9
# 2403         32005  Zacatecas                        Calera       387
# 2404         32006  Zacatecas    Cañitas De Felipe Pescador        22
# 2405         32007  Zacatecas            Concepcion Del Oro       130
# 2406         32008  Zacatecas                    Cuauhtemoc        40
# 2407         32009  Zacatecas                 Chalchihuites        17
# 2408         32010  Zacatecas                     Fresnillo      2628
# 2409         32011  Zacatecas  Trinidad Garcia De La Cadena         7
# 2410         32012  Zacatecas                 Genaro Codina        54
# 2411         32013  Zacatecas       General Enrique Estrada        64
# 2412         32014  Zacatecas  General Francisco R. Murguia        22
# 2413         32015  Zacatecas  El Plateado De Joaquin Amaro         7
# 2414         32016  Zacatecas        General Panfilo Natera       108
# 2415         32017  Zacatecas                     Guadalupe      2222
# 2416         32018  Zacatecas                      Huanusco        16
# 2417         32019  Zacatecas                         Jalpa       119
# 2418         32020  Zacatecas                         Jerez       483
# 2419         32021  Zacatecas              Jimenez Del Teul         5
# 2420         32022  Zacatecas                   Juan Aldama        81
# 2421         32023  Zacatecas                     Juchipila        45
# 2422         32024  Zacatecas                        Loreto       208
# 2423         32025  Zacatecas                     Luis Moya        50
# 2424         32026  Zacatecas                       Mazapil        78
# 2425         32027  Zacatecas                Melchor Ocampo         5
# 2426         32028  Zacatecas             Mezquital Del Oro         2
# 2427         32029  Zacatecas                   Miguel Auza        72
# 2428         32030  Zacatecas                         Momax        12
# 2429         32031  Zacatecas                Monte Escobedo        58
# 2430         32032  Zacatecas                       Morelos       128
# 2431         32033  Zacatecas            Moyahua De Estrada         9
# 2432         32034  Zacatecas           Nochistlan De Mejia        53
# 2433         32035  Zacatecas              Noria De Angeles        24
# 2434         32036  Zacatecas                   Ojocaliente       352
# 2435         32037  Zacatecas                        Panuco        96
# 2436         32038  Zacatecas                         Pinos       292
# 2437         32039  Zacatecas                    Rio Grande       173
# 2438         32040  Zacatecas                     Sain Alto        78
# 2439         32041  Zacatecas                   El Salvador         3
# 2440         32042  Zacatecas                    Sombrerete       342
# 2441         32043  Zacatecas                    Susticacan         3
# 2442         32044  Zacatecas                       Tabasco        44
# 2443         32045  Zacatecas                   Tepechitlan        42
# 2444         32046  Zacatecas                     Tepetongo        38
# 2445         32047  Zacatecas       Teul De Gonzalez Ortega        32
# 2446         32048  Zacatecas  Tlaltenango De Sanchez Roman       155
# 2447         32049  Zacatecas                    Valparaiso       278
# 2448         32050  Zacatecas                    Vetagrande        63
# 2449         32051  Zacatecas                  Villa De Cos       149
# 2450         32052  Zacatecas                  Villa Garcia        35
# 2451         32053  Zacatecas         Villa Gonzalez Ortega        35
# 2452         32054  Zacatecas                 Villa Hidalgo        45
# 2453         32055  Zacatecas                    Villanueva       174
# 2454         32056  Zacatecas                     Zacatecas      1942
# 2455         32057  Zacatecas                      Trancoso       178
# 2456         32058  Zacatecas         Santa Maria De La Paz        15
#
#          total  crimes_10k  class                       entidad_municipio
# 2399    6086.0   32.862307      2                        zacatecas-apozol
# 2400    4738.0   10.552976      1                        zacatecas-apulco
# 2401    2427.0   49.443758      3                      zacatecas-atolinga
# 2402    3990.0   22.556391      2                 zacatecas-benito juarez
# 2403   45204.0   85.611893      4                        zacatecas-calera
# 2404    8393.0   26.212320      2    zacatecas-cañitas de felipe pescador
# 2405   12944.0  100.432633      4            zacatecas-concepcion del oro
# 2406   12590.0   31.771247      2                    zacatecas-cuauhtemoc
# 2407   11416.0   14.891381      1                 zacatecas-chalchihuites
# 2408  230865.0  113.832759      4                     zacatecas-fresnillo
# 2409    2884.0   24.271845      2  zacatecas-trinidad garcia de la cadena
# 2410    8185.0   65.974343      3                 zacatecas-genaro codina
# 2411    6325.0  101.185771      4       zacatecas-general enrique estrada
# 2412   21809.0   10.087579      0  zacatecas-general francisco r. murguia
# 2413    1160.0   60.344828      3  zacatecas-el plateado de joaquin amaro
# 2414   23192.0   46.567782      3        zacatecas-general panfilo natera
# 2415  187918.0  118.243063      4                     zacatecas-guadalupe
# 2416    4084.0   39.177277      3                      zacatecas-huanusco
# 2417   24093.0   49.391940      3                         zacatecas-jalpa
# 2418   59125.0   81.691332      4                         zacatecas-jerez
# 2419    4275.0   11.695906      1              zacatecas-jimenez del teul
# 2420   21806.0   37.145740      2                   zacatecas-juan aldama
# 2421   12627.0   35.637919      2                     zacatecas-juchipila
# 2422   53441.0   38.921427      3                        zacatecas-loreto
# 2423   13292.0   37.616611      2                     zacatecas-luis moya
# 2424   17457.0   44.681217      3                       zacatecas-mazapil
# 2425    2938.0   17.018380      1                zacatecas-melchor ocampo
# 2426    2484.0    8.051530      0             zacatecas-mezquital del oro
# 2427   23827.0   30.217820      2                   zacatecas-miguel auza
# 2428    2404.0   49.916805      3                         zacatecas-momax
# 2429    9129.0   63.533793      3                zacatecas-monte escobedo
# 2430   12354.0  103.610167      4                       zacatecas-morelos
# 2431    3947.0   22.802128      2            zacatecas-moyahua de estrada
# 2432   27750.0   19.099099      1           zacatecas-nochistlan de mejia
# 2433   16864.0   14.231499      1              zacatecas-noria de angeles
# 2434   43471.0   80.973523      4                   zacatecas-ojocaliente
# 2435   17647.0   54.400181      3                        zacatecas-panuco
# 2436   73151.0   39.917431      3                         zacatecas-pinos
# 2437   63880.0   27.082029      2                    zacatecas-rio grande
# 2438   22278.0   35.012120      2                     zacatecas-sain alto
# 2439    2455.0   12.219959      1                   zacatecas-el salvador
# 2440   62433.0   54.778723      3                    zacatecas-sombrerete
# 2441    1329.0   22.573363      2                    zacatecas-susticacan
# 2442   15484.0   28.416430      2                       zacatecas-tabasco
# 2443    8855.0   47.430830      3                   zacatecas-tepechitlan
# 2444    7071.0   53.740631      3                     zacatecas-tepetongo
# 2445    5378.0   59.501673      3       zacatecas-teul de gonzalez ortega
# 2446   26645.0   58.172265      3  zacatecas-tlaltenango de sanchez roman
# 2447   32606.0   85.260382      4                    zacatecas-valparaiso
# 2448    9796.0   64.311964      3                    zacatecas-vetagrande
# 2449   35252.0   42.267105      3                  zacatecas-villa de cos
# 2450   18745.0   18.671646      1                  zacatecas-villa garcia
# 2451   13099.0   26.719597      2         zacatecas-villa gonzalez ortega
# 2452   19155.0   23.492561      2                 zacatecas-villa hidalgo
# 2453   30240.0   57.539683      3                    zacatecas-villanueva
# 2454  146147.0  132.879909      4                     zacatecas-zacatecas
# 2455   19413.0   91.691135      4                      zacatecas-trancoso
# 2456    2656.0   56.475904      3         zacatecas-santa maria de la paz

# %% [markdown]
# Coinciding values entidad_municipio

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

#for i in unique_mun_locations:
 #   if i not in unique_mun_data:
  #      print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# entidad_municipio zacatecas-benito juarez does not exist in locations data
# entidad_municipio zacatecas-concepcion del oro does not exist in locations data
# entidad_municipio zacatecas-cuauhtemoc does not exist in locations data
# entidad_municipio zacatecas-trinidad garcia de la cadena does not exist in locations data
# entidad_municipio zacatecas-general francisco r. murguia does not exist in locations data
# entidad_municipio zacatecas-el plateado de joaquin amaro does not exist in locations data
# entidad_municipio zacatecas-general panfilo natera does not exist in locations data
# entidad_municipio zacatecas-jimenez del teul does not exist in locations data
# entidad_municipio zacatecas-nochistlan de mejia does not exist in locations data
# entidad_municipio zacatecas-noria de angeles does not exist in locations data
# entidad_municipio zacatecas-panuco does not exist in locations data
# entidad_municipio zacatecas-rio grande does not exist in locations data
# entidad_municipio zacatecas-susticacan does not exist in locations data
# entidad_municipio zacatecas-tepechitlan does not exist in locations data
# entidad_municipio zacatecas-teul de gonzalez ortega does not exist in locations data
# entidad_municipio zacatecas-tlaltenango de sanchez roman does not exist in locations data
# entidad_municipio zacatecas-valparaiso does not exist in locations data
# entidad_municipio zacatecas-villa garcia does not exist in locations data
# entidad_municipio zacatecas-villa gonzalez ortega does not exist in locations data
# entidad_municipio zacatecas-santa maria de la paz does not exist in locations data
# No missing values
# Ready to merge crimes and data

# %%
# Cleaning acentos
locations = locations.replace({'Á': 'A', 'á': 'a',
                    'É': 'E', 'é': 'e',
                    'Í': 'I', 'í': 'i',
                    'Ó': 'O', 'ó': 'o',
                    'Ú': 'U', 'ú': 'u'},
                    regex=True)

data = data.replace({'Á': 'A', 'á': 'a',
                    'É': 'E', 'é': 'e',
                    'Í': 'I', 'í': 'i',
                    'Ó': 'O', 'ó': 'o',
                    'Ú': 'U', 'ú': 'u'},
                    regex=True)
locations
# Out:
#         código postal                                       asentamiento  \
# 0                1000                                          San Angel
# 1                1010                                          Los Alpes
# 2                1020                                      Guadalupe Inn
# 3                1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4                1029                                          INFONAVIT
# ...               ...                                                ...
# 143219          99993                                            Cuxpala
# 143220          99994                                   Vicente Guerrero
# 143221          99998                                          Palmarejo
# 143222          99998                                        Jesus Maria
# 143223          99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143222     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143223     Rancheria  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip                entidad_municipio
# 0          AlvaroObregon  ciudad de mexico-alvaro obregon
# 1          AlvaroObregon  ciudad de mexico-alvaro obregon
# 2          AlvaroObregon  ciudad de mexico-alvaro obregon
# 3          AlvaroObregon  ciudad de mexico-alvaro obregon
# 4          AlvaroObregon  ciudad de mexico-alvaro obregon
# ...                  ...                              ...
# 143219  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143220  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143221  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143222  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143223  MoyahuadeEstrada     zacatecas-moyahua de estrada
#
# [143224 rows x 8 columns]

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

#for i in unique_mun_locations:
 #   if i not in unique_mun_data:
  #      print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# No missing values
# Ready to merge crimes and data

# %%
# Replacing data mannually
locations['entidad_municipio'] = locations['entidad_municipio'].replace({
                                                                        'guanajuato-silao de la victoria': 'guanajuato-silao',
                                                                        'jalisco-san pedro tlaquepaque': 'jalisco-tlaquepaque',
                                                                        'mexico-acambay de ruiz castañeda': 'mexico-acambay',
                                                                        'morelos-tlaltizapan de zapata': 'morelos-tlaltizapan',
                                                                        'chihuahua-dr. belisario dominguez': 'chihuahua-doctor belisario dominguez',
                                                                        'nuevo leon-el carmen': 'nuevo leon-carmen'
                                                                        })

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

for i in unique_mun_locations:
    if i not in unique_mun_data:
        print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# entidad_municipio ciudad de mexico-alvaro obregon does not exist in data data
# entidad_municipio ciudad de mexico-azcapotzalco does not exist in data data
# entidad_municipio ciudad de mexico-benito juarez does not exist in data data
# entidad_municipio ciudad de mexico-coyoacan does not exist in data data
# entidad_municipio ciudad de mexico-cuajimalpa de morelos does not exist in data data
# entidad_municipio ciudad de mexico-cuauhtemoc does not exist in data data
# entidad_municipio ciudad de mexico-gustavo a. madero does not exist in data data
# entidad_municipio ciudad de mexico-iztacalco does not exist in data data
# entidad_municipio ciudad de mexico-iztapalapa does not exist in data data
# entidad_municipio ciudad de mexico-la magdalena contreras does not exist in data data
# entidad_municipio ciudad de mexico-miguel hidalgo does not exist in data data
# entidad_municipio ciudad de mexico-milpa alta does not exist in data data
# entidad_municipio ciudad de mexico-tlahuac does not exist in data data
# entidad_municipio ciudad de mexico-tlalpan does not exist in data data
# entidad_municipio ciudad de mexico-venustiano carranza does not exist in data data
# entidad_municipio ciudad de mexico-xochimilco does not exist in data data
# entidad_municipio aguascalientes-aguascalientes does not exist in data data
# entidad_municipio aguascalientes-san francisco de los romo does not exist in data data
# entidad_municipio aguascalientes-el llano does not exist in data data
# entidad_municipio aguascalientes-rincon de romos does not exist in data data
# entidad_municipio aguascalientes-cosio does not exist in data data
# entidad_municipio aguascalientes-san jose de gracia does not exist in data data
# entidad_municipio aguascalientes-tepezala does not exist in data data
# entidad_municipio aguascalientes-pabellon de arteaga does not exist in data data
# entidad_municipio aguascalientes-asientos does not exist in data data
# entidad_municipio aguascalientes-calvillo does not exist in data data
# entidad_municipio aguascalientes-jesus maria does not exist in data data
# entidad_municipio baja california-mexicali does not exist in data data
# entidad_municipio baja california-tecate does not exist in data data
# entidad_municipio baja california-tijuana does not exist in data data
# entidad_municipio baja california-playas de rosarito does not exist in data data
# entidad_municipio baja california-ensenada does not exist in data data
# entidad_municipio baja california sur-la paz does not exist in data data
# entidad_municipio baja california sur-los cabos does not exist in data data
# entidad_municipio baja california sur-comondu does not exist in data data
# entidad_municipio baja california sur-loreto does not exist in data data
# entidad_municipio baja california sur-mulege does not exist in data data
# entidad_municipio campeche-campeche does not exist in data data
# entidad_municipio campeche-carmen does not exist in data data
# entidad_municipio campeche-palizada does not exist in data data
# entidad_municipio campeche-candelaria does not exist in data data
# entidad_municipio campeche-escarcega does not exist in data data
# entidad_municipio campeche-champoton does not exist in data data
# entidad_municipio campeche-hopelchen does not exist in data data
# entidad_municipio campeche-calakmul does not exist in data data
# entidad_municipio campeche-tenabo does not exist in data data
# entidad_municipio campeche-hecelchakan does not exist in data data
# entidad_municipio campeche-calkini does not exist in data data
# entidad_municipio coahuila de zaragoza-saltillo does not exist in data data
# entidad_municipio coahuila de zaragoza-arteaga does not exist in data data
# entidad_municipio coahuila de zaragoza-juarez does not exist in data data
# entidad_municipio coahuila de zaragoza-progreso does not exist in data data
# entidad_municipio coahuila de zaragoza-escobedo does not exist in data data
# entidad_municipio coahuila de zaragoza-san buenaventura does not exist in data data
# entidad_municipio coahuila de zaragoza-abasolo does not exist in data data
# entidad_municipio coahuila de zaragoza-candela does not exist in data data
# entidad_municipio coahuila de zaragoza-frontera does not exist in data data
# entidad_municipio coahuila de zaragoza-monclova does not exist in data data
# entidad_municipio coahuila de zaragoza-castaños does not exist in data data
# entidad_municipio coahuila de zaragoza-ramos arizpe does not exist in data data
# entidad_municipio coahuila de zaragoza-general cepeda does not exist in data data
# entidad_municipio coahuila de zaragoza-piedras negras does not exist in data data
# entidad_municipio coahuila de zaragoza-nava does not exist in data data
# entidad_municipio coahuila de zaragoza-acuña does not exist in data data
# entidad_municipio coahuila de zaragoza-muzquiz does not exist in data data
# entidad_municipio coahuila de zaragoza-jimenez does not exist in data data
# entidad_municipio coahuila de zaragoza-zaragoza does not exist in data data
# entidad_municipio coahuila de zaragoza-morelos does not exist in data data
# entidad_municipio coahuila de zaragoza-allende does not exist in data data
# entidad_municipio coahuila de zaragoza-villa union does not exist in data data
# entidad_municipio coahuila de zaragoza-guerrero does not exist in data data
# entidad_municipio coahuila de zaragoza-hidalgo does not exist in data data
# entidad_municipio coahuila de zaragoza-sabinas does not exist in data data
# entidad_municipio coahuila de zaragoza-san juan de sabinas does not exist in data data
# entidad_municipio coahuila de zaragoza-torreon does not exist in data data
# entidad_municipio coahuila de zaragoza-matamoros does not exist in data data
# entidad_municipio coahuila de zaragoza-viesca does not exist in data data
# entidad_municipio coahuila de zaragoza-ocampo does not exist in data data
# entidad_municipio coahuila de zaragoza-nadadores does not exist in data data
# entidad_municipio coahuila de zaragoza-sierra mojada does not exist in data data
# entidad_municipio coahuila de zaragoza-cuatro cienegas does not exist in data data
# entidad_municipio coahuila de zaragoza-lamadrid does not exist in data data
# entidad_municipio coahuila de zaragoza-sacramento does not exist in data data
# entidad_municipio coahuila de zaragoza-san pedro does not exist in data data
# entidad_municipio coahuila de zaragoza-francisco i. madero does not exist in data data
# entidad_municipio coahuila de zaragoza-parras does not exist in data data
# entidad_municipio colima-colima does not exist in data data
# entidad_municipio colima-tecoman does not exist in data data
# entidad_municipio colima-manzanillo does not exist in data data
# entidad_municipio colima-armeria does not exist in data data
# entidad_municipio colima-coquimatlan does not exist in data data
# entidad_municipio colima-comala does not exist in data data
# entidad_municipio colima-cuauhtemoc does not exist in data data
# entidad_municipio colima-ixtlahuacan does not exist in data data
# entidad_municipio colima-minatitlan does not exist in data data
# entidad_municipio colima-villa de alvarez does not exist in data data
# entidad_municipio chiapas-tuxtla gutierrez does not exist in data data
# entidad_municipio chiapas-san fernando does not exist in data data
# entidad_municipio chiapas-berriozabal does not exist in data data
# entidad_municipio chiapas-ocozocoautla de espinosa does not exist in data data
# entidad_municipio chiapas-suchiapa does not exist in data data
# entidad_municipio chiapas-chiapa de corzo does not exist in data data
# entidad_municipio chiapas-osumacinta does not exist in data data
# entidad_municipio chiapas-san cristobal de las casas does not exist in data data
# entidad_municipio chiapas-chamula does not exist in data data
# entidad_municipio chiapas-ixtapa does not exist in data data
# entidad_municipio chiapas-zinacantan does not exist in data data
# entidad_municipio chiapas-acala does not exist in data data
# entidad_municipio chiapas-chiapilla does not exist in data data
# entidad_municipio chiapas-san lucas does not exist in data data
# entidad_municipio chiapas-teopisca does not exist in data data
# entidad_municipio chiapas-amatenango del valle does not exist in data data
# entidad_municipio chiapas-chanal does not exist in data data
# entidad_municipio chiapas-oxchuc does not exist in data data
# entidad_municipio chiapas-huixtan does not exist in data data
# entidad_municipio chiapas-tenejapa does not exist in data data
# entidad_municipio chiapas-mitontic does not exist in data data
# entidad_municipio chiapas-reforma does not exist in data data
# entidad_municipio chiapas-juarez does not exist in data data
# entidad_municipio chiapas-pichucalco does not exist in data data
# entidad_municipio chiapas-sunuapa does not exist in data data
# entidad_municipio chiapas-ostuacan does not exist in data data
# entidad_municipio chiapas-francisco leon does not exist in data data
# entidad_municipio chiapas-ixtacomitan does not exist in data data
# entidad_municipio chiapas-solosuchiapa does not exist in data data
# entidad_municipio chiapas-ixtapangajoya does not exist in data data
# entidad_municipio chiapas-tecpatan does not exist in data data
# entidad_municipio chiapas-copainala does not exist in data data
# entidad_municipio chiapas-chicoasen does not exist in data data
# entidad_municipio chiapas-coapilla does not exist in data data
# entidad_municipio chiapas-pantepec does not exist in data data
# entidad_municipio chiapas-tapalapa does not exist in data data
# entidad_municipio chiapas-ocotepec does not exist in data data
# entidad_municipio chiapas-chapultenango does not exist in data data
# entidad_municipio chiapas-amatan does not exist in data data
# entidad_municipio chiapas-huitiupan does not exist in data data
# entidad_municipio chiapas-ixhuatan does not exist in data data
# entidad_municipio chiapas-tapilula does not exist in data data
# entidad_municipio chiapas-rayon does not exist in data data
# entidad_municipio chiapas-pueblo nuevo solistahuacan does not exist in data data
# entidad_municipio chiapas-jitotol does not exist in data data
# entidad_municipio chiapas-bochil does not exist in data data
# entidad_municipio chiapas-soyalo does not exist in data data
# entidad_municipio chiapas-san juan cancuc does not exist in data data
# entidad_municipio chiapas-sabanilla does not exist in data data
# entidad_municipio chiapas-simojovel does not exist in data data
# entidad_municipio chiapas-san andres duraznal does not exist in data data
# entidad_municipio chiapas-el bosque does not exist in data data
# entidad_municipio chiapas-chalchihuitan does not exist in data data
# entidad_municipio chiapas-larrainzar does not exist in data data
# entidad_municipio chiapas-santiago el pinar does not exist in data data
# entidad_municipio chiapas-chenalho does not exist in data data
# entidad_municipio chiapas-aldama does not exist in data data
# entidad_municipio chiapas-pantelho does not exist in data data
# entidad_municipio chiapas-sitala does not exist in data data
# entidad_municipio chiapas-salto de agua does not exist in data data
# entidad_municipio chiapas-tila does not exist in data data
# entidad_municipio chiapas-tumbala does not exist in data data
# entidad_municipio chiapas-yajalon does not exist in data data
# entidad_municipio chiapas-ocosingo does not exist in data data
# entidad_municipio chiapas-chilon does not exist in data data
# entidad_municipio chiapas-benemerito de las americas does not exist in data data
# entidad_municipio chiapas-marques de comillas does not exist in data data
# entidad_municipio chiapas-palenque does not exist in data data
# entidad_municipio chiapas-la libertad does not exist in data data
# entidad_municipio chiapas-catazaja does not exist in data data
# entidad_municipio chiapas-comitan de dominguez does not exist in data data
# entidad_municipio chiapas-tzimol does not exist in data data
# entidad_municipio chiapas-chicomuselo does not exist in data data
# entidad_municipio chiapas-bella vista does not exist in data data
# entidad_municipio chiapas-frontera comalapa does not exist in data data
# entidad_municipio chiapas-la trinitaria does not exist in data data
# entidad_municipio chiapas-la independencia does not exist in data data
# entidad_municipio chiapas-maravilla tenejapa does not exist in data data
# entidad_municipio chiapas-las margaritas does not exist in data data
# entidad_municipio chiapas-altamirano does not exist in data data
# entidad_municipio chiapas-venustiano carranza does not exist in data data
# entidad_municipio chiapas-totolapa does not exist in data data
# entidad_municipio chiapas-nicolas ruiz does not exist in data data
# entidad_municipio chiapas-las rosas does not exist in data data
# entidad_municipio chiapas-la concordia does not exist in data data
# entidad_municipio chiapas-angel albino corzo does not exist in data data
# entidad_municipio chiapas-montecristo de guerrero does not exist in data data
# entidad_municipio chiapas-socoltenango does not exist in data data
# entidad_municipio chiapas-cintalapa does not exist in data data
# entidad_municipio chiapas-jiquipilas does not exist in data data
# entidad_municipio chiapas-arriaga does not exist in data data
# entidad_municipio chiapas-villaflores does not exist in data data
# entidad_municipio chiapas-tonala does not exist in data data
# entidad_municipio chiapas-villa corzo does not exist in data data
# entidad_municipio chiapas-pijijiapan does not exist in data data
# entidad_municipio chiapas-mapastepec does not exist in data data
# entidad_municipio chiapas-acapetahua does not exist in data data
# entidad_municipio chiapas-acacoyagua does not exist in data data
# entidad_municipio chiapas-escuintla does not exist in data data
# entidad_municipio chiapas-villa comaltitlan does not exist in data data
# entidad_municipio chiapas-huixtla does not exist in data data
# entidad_municipio chiapas-mazatan does not exist in data data
# entidad_municipio chiapas-huehuetan does not exist in data data
# entidad_municipio chiapas-tuzantan does not exist in data data
# entidad_municipio chiapas-tapachula does not exist in data data
# entidad_municipio chiapas-suchiate does not exist in data data
# entidad_municipio chiapas-frontera hidalgo does not exist in data data
# entidad_municipio chiapas-metapa does not exist in data data
# entidad_municipio chiapas-tuxtla chico does not exist in data data
# entidad_municipio chiapas-union juarez does not exist in data data
# entidad_municipio chiapas-cacahoatan does not exist in data data
# entidad_municipio chiapas-motozintla does not exist in data data
# entidad_municipio chiapas-mazapa de madero does not exist in data data
# entidad_municipio chiapas-amatenango de la frontera does not exist in data data
# entidad_municipio chiapas-bejucal de ocampo does not exist in data data
# entidad_municipio chiapas-la grandeza does not exist in data data
# entidad_municipio chiapas-el porvenir does not exist in data data
# entidad_municipio chiapas-siltepec does not exist in data data
# entidad_municipio chihuahua-chihuahua does not exist in data data
# entidad_municipio chihuahua-cuauhtemoc does not exist in data data
# entidad_municipio chihuahua-riva palacio does not exist in data data
# entidad_municipio chihuahua-aquiles serdan does not exist in data data
# entidad_municipio chihuahua-bachiniva does not exist in data data
# entidad_municipio chihuahua-guerrero does not exist in data data
# entidad_municipio chihuahua-nuevo casas grandes does not exist in data data
# entidad_municipio chihuahua-ascension does not exist in data data
# entidad_municipio chihuahua-janos does not exist in data data
# entidad_municipio chihuahua-casas grandes does not exist in data data
# entidad_municipio chihuahua-galeana does not exist in data data
# entidad_municipio chihuahua-buenaventura does not exist in data data
# entidad_municipio chihuahua-gomez farias does not exist in data data
# entidad_municipio chihuahua-ignacio zaragoza does not exist in data data
# entidad_municipio chihuahua-madera does not exist in data data
# entidad_municipio chihuahua-namiquipa does not exist in data data
# entidad_municipio chihuahua-temosachic does not exist in data data
# entidad_municipio chihuahua-matachi does not exist in data data
# entidad_municipio chihuahua-juarez does not exist in data data
# entidad_municipio chihuahua-guadalupe does not exist in data data
# entidad_municipio chihuahua-praxedis g. guerrero does not exist in data data
# entidad_municipio chihuahua-ahumada does not exist in data data
# entidad_municipio chihuahua-coyame del sotol does not exist in data data
# entidad_municipio chihuahua-ojinaga does not exist in data data
# entidad_municipio chihuahua-aldama does not exist in data data
# entidad_municipio chihuahua-julimes does not exist in data data
# entidad_municipio chihuahua-manuel benavides does not exist in data data
# entidad_municipio chihuahua-delicias does not exist in data data
# entidad_municipio chihuahua-rosales does not exist in data data
# entidad_municipio chihuahua-meoqui does not exist in data data
# entidad_municipio chihuahua-doctor belisario dominguez does not exist in data data
# entidad_municipio chihuahua-satevo does not exist in data data
# entidad_municipio chihuahua-san francisco de borja does not exist in data data
# entidad_municipio chihuahua-nonoava does not exist in data data
# entidad_municipio chihuahua-guachochi does not exist in data data
# entidad_municipio chihuahua-bocoyna does not exist in data data
# entidad_municipio chihuahua-cusihuiriachi does not exist in data data
# entidad_municipio chihuahua-gran morelos does not exist in data data
# entidad_municipio chihuahua-santa isabel does not exist in data data
# entidad_municipio chihuahua-carichi does not exist in data data
# entidad_municipio chihuahua-uruachi does not exist in data data
# entidad_municipio chihuahua-ocampo does not exist in data data
# entidad_municipio chihuahua-moris does not exist in data data
# entidad_municipio chihuahua-chinipas does not exist in data data
# entidad_municipio chihuahua-maguarichi does not exist in data data
# entidad_municipio chihuahua-guazapares does not exist in data data
# entidad_municipio chihuahua-batopilas does not exist in data data
# entidad_municipio chihuahua-urique does not exist in data data
# entidad_municipio chihuahua-morelos does not exist in data data
# entidad_municipio chihuahua-guadalupe y calvo does not exist in data data
# entidad_municipio chihuahua-san francisco del oro does not exist in data data
# entidad_municipio chihuahua-rosario does not exist in data data
# entidad_municipio chihuahua-huejotitan does not exist in data data
# entidad_municipio chihuahua-el tule does not exist in data data
# entidad_municipio chihuahua-balleza does not exist in data data
# entidad_municipio chihuahua-santa barbara does not exist in data data
# entidad_municipio chihuahua-camargo does not exist in data data
# entidad_municipio chihuahua-saucillo does not exist in data data
# entidad_municipio chihuahua-valle de zaragoza does not exist in data data
# entidad_municipio chihuahua-la cruz does not exist in data data
# entidad_municipio chihuahua-san francisco de conchos does not exist in data data
# entidad_municipio chihuahua-hidalgo del parral does not exist in data data
# entidad_municipio chihuahua-allende does not exist in data data
# entidad_municipio chihuahua-lopez does not exist in data data
# entidad_municipio chihuahua-matamoros does not exist in data data
# entidad_municipio chihuahua-jimenez does not exist in data data
# entidad_municipio chihuahua-coronado does not exist in data data
# entidad_municipio durango-durango does not exist in data data
# entidad_municipio durango-canatlan does not exist in data data
# entidad_municipio durango-nuevo ideal does not exist in data data
# entidad_municipio durango-coneto de comonfort does not exist in data data
# entidad_municipio durango-san juan del rio does not exist in data data
# entidad_municipio durango-canelas does not exist in data data
# entidad_municipio durango-topia does not exist in data data
# entidad_municipio durango-tamazula does not exist in data data
# entidad_municipio durango-santiago papasquiaro does not exist in data data
# entidad_municipio durango-otaez does not exist in data data
# entidad_municipio durango-san dimas does not exist in data data
# entidad_municipio durango-guadalupe victoria does not exist in data data
# entidad_municipio durango-peñon blanco does not exist in data data
# entidad_municipio durango-panuco de coronado does not exist in data data
# entidad_municipio durango-poanas does not exist in data data
# entidad_municipio durango-nombre de dios does not exist in data data
# entidad_municipio durango-vicente guerrero does not exist in data data
# entidad_municipio durango-suchil does not exist in data data
# entidad_municipio durango-pueblo nuevo does not exist in data data
# entidad_municipio durango-mezquital does not exist in data data
# entidad_municipio durango-gomez palacio does not exist in data data
# entidad_municipio durango-lerdo does not exist in data data
# entidad_municipio durango-mapimi does not exist in data data
# entidad_municipio durango-tlahualilo does not exist in data data
# entidad_municipio durango-hidalgo does not exist in data data
# entidad_municipio durango-ocampo does not exist in data data
# entidad_municipio durango-guanacevi does not exist in data data
# entidad_municipio durango-san bernardo does not exist in data data
# entidad_municipio durango-inde does not exist in data data
# entidad_municipio durango-san pedro del gallo does not exist in data data
# entidad_municipio durango-tepehuanes does not exist in data data
# entidad_municipio durango-el oro does not exist in data data
# entidad_municipio durango-nazas does not exist in data data
# entidad_municipio durango-san luis del cordero does not exist in data data
# entidad_municipio durango-rodeo does not exist in data data
# entidad_municipio durango-cuencame does not exist in data data
# entidad_municipio durango-santa clara does not exist in data data
# entidad_municipio durango-san juan de guadalupe does not exist in data data
# entidad_municipio durango-general simon bolivar does not exist in data data
# entidad_municipio guanajuato-guanajuato does not exist in data data
# entidad_municipio guanajuato-silao does not exist in data data
# entidad_municipio guanajuato-romita does not exist in data data
# entidad_municipio guanajuato-san francisco del rincon does not exist in data data
# entidad_municipio guanajuato-purisima del rincon does not exist in data data
# entidad_municipio guanajuato-manuel doblado does not exist in data data
# entidad_municipio guanajuato-irapuato does not exist in data data
# entidad_municipio guanajuato-salamanca does not exist in data data
# entidad_municipio guanajuato-pueblo nuevo does not exist in data data
# entidad_municipio guanajuato-penjamo does not exist in data data
# entidad_municipio guanajuato-cueramaro does not exist in data data
# entidad_municipio guanajuato-abasolo does not exist in data data
# entidad_municipio guanajuato-huanimaro does not exist in data data
# entidad_municipio guanajuato-leon does not exist in data data
# entidad_municipio guanajuato-san felipe does not exist in data data
# entidad_municipio guanajuato-ocampo does not exist in data data
# entidad_municipio guanajuato-san miguel de allende does not exist in data data
# entidad_municipio guanajuato-dolores hidalgo cuna de la independencia nacional does not exist in data data
# entidad_municipio guanajuato-san diego de la union does not exist in data data
# entidad_municipio guanajuato-san luis de la paz does not exist in data data
# entidad_municipio guanajuato-victoria does not exist in data data
# entidad_municipio guanajuato-xichu does not exist in data data
# entidad_municipio guanajuato-atarjea does not exist in data data
# entidad_municipio guanajuato-santa catarina does not exist in data data
# entidad_municipio guanajuato-doctor mora does not exist in data data
# entidad_municipio guanajuato-tierra blanca does not exist in data data
# entidad_municipio guanajuato-san jose iturbide does not exist in data data
# entidad_municipio guanajuato-celaya does not exist in data data
# entidad_municipio guanajuato-apaseo el grande does not exist in data data
# entidad_municipio guanajuato-comonfort does not exist in data data
# entidad_municipio guanajuato-santa cruz de juventino rosas does not exist in data data
# entidad_municipio guanajuato-villagran does not exist in data data
# entidad_municipio guanajuato-cortazar does not exist in data data
# entidad_municipio guanajuato-valle de santiago does not exist in data data
# entidad_municipio guanajuato-jaral del progreso does not exist in data data
# entidad_municipio guanajuato-apaseo el alto does not exist in data data
# entidad_municipio guanajuato-jerecuaro does not exist in data data
# entidad_municipio guanajuato-coroneo does not exist in data data
# entidad_municipio guanajuato-acambaro does not exist in data data
# entidad_municipio guanajuato-tarimoro does not exist in data data
# entidad_municipio guanajuato-tarandacuao does not exist in data data
# entidad_municipio guanajuato-moroleon does not exist in data data
# entidad_municipio guanajuato-salvatierra does not exist in data data
# entidad_municipio guanajuato-yuriria does not exist in data data
# entidad_municipio guanajuato-santiago maravatio does not exist in data data
# entidad_municipio guanajuato-uriangato does not exist in data data
# entidad_municipio guerrero-chilpancingo de los bravo does not exist in data data
# entidad_municipio guerrero-general heliodoro castillo does not exist in data data
# entidad_municipio guerrero-leonardo bravo does not exist in data data
# entidad_municipio guerrero-tixtla de guerrero does not exist in data data
# entidad_municipio guerrero-ayutla de los libres does not exist in data data
# entidad_municipio guerrero-mochitlan does not exist in data data
# entidad_municipio guerrero-quechultenango does not exist in data data
# entidad_municipio guerrero-tecoanapa does not exist in data data
# entidad_municipio guerrero-acapulco de juarez does not exist in data data
# entidad_municipio guerrero-juan r. escudero does not exist in data data
# entidad_municipio guerrero-san marcos does not exist in data data
# entidad_municipio guerrero-iguala de la independencia does not exist in data data
# entidad_municipio guerrero-huitzuco de los figueroa does not exist in data data
# entidad_municipio guerrero-tepecoacuilco de trujano does not exist in data data
# entidad_municipio guerrero-eduardo neri does not exist in data data
# entidad_municipio guerrero-taxco de alarcon does not exist in data data
# entidad_municipio guerrero-buenavista de cuellar does not exist in data data
# entidad_municipio guerrero-tetipac does not exist in data data
# entidad_municipio guerrero-pilcaya does not exist in data data
# entidad_municipio guerrero-teloloapan does not exist in data data
# entidad_municipio guerrero-ixcateopan de cuauhtemoc does not exist in data data
# entidad_municipio guerrero-pedro ascencio alquisiras does not exist in data data
# entidad_municipio guerrero-general canuto a. neri does not exist in data data
# entidad_municipio guerrero-arcelia does not exist in data data
# entidad_municipio guerrero-apaxtla does not exist in data data
# entidad_municipio guerrero-cuetzala del progreso does not exist in data data
# entidad_municipio guerrero-cocula does not exist in data data
# entidad_municipio guerrero-tlapehuala does not exist in data data
# entidad_municipio guerrero-cutzamala de pinzon does not exist in data data
# entidad_municipio guerrero-pungarabato does not exist in data data
# entidad_municipio guerrero-tlalchapa does not exist in data data
# entidad_municipio guerrero-coyuca de catalan does not exist in data data
# entidad_municipio guerrero-ajuchitlan del progreso does not exist in data data
# entidad_municipio guerrero-zirandaro does not exist in data data
# entidad_municipio guerrero-san miguel totolapan does not exist in data data
# entidad_municipio guerrero-la union de isidoro montes de oca does not exist in data data
# entidad_municipio guerrero-petatlan does not exist in data data
# entidad_municipio guerrero-coahuayutla de jose maria izazaga does not exist in data data
# entidad_municipio guerrero-zihuatanejo de azueta does not exist in data data
# entidad_municipio guerrero-tecpan de galeana does not exist in data data
# entidad_municipio guerrero-atoyac de alvarez does not exist in data data
# entidad_municipio guerrero-benito juarez does not exist in data data
# entidad_municipio guerrero-coyuca de benitez does not exist in data data
# entidad_municipio guerrero-olinala does not exist in data data
# entidad_municipio guerrero-atenango del rio does not exist in data data
# entidad_municipio guerrero-copalillo does not exist in data data
# entidad_municipio guerrero-cualac does not exist in data data
# entidad_municipio guerrero-chilapa de alvarez does not exist in data data
# entidad_municipio guerrero-jose joaquin de herrera does not exist in data data
# entidad_municipio guerrero-ahuacuotzingo does not exist in data data
# entidad_municipio guerrero-zitlala does not exist in data data
# entidad_municipio guerrero-martir de cuilapan does not exist in data data
# entidad_municipio guerrero-huamuxtitlan does not exist in data data
# entidad_municipio guerrero-xochihuehuetlan does not exist in data data
# entidad_municipio guerrero-alpoyeca does not exist in data data
# entidad_municipio guerrero-tlapa de comonfort does not exist in data data
# entidad_municipio guerrero-tlalixtaquilla de maldonado does not exist in data data
# entidad_municipio guerrero-xalpatlahuac does not exist in data data
# entidad_municipio guerrero-zapotitlan tablas does not exist in data data
# entidad_municipio guerrero-acatepec does not exist in data data
# entidad_municipio guerrero-atlixtac does not exist in data data
# entidad_municipio guerrero-copanatoyac does not exist in data data
# entidad_municipio guerrero-malinaltepec does not exist in data data
# entidad_municipio guerrero-iliatenco does not exist in data data
# entidad_municipio guerrero-tlacoapa does not exist in data data
# entidad_municipio guerrero-atlamajalcingo del monte does not exist in data data
# entidad_municipio guerrero-san luis acatlan does not exist in data data
# entidad_municipio guerrero-metlatonoc does not exist in data data
# entidad_municipio guerrero-cochoapa el grande does not exist in data data
# entidad_municipio guerrero-alcozauca de guerrero does not exist in data data
# entidad_municipio guerrero-ometepec does not exist in data data
# entidad_municipio guerrero-tlacoachistlahuaca does not exist in data data
# entidad_municipio guerrero-xochistlahuaca does not exist in data data
# entidad_municipio guerrero-florencio villarreal does not exist in data data
# entidad_municipio guerrero-cuautepec does not exist in data data
# entidad_municipio guerrero-copala does not exist in data data
# entidad_municipio guerrero-azoyu does not exist in data data
# entidad_municipio guerrero-juchitan does not exist in data data
# entidad_municipio guerrero-marquelia does not exist in data data
# entidad_municipio guerrero-cuajinicuilapa does not exist in data data
# entidad_municipio guerrero-igualapa does not exist in data data
# entidad_municipio hidalgo-pachuca de soto does not exist in data data
# entidad_municipio hidalgo-mineral del chico does not exist in data data
# entidad_municipio hidalgo-mineral del monte does not exist in data data
# entidad_municipio hidalgo-ajacuba does not exist in data data
# entidad_municipio hidalgo-san agustin tlaxiaca does not exist in data data
# entidad_municipio hidalgo-mineral de la reforma does not exist in data data
# entidad_municipio hidalgo-zapotlan de juarez does not exist in data data
# entidad_municipio hidalgo-jacala de ledezma does not exist in data data
# entidad_municipio hidalgo-pisaflores does not exist in data data
# entidad_municipio hidalgo-pacula does not exist in data data
# entidad_municipio hidalgo-la mision does not exist in data data
# entidad_municipio hidalgo-chapulhuacan does not exist in data data
# entidad_municipio hidalgo-ixmiquilpan does not exist in data data
# entidad_municipio hidalgo-zimapan does not exist in data data
# entidad_municipio hidalgo-nicolas flores does not exist in data data
# entidad_municipio hidalgo-cardonal does not exist in data data
# entidad_municipio hidalgo-tasquillo does not exist in data data
# entidad_municipio hidalgo-alfajayucan does not exist in data data
# entidad_municipio hidalgo-huichapan does not exist in data data
# entidad_municipio hidalgo-tecozautla does not exist in data data
# entidad_municipio hidalgo-nopala de villagran does not exist in data data
# entidad_municipio hidalgo-actopan does not exist in data data
# entidad_municipio hidalgo-santiago de anaya does not exist in data data
# entidad_municipio hidalgo-san salvador does not exist in data data
# entidad_municipio hidalgo-francisco i. madero does not exist in data data
# entidad_municipio hidalgo-el arenal does not exist in data data
# entidad_municipio hidalgo-mixquiahuala de juarez does not exist in data data
# entidad_municipio hidalgo-progreso de obregon does not exist in data data
# entidad_municipio hidalgo-chilcuautla does not exist in data data
# entidad_municipio hidalgo-tezontepec de aldama does not exist in data data
# entidad_municipio hidalgo-tlahuelilpan does not exist in data data
# entidad_municipio hidalgo-tula de allende does not exist in data data
# entidad_municipio hidalgo-tepeji del rio de ocampo does not exist in data data
# entidad_municipio hidalgo-chapantongo does not exist in data data
# entidad_municipio hidalgo-tepetitlan does not exist in data data
# entidad_municipio hidalgo-tetepango does not exist in data data
# entidad_municipio hidalgo-tlaxcoapan does not exist in data data
# entidad_municipio hidalgo-atitalaquia does not exist in data data
# entidad_municipio hidalgo-atotonilco de tula does not exist in data data
# entidad_municipio hidalgo-huejutla de reyes does not exist in data data
# entidad_municipio hidalgo-san felipe orizatlan does not exist in data data
# entidad_municipio hidalgo-jaltocan does not exist in data data
# entidad_municipio hidalgo-huautla does not exist in data data
# entidad_municipio hidalgo-atlapexco does not exist in data data
# entidad_municipio hidalgo-huazalingo does not exist in data data
# entidad_municipio hidalgo-yahualica does not exist in data data
# entidad_municipio hidalgo-xochiatipan does not exist in data data
# entidad_municipio hidalgo-molango de escamilla does not exist in data data
# entidad_municipio hidalgo-tepehuacan de guerrero does not exist in data data
# entidad_municipio hidalgo-lolotla does not exist in data data
# entidad_municipio hidalgo-tlanchinol does not exist in data data
# entidad_municipio hidalgo-tlahuiltepa does not exist in data data
# entidad_municipio hidalgo-juarez hidalgo does not exist in data data
# entidad_municipio hidalgo-zacualtipan de angeles does not exist in data data
# entidad_municipio hidalgo-calnali does not exist in data data
# entidad_municipio hidalgo-xochicoatlan does not exist in data data
# entidad_municipio hidalgo-tianguistengo does not exist in data data
# entidad_municipio hidalgo-atotonilco el grande does not exist in data data
# entidad_municipio hidalgo-eloxochitlan does not exist in data data
# entidad_municipio hidalgo-metztitlan does not exist in data data
# entidad_municipio hidalgo-san agustin metzquititlan does not exist in data data
# entidad_municipio hidalgo-metepec does not exist in data data
# entidad_municipio hidalgo-huehuetla does not exist in data data
# entidad_municipio hidalgo-san bartolo tutotepec does not exist in data data
# entidad_municipio hidalgo-agua blanca de iturbide does not exist in data data
# entidad_municipio hidalgo-tenango de doria does not exist in data data
# entidad_municipio hidalgo-huasca de ocampo does not exist in data data
# entidad_municipio hidalgo-acatlan does not exist in data data
# entidad_municipio hidalgo-omitlan de juarez does not exist in data data
# entidad_municipio hidalgo-epazoyucan does not exist in data data
# entidad_municipio hidalgo-tulancingo de bravo does not exist in data data
# entidad_municipio hidalgo-acaxochitlan does not exist in data data
# entidad_municipio hidalgo-cuautepec de hinojosa does not exist in data data
# entidad_municipio hidalgo-santiago tulantepec de lugo guerrero does not exist in data data
# entidad_municipio hidalgo-singuilucan does not exist in data data
# entidad_municipio hidalgo-tizayuca does not exist in data data
# entidad_municipio hidalgo-zempoala does not exist in data data
# entidad_municipio hidalgo-tolcayuca does not exist in data data
# entidad_municipio hidalgo-villa de tezontepec does not exist in data data
# entidad_municipio hidalgo-apan does not exist in data data
# entidad_municipio hidalgo-tlanalapa does not exist in data data
# entidad_municipio hidalgo-almoloya does not exist in data data
# entidad_municipio hidalgo-emiliano zapata does not exist in data data
# entidad_municipio hidalgo-tepeapulco does not exist in data data
# entidad_municipio jalisco-guadalajara does not exist in data data
# entidad_municipio jalisco-zapopan does not exist in data data
# entidad_municipio jalisco-san cristobal de la barranca does not exist in data data
# entidad_municipio jalisco-ixtlahuacan del rio does not exist in data data
# entidad_municipio jalisco-tala does not exist in data data
# entidad_municipio jalisco-el arenal does not exist in data data
# entidad_municipio jalisco-amatitan does not exist in data data
# entidad_municipio jalisco-tonala does not exist in data data
# entidad_municipio jalisco-zapotlanejo does not exist in data data
# entidad_municipio jalisco-acatic does not exist in data data
# entidad_municipio jalisco-cuquio does not exist in data data
# entidad_municipio jalisco-tlaquepaque does not exist in data data
# entidad_municipio jalisco-tlajomulco de zuñiga does not exist in data data
# entidad_municipio jalisco-el salto does not exist in data data
# entidad_municipio jalisco-acatlan de juarez does not exist in data data
# entidad_municipio jalisco-villa corona does not exist in data data
# entidad_municipio jalisco-zacoalco de torres does not exist in data data
# entidad_municipio jalisco-atemajac de brizuela does not exist in data data
# entidad_municipio jalisco-jocotepec does not exist in data data
# entidad_municipio jalisco-ixtlahuacan de los membrillos does not exist in data data
# entidad_municipio jalisco-juanacatlan does not exist in data data
# entidad_municipio jalisco-chapala does not exist in data data
# entidad_municipio jalisco-poncitlan does not exist in data data
# entidad_municipio jalisco-zapotlan del rey does not exist in data data
# entidad_municipio jalisco-huejuquilla el alto does not exist in data data
# entidad_municipio jalisco-mezquitic does not exist in data data
# entidad_municipio jalisco-villa guerrero does not exist in data data
# entidad_municipio jalisco-bolaños does not exist in data data
# entidad_municipio jalisco-totatiche does not exist in data data
# entidad_municipio jalisco-colotlan does not exist in data data
# entidad_municipio jalisco-santa maria de los angeles does not exist in data data
# entidad_municipio jalisco-huejucar does not exist in data data
# entidad_municipio jalisco-chimaltitan does not exist in data data
# entidad_municipio jalisco-san martin de bolaños does not exist in data data
# entidad_municipio jalisco-tequila does not exist in data data
# entidad_municipio jalisco-hostotipaquillo does not exist in data data
# entidad_municipio jalisco-magdalena does not exist in data data
# entidad_municipio jalisco-etzatlan does not exist in data data
# entidad_municipio jalisco-san marcos does not exist in data data
# entidad_municipio jalisco-san juanito de escobedo does not exist in data data
# entidad_municipio jalisco-ameca does not exist in data data
# entidad_municipio jalisco-ahualulco de mercado does not exist in data data
# entidad_municipio jalisco-teuchitlan does not exist in data data
# entidad_municipio jalisco-san martin hidalgo does not exist in data data
# entidad_municipio jalisco-guachinango does not exist in data data
# entidad_municipio jalisco-mixtlan does not exist in data data
# entidad_municipio jalisco-mascota does not exist in data data
# entidad_municipio jalisco-san sebastian del oeste does not exist in data data
# entidad_municipio jalisco-san juan de los lagos does not exist in data data
# entidad_municipio jalisco-jalostotitlan does not exist in data data
# entidad_municipio jalisco-san miguel el alto does not exist in data data
# entidad_municipio jalisco-san julian does not exist in data data
# entidad_municipio jalisco-arandas does not exist in data data
# entidad_municipio jalisco-san ignacio cerro gordo does not exist in data data
# entidad_municipio jalisco-teocaltiche does not exist in data data
# entidad_municipio jalisco-villa hidalgo does not exist in data data
# entidad_municipio jalisco-encarnacion de diaz does not exist in data data
# entidad_municipio jalisco-yahualica de gonzalez gallo does not exist in data data
# entidad_municipio jalisco-mexticacan does not exist in data data
# entidad_municipio jalisco-cañadas de obregon does not exist in data data
# entidad_municipio jalisco-valle de guadalupe does not exist in data data
# entidad_municipio jalisco-lagos de moreno does not exist in data data
# entidad_municipio jalisco-ojuelos de jalisco does not exist in data data
# entidad_municipio jalisco-union de san antonio does not exist in data data
# entidad_municipio jalisco-san diego de alejandria does not exist in data data
# entidad_municipio jalisco-tepatitlan de morelos does not exist in data data
# entidad_municipio jalisco-tototlan does not exist in data data
# entidad_municipio jalisco-atotonilco el alto does not exist in data data
# entidad_municipio jalisco-ocotlan does not exist in data data
# entidad_municipio jalisco-jamay does not exist in data data
# entidad_municipio jalisco-la barca does not exist in data data
# entidad_municipio jalisco-ayotlan does not exist in data data
# entidad_municipio jalisco-jesus maria does not exist in data data
# entidad_municipio jalisco-degollado does not exist in data data
# entidad_municipio jalisco-union de tula does not exist in data data
# entidad_municipio jalisco-ayutla does not exist in data data
# entidad_municipio jalisco-atenguillo does not exist in data data
# entidad_municipio jalisco-cuautla does not exist in data data
# entidad_municipio jalisco-atengo does not exist in data data
# entidad_municipio jalisco-talpa de allende does not exist in data data
# entidad_municipio jalisco-puerto vallarta does not exist in data data
# entidad_municipio jalisco-cabo corrientes does not exist in data data
# entidad_municipio jalisco-tomatlan does not exist in data data
# entidad_municipio jalisco-cocula does not exist in data data
# entidad_municipio jalisco-tecolotlan does not exist in data data
# entidad_municipio jalisco-tenamaxtlan does not exist in data data
# entidad_municipio jalisco-juchitlan does not exist in data data
# entidad_municipio jalisco-chiquilistlan does not exist in data data
# entidad_municipio jalisco-ejutla does not exist in data data
# entidad_municipio jalisco-el limon does not exist in data data
# entidad_municipio jalisco-el grullo does not exist in data data
# entidad_municipio jalisco-tonaya does not exist in data data
# entidad_municipio jalisco-tuxcacuesco does not exist in data data
# entidad_municipio jalisco-villa purificacion does not exist in data data
# entidad_municipio jalisco-la huerta does not exist in data data
# entidad_municipio jalisco-autlan de navarro does not exist in data data
# entidad_municipio jalisco-casimiro castillo does not exist in data data
# entidad_municipio jalisco-cuautitlan de garcia barragan does not exist in data data
# entidad_municipio jalisco-cihuatlan does not exist in data data
# entidad_municipio jalisco-zapotlan el grande does not exist in data data
# entidad_municipio jalisco-gomez farias does not exist in data data
# entidad_municipio jalisco-concepcion de buenos aires does not exist in data data
# entidad_municipio jalisco-atoyac does not exist in data data
# entidad_municipio jalisco-techaluta de montenegro does not exist in data data
# entidad_municipio jalisco-teocuitatlan de corona does not exist in data data
# entidad_municipio jalisco-sayula does not exist in data data
# entidad_municipio jalisco-tapalpa does not exist in data data
# entidad_municipio jalisco-amacueca does not exist in data data
# entidad_municipio jalisco-tizapan el alto does not exist in data data
# entidad_municipio jalisco-tuxcueca does not exist in data data
# entidad_municipio jalisco-la manzanilla de la paz does not exist in data data
# entidad_municipio jalisco-mazamitla does not exist in data data
# entidad_municipio jalisco-valle de juarez does not exist in data data
# entidad_municipio jalisco-quitupan does not exist in data data
# entidad_municipio jalisco-zapotiltic does not exist in data data
# entidad_municipio jalisco-tamazula de gordiano does not exist in data data
# entidad_municipio jalisco-san gabriel does not exist in data data
# entidad_municipio jalisco-toliman does not exist in data data
# entidad_municipio jalisco-zapotitlan de vadillo does not exist in data data
# entidad_municipio jalisco-tuxpan does not exist in data data
# entidad_municipio jalisco-tonila does not exist in data data
# entidad_municipio jalisco-pihuamo does not exist in data data
# entidad_municipio jalisco-tecalitlan does not exist in data data
# entidad_municipio jalisco-jilotlan de los dolores does not exist in data data
# entidad_municipio jalisco-santa maria del oro does not exist in data data
# entidad_municipio mexico-toluca does not exist in data data
# entidad_municipio mexico-acambay does not exist in data data
# entidad_municipio mexico-aculco does not exist in data data
# entidad_municipio mexico-temascalcingo does not exist in data data
# entidad_municipio mexico-atlacomulco does not exist in data data
# entidad_municipio mexico-timilpan does not exist in data data
# entidad_municipio mexico-morelos does not exist in data data
# entidad_municipio mexico-el oro does not exist in data data
# entidad_municipio mexico-san felipe del progreso does not exist in data data
# entidad_municipio mexico-san jose del rincon does not exist in data data
# entidad_municipio mexico-jocotitlan does not exist in data data
# entidad_municipio mexico-ixtlahuaca does not exist in data data
# entidad_municipio mexico-jiquipilco does not exist in data data
# entidad_municipio mexico-temoaya does not exist in data data
# entidad_municipio mexico-almoloya de juarez does not exist in data data
# entidad_municipio mexico-villa victoria does not exist in data data
# entidad_municipio mexico-villa de allende does not exist in data data
# entidad_municipio mexico-donato guerra does not exist in data data
# entidad_municipio mexico-ixtapan del oro does not exist in data data
# entidad_municipio mexico-santo tomas does not exist in data data
# entidad_municipio mexico-otzoloapan does not exist in data data
# entidad_municipio mexico-zacazonapan does not exist in data data
# entidad_municipio mexico-valle de bravo does not exist in data data
# entidad_municipio mexico-amanalco does not exist in data data
# entidad_municipio mexico-temascaltepec does not exist in data data
# entidad_municipio mexico-zinacantepec does not exist in data data
# entidad_municipio mexico-tejupilco does not exist in data data
# entidad_municipio mexico-luvianos does not exist in data data
# entidad_municipio mexico-san simon de guerrero does not exist in data data
# entidad_municipio mexico-amatepec does not exist in data data
# entidad_municipio mexico-tlatlaya does not exist in data data
# entidad_municipio mexico-sultepec does not exist in data data
# entidad_municipio mexico-texcaltitlan does not exist in data data
# entidad_municipio mexico-coatepec harinas does not exist in data data
# entidad_municipio mexico-villa guerrero does not exist in data data
# entidad_municipio mexico-zacualpan does not exist in data data
# entidad_municipio mexico-almoloya de alquisiras does not exist in data data
# entidad_municipio mexico-ixtapan de la sal does not exist in data data
# entidad_municipio mexico-tonatico does not exist in data data
# entidad_municipio mexico-zumpahuacan does not exist in data data
# entidad_municipio mexico-lerma does not exist in data data
# entidad_municipio mexico-xonacatlan does not exist in data data
# entidad_municipio mexico-otzolotepec does not exist in data data
# ...
# entidad_municipio veracruz de ignacio de la llave-ixhuatlan del cafe does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tepatlaxco does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-comapa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-zentla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-camaron de tejeda does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-soledad de doblado does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-manlio fabio altamirano does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-jamapa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-medellin does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-boca del rio does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-orizaba does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-rafael delgado does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-mariano escobedo does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-ixhuatlancillo does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-atzacan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-ixtaczoquitlan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-fortin does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cordoba does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-maltrata does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-nogales does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-rio blanco does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-camerino z. mendoza does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-aquila does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-acultzingo does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-soledad atzompa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-huiloapan de cuauhtemoc does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tlaquilpa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-astacinga does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-xoxocotla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-atlahuilco does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tequila does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-san andres tenejapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tlilapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-magdalena does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-naranjal does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-coetzala does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-omealca does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cuitlahuac does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cuichapa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-yanga does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-amatlan de los reyes does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-atoyac does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-paso del macho does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-carrillo puerto does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cotaxtla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-zongolica does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tehuipango does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-mixtla de altamirano does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-los reyes does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-texhuacan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tezonapa does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tierra blanca does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tlalixcoyan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-ignacio de la llave does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-alvarado does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-lerdo de tejada does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tres valles does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-carlos a. carrillo does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cosamaloapan de carpio does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-ixmatlahuacan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-acula does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-amatitlan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tlacotalpan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-saltabarranca does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-otatitlan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tlacojalpan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tuxtilla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-chacaltianguis does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-jose azueta does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-playa vicente does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-santiago sochiapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-isla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-juan rodriguez clara does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-san andres tuxtla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-santiago tuxtla does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-angel r. cabada does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-hueyapan de ocampo does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-catemaco does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-soteapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-mecayapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-tatahuicapan de juarez does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-pajapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-chinameca does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-acayucan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-san juan evangelista does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-sayula de aleman does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-oluta does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-soconusco does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-texistepec does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-jaltipan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-zaragoza does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-oteapan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-cosoleacaque does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-nanchital de lazaro cardenas del rio does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-ixhuatlan del sureste does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-moloacan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-coatzacoalcos does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-agua dulce does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-minatitlan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-hidalgotitlan does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-jesus carranza does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-las choapas does not exist in data data
# entidad_municipio veracruz de ignacio de la llave-uxpanapa does not exist in data data
# entidad_municipio yucatan-merida does not exist in data data
# entidad_municipio yucatan-progreso does not exist in data data
# entidad_municipio yucatan-chicxulub pueblo does not exist in data data
# entidad_municipio yucatan-ixil does not exist in data data
# entidad_municipio yucatan-conkal does not exist in data data
# entidad_municipio yucatan-yaxkukul does not exist in data data
# entidad_municipio yucatan-hunucma does not exist in data data
# entidad_municipio yucatan-ucu does not exist in data data
# entidad_municipio yucatan-kinchil does not exist in data data
# entidad_municipio yucatan-tetiz does not exist in data data
# entidad_municipio yucatan-celestun does not exist in data data
# entidad_municipio yucatan-kanasin does not exist in data data
# entidad_municipio yucatan-timucuy does not exist in data data
# entidad_municipio yucatan-acanceh does not exist in data data
# entidad_municipio yucatan-tixpehual does not exist in data data
# entidad_municipio yucatan-uman does not exist in data data
# entidad_municipio yucatan-telchac pueblo does not exist in data data
# entidad_municipio yucatan-dzemul does not exist in data data
# entidad_municipio yucatan-telchac puerto does not exist in data data
# entidad_municipio yucatan-cansahcab does not exist in data data
# entidad_municipio yucatan-sinanche does not exist in data data
# entidad_municipio yucatan-yobain does not exist in data data
# entidad_municipio yucatan-motul does not exist in data data
# entidad_municipio yucatan-baca does not exist in data data
# entidad_municipio yucatan-mococha does not exist in data data
# entidad_municipio yucatan-muxupip does not exist in data data
# entidad_municipio yucatan-cacalchen does not exist in data data
# entidad_municipio yucatan-bokoba does not exist in data data
# entidad_municipio yucatan-tixkokob does not exist in data data
# entidad_municipio yucatan-hoctun does not exist in data data
# entidad_municipio yucatan-tahmek does not exist in data data
# entidad_municipio yucatan-dzidzantun does not exist in data data
# entidad_municipio yucatan-temax does not exist in data data
# entidad_municipio yucatan-tekanto does not exist in data data
# entidad_municipio yucatan-teya does not exist in data data
# entidad_municipio yucatan-suma does not exist in data data
# entidad_municipio yucatan-tepakan does not exist in data data
# entidad_municipio yucatan-tekal de venegas does not exist in data data
# entidad_municipio yucatan-izamal does not exist in data data
# entidad_municipio yucatan-hocaba does not exist in data data
# entidad_municipio yucatan-xocchel does not exist in data data
# entidad_municipio yucatan-seye does not exist in data data
# entidad_municipio yucatan-cuzama does not exist in data data
# entidad_municipio yucatan-homun does not exist in data data
# entidad_municipio yucatan-sanahcat does not exist in data data
# entidad_municipio yucatan-huhi does not exist in data data
# entidad_municipio yucatan-dzilam gonzalez does not exist in data data
# entidad_municipio yucatan-dzilam de bravo does not exist in data data
# entidad_municipio yucatan-panaba does not exist in data data
# entidad_municipio yucatan-san felipe does not exist in data data
# entidad_municipio yucatan-buctzotz does not exist in data data
# entidad_municipio yucatan-sucila does not exist in data data
# entidad_municipio yucatan-cenotillo does not exist in data data
# entidad_municipio yucatan-dzoncauich does not exist in data data
# entidad_municipio yucatan-tunkas does not exist in data data
# entidad_municipio yucatan-quintana roo does not exist in data data
# entidad_municipio yucatan-dzitas does not exist in data data
# entidad_municipio yucatan-kantunil does not exist in data data
# entidad_municipio yucatan-sudzal does not exist in data data
# entidad_municipio yucatan-tekit does not exist in data data
# entidad_municipio yucatan-sotuta does not exist in data data
# entidad_municipio yucatan-tizimin does not exist in data data
# entidad_municipio yucatan-rio lagartos does not exist in data data
# entidad_municipio yucatan-espita does not exist in data data
# entidad_municipio yucatan-temozon does not exist in data data
# entidad_municipio yucatan-calotmul does not exist in data data
# entidad_municipio yucatan-tinum does not exist in data data
# entidad_municipio yucatan-chankom does not exist in data data
# entidad_municipio yucatan-chichimila does not exist in data data
# entidad_municipio yucatan-tixcacalcupul does not exist in data data
# entidad_municipio yucatan-kaua does not exist in data data
# entidad_municipio yucatan-cuncunul does not exist in data data
# entidad_municipio yucatan-tekom does not exist in data data
# entidad_municipio yucatan-chemax does not exist in data data
# entidad_municipio yucatan-valladolid does not exist in data data
# entidad_municipio yucatan-uayma does not exist in data data
# entidad_municipio yucatan-maxcanu does not exist in data data
# entidad_municipio yucatan-samahil does not exist in data data
# entidad_municipio yucatan-opichen does not exist in data data
# entidad_municipio yucatan-chochola does not exist in data data
# entidad_municipio yucatan-kopoma does not exist in data data
# entidad_municipio yucatan-tecoh does not exist in data data
# entidad_municipio yucatan-abala does not exist in data data
# entidad_municipio yucatan-halacho does not exist in data data
# entidad_municipio yucatan-muna does not exist in data data
# entidad_municipio yucatan-sacalum does not exist in data data
# entidad_municipio yucatan-mani does not exist in data data
# entidad_municipio yucatan-dzan does not exist in data data
# entidad_municipio yucatan-chapab does not exist in data data
# entidad_municipio yucatan-ticul does not exist in data data
# entidad_municipio yucatan-oxkutzcab does not exist in data data
# entidad_municipio yucatan-santa elena does not exist in data data
# entidad_municipio yucatan-mama does not exist in data data
# entidad_municipio yucatan-chumayel does not exist in data data
# entidad_municipio yucatan-mayapan does not exist in data data
# entidad_municipio yucatan-teabo does not exist in data data
# entidad_municipio yucatan-cantamayec does not exist in data data
# entidad_municipio yucatan-yaxcaba does not exist in data data
# entidad_municipio yucatan-peto does not exist in data data
# entidad_municipio yucatan-chikindzonot does not exist in data data
# entidad_municipio yucatan-tahdziu does not exist in data data
# entidad_municipio yucatan-tixmehuac does not exist in data data
# entidad_municipio yucatan-chacsinkin does not exist in data data
# entidad_municipio yucatan-tzucacab does not exist in data data
# entidad_municipio yucatan-tekax does not exist in data data
# entidad_municipio yucatan-akil does not exist in data data
# No missing values
# Ready to merge crimes and data

# %%
data[data['entidad_municipio'].str.contains('oaxaca-zapotitlan')]
# Out:
# Empty DataFrame
# Columns: [id_municipio, entidad, municipio, carpetas, total, crimes_10k, class, entidad_municipio]
# Index: []

# %%
locations[locations['entidad_municipio'].str.contains('oaxaca-zapotitlan')]
# Out:
#        código postal                      asentamiento       tipo  \
# 91154          69060                 Zapotitlan Palmas  Rancheria
# 91176          69120                Zapotitlan Lagunas     Pueblo
# 91177          69123                  Cerro los Cuates  Rancheria
# 91178          69123                        El Naranjo  Rancheria
# 91179          69123                 Barrio San Isidro     Barrio
# 91180          69123                   El Palmon Largo  Rancheria
# 91181          69123                        La Soledad  Rancheria
# 91182          69123            San Pedro Cuaxoxocatla  Rancheria
# 91183          69123                San Miguel Hidalgo  Rancheria
# 91184          69123            Guadalupe Buenos Aires  Rancheria
# 91185          69124          Santa Cruz Vista Hermosa  Rancheria
# 91186          69126                 Falda del Tepeyac  Rancheria
# 91187          69126              Guadalupe del Recreo     Pueblo
# 91188          69126             Paraje la Cruz Blanca  Rancheria
# 91189          69126             San Jose el Huamuchil  Rancheria
# 91190          69127                Tlacotepec Lagunas  Rancheria
# 91191          69127  Santa Cruz Soledad (Las Casitas)  Rancheria
#
#                 municipio ciudad entidad    municipio_strip  \
# 91154   Zapotitlan Palmas    NaN  Oaxaca   ZapotitlanPalmas
# 91176  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91177  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91178  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91179  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91180  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91181  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91182  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91183  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91184  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91185  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91186  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91187  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91188  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91189  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91190  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91191  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
#
#                entidad_municipio
# 91154   oaxaca-zapotitlan palmas
# 91176  oaxaca-zapotitlan lagunas
# 91177  oaxaca-zapotitlan lagunas
# 91178  oaxaca-zapotitlan lagunas
# 91179  oaxaca-zapotitlan lagunas
# 91180  oaxaca-zapotitlan lagunas
# 91181  oaxaca-zapotitlan lagunas
# 91182  oaxaca-zapotitlan lagunas
# 91183  oaxaca-zapotitlan lagunas
# 91184  oaxaca-zapotitlan lagunas
# 91185  oaxaca-zapotitlan lagunas
# 91186  oaxaca-zapotitlan lagunas
# 91187  oaxaca-zapotitlan lagunas
# 91188  oaxaca-zapotitlan lagunas
# 91189  oaxaca-zapotitlan lagunas
# 91190  oaxaca-zapotitlan lagunas
# 91191  oaxaca-zapotitlan lagunas

# %%
# Merging
colonias = pd.merge(locations, data, how='left', on='entidad_municipio')
# CLeaning columns
colonias.drop(columns=['entidad_y', 'municipio_y'], inplace=True)
colonias.rename(columns={'entidad_x': 'entidad', 'municipio_x': 'municipio'}, inplace=True)
colonias.head()
# Out:
#    código postal                                       asentamiento  \
# 0           1000                                          San Angel
# 1           1010                                          Los Alpes
# 2           1020                                      Guadalupe Inn
# 3           1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4           1029                                          INFONAVIT
#
#            tipo       municipio            ciudad           entidad  \
# 0       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3  Gran usuario  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4  Gran usuario  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
#
#   municipio_strip                entidad_municipio  id_municipio  carpetas  \
# 0   AlvaroObregon  ciudad de mexico-alvaro obregon           NaN       NaN
# 1   AlvaroObregon  ciudad de mexico-alvaro obregon           NaN       NaN
# 2   AlvaroObregon  ciudad de mexico-alvaro obregon           NaN       NaN
# 3   AlvaroObregon  ciudad de mexico-alvaro obregon           NaN       NaN
# 4   AlvaroObregon  ciudad de mexico-alvaro obregon           NaN       NaN
#
#    total  crimes_10k  class
# 0    NaN         NaN    NaN
# 1    NaN         NaN    NaN
# 2    NaN         NaN    NaN
# 3    NaN         NaN    NaN
# 4    NaN         NaN    NaN

# %% [markdown]
# Adding coordenates for every zip code

# %%
# Importing data
coordenates_cp = pd.read_csv('data/coordenates_colonias.csv', usecols=[0,3,6,8,9])
# Cleaning columns
coordenates_cp.columns = ['id_entidad', 'id_municipio', 'localidad', 'lat', 'lon']
coordenates_cp.columns = [x.lower().strip() for x in coordenates_cp.columns]
# Generating id_municipio full
coordenates_cp['id_municipio'] = coordenates_cp['id_entidad']*1000 + coordenates_cp['id_municipio']
coordenates_cp
# Out:
#         id_entidad  id_municipio               localidad        lat  \
# 0                1          1001          Aguascalientes  21.879823
# 1                1          1001          Granja Adelita  21.871875
# 2                1          1001               Agua Azul  21.883756
# 3                1          1001           Rancho Alegre  21.854599
# 4                1          1001  Los Arbolitos [Rancho]  21.780181
# ...            ...           ...                     ...        ...
# 304216          32         32058              San Isidro  21.486425
# 304217          32         32058                San José  21.516539
# 304218          32         32058   San Miguel Tepetitlán  21.504213
# 304219          32         32058              San Rafael  21.527595
# 304220          32         32058                Santa Fe  21.528992
#
#                lon
# 0      -102.296047
# 1      -102.373531
# 2      -102.357122
# 3      -102.372746
# 4      -102.357295
# ...            ...
# 304216 -103.337268
# 304217 -103.456568
# 304218 -103.335932
# 304219 -103.372259
# 304220 -103.385095
#
# [304221 rows x 5 columns]

# %%
# Creating list of unique ids in each coordenates_cpset
unique_mun_colonias = colonias['id_municipio'].unique()
unique_mun_coordenates_cp = coordenates_cp['id_municipio'].unique()

# Len of the lists
len_mun_colonias = len(colonias['id_municipio'].unique())
len_mun_coordenates_cp = len(coordenates_cp['id_municipio'].unique())

for i in unique_mun_coordenates_cp:
    if i not in unique_mun_colonias:
        print('id_municipio {} does not exist in colonias coordenates_cp'.format(i))

for i in unique_mun_colonias:
    if i not in unique_mun_coordenates_cp:
        print('id_municipio {} does not exist in coordenates_cp coordenates_cp'.format(i))


if len_mun_colonias == len_mun_coordenates_cp:
    print('Equal lenghts')
# Out:
# id_municipio 1001 does not exist in colonias coordenates_cp
# id_municipio 1002 does not exist in colonias coordenates_cp
# id_municipio 1003 does not exist in colonias coordenates_cp
# id_municipio 1004 does not exist in colonias coordenates_cp
# id_municipio 1005 does not exist in colonias coordenates_cp
# id_municipio 1006 does not exist in colonias coordenates_cp
# id_municipio 1007 does not exist in colonias coordenates_cp
# id_municipio 1008 does not exist in colonias coordenates_cp
# id_municipio 1009 does not exist in colonias coordenates_cp
# id_municipio 1010 does not exist in colonias coordenates_cp
# id_municipio 1011 does not exist in colonias coordenates_cp
# id_municipio 2001 does not exist in colonias coordenates_cp
# id_municipio 2002 does not exist in colonias coordenates_cp
# id_municipio 2003 does not exist in colonias coordenates_cp
# id_municipio 2004 does not exist in colonias coordenates_cp
# id_municipio 2005 does not exist in colonias coordenates_cp
# id_municipio 3001 does not exist in colonias coordenates_cp
# id_municipio 3002 does not exist in colonias coordenates_cp
# id_municipio 3003 does not exist in colonias coordenates_cp
# id_municipio 3008 does not exist in colonias coordenates_cp
# id_municipio 3009 does not exist in colonias coordenates_cp
# id_municipio 4001 does not exist in colonias coordenates_cp
# id_municipio 4002 does not exist in colonias coordenates_cp
# id_municipio 4003 does not exist in colonias coordenates_cp
# id_municipio 4004 does not exist in colonias coordenates_cp
# id_municipio 4005 does not exist in colonias coordenates_cp
# id_municipio 4006 does not exist in colonias coordenates_cp
# id_municipio 4007 does not exist in colonias coordenates_cp
# id_municipio 4008 does not exist in colonias coordenates_cp
# id_municipio 4009 does not exist in colonias coordenates_cp
# id_municipio 4010 does not exist in colonias coordenates_cp
# id_municipio 4011 does not exist in colonias coordenates_cp
# id_municipio 5001 does not exist in colonias coordenates_cp
# id_municipio 5002 does not exist in colonias coordenates_cp
# id_municipio 5003 does not exist in colonias coordenates_cp
# id_municipio 5004 does not exist in colonias coordenates_cp
# id_municipio 5005 does not exist in colonias coordenates_cp
# id_municipio 5006 does not exist in colonias coordenates_cp
# id_municipio 5007 does not exist in colonias coordenates_cp
# id_municipio 5008 does not exist in colonias coordenates_cp
# id_municipio 5009 does not exist in colonias coordenates_cp
# id_municipio 5010 does not exist in colonias coordenates_cp
# id_municipio 5011 does not exist in colonias coordenates_cp
# id_municipio 5012 does not exist in colonias coordenates_cp
# id_municipio 5013 does not exist in colonias coordenates_cp
# id_municipio 5014 does not exist in colonias coordenates_cp
# id_municipio 5015 does not exist in colonias coordenates_cp
# id_municipio 5016 does not exist in colonias coordenates_cp
# id_municipio 5017 does not exist in colonias coordenates_cp
# id_municipio 5018 does not exist in colonias coordenates_cp
# id_municipio 5019 does not exist in colonias coordenates_cp
# id_municipio 5020 does not exist in colonias coordenates_cp
# id_municipio 5021 does not exist in colonias coordenates_cp
# id_municipio 5022 does not exist in colonias coordenates_cp
# id_municipio 5023 does not exist in colonias coordenates_cp
# id_municipio 5024 does not exist in colonias coordenates_cp
# id_municipio 5025 does not exist in colonias coordenates_cp
# id_municipio 5026 does not exist in colonias coordenates_cp
# id_municipio 5027 does not exist in colonias coordenates_cp
# id_municipio 5028 does not exist in colonias coordenates_cp
# id_municipio 5029 does not exist in colonias coordenates_cp
# id_municipio 5030 does not exist in colonias coordenates_cp
# id_municipio 5031 does not exist in colonias coordenates_cp
# id_municipio 5032 does not exist in colonias coordenates_cp
# id_municipio 5033 does not exist in colonias coordenates_cp
# id_municipio 5034 does not exist in colonias coordenates_cp
# id_municipio 5035 does not exist in colonias coordenates_cp
# id_municipio 5036 does not exist in colonias coordenates_cp
# id_municipio 5037 does not exist in colonias coordenates_cp
# id_municipio 5038 does not exist in colonias coordenates_cp
# id_municipio 6001 does not exist in colonias coordenates_cp
# id_municipio 6002 does not exist in colonias coordenates_cp
# id_municipio 6003 does not exist in colonias coordenates_cp
# id_municipio 6004 does not exist in colonias coordenates_cp
# id_municipio 6005 does not exist in colonias coordenates_cp
# id_municipio 6006 does not exist in colonias coordenates_cp
# id_municipio 6007 does not exist in colonias coordenates_cp
# id_municipio 6008 does not exist in colonias coordenates_cp
# id_municipio 6009 does not exist in colonias coordenates_cp
# id_municipio 6010 does not exist in colonias coordenates_cp
# id_municipio 7001 does not exist in colonias coordenates_cp
# id_municipio 7002 does not exist in colonias coordenates_cp
# id_municipio 7003 does not exist in colonias coordenates_cp
# id_municipio 7004 does not exist in colonias coordenates_cp
# id_municipio 7005 does not exist in colonias coordenates_cp
# id_municipio 7006 does not exist in colonias coordenates_cp
# id_municipio 7007 does not exist in colonias coordenates_cp
# id_municipio 7008 does not exist in colonias coordenates_cp
# id_municipio 7009 does not exist in colonias coordenates_cp
# id_municipio 7010 does not exist in colonias coordenates_cp
# id_municipio 7011 does not exist in colonias coordenates_cp
# id_municipio 7012 does not exist in colonias coordenates_cp
# id_municipio 7013 does not exist in colonias coordenates_cp
# id_municipio 7014 does not exist in colonias coordenates_cp
# id_municipio 7015 does not exist in colonias coordenates_cp
# id_municipio 7016 does not exist in colonias coordenates_cp
# id_municipio 7017 does not exist in colonias coordenates_cp
# id_municipio 7018 does not exist in colonias coordenates_cp
# id_municipio 7019 does not exist in colonias coordenates_cp
# id_municipio 7020 does not exist in colonias coordenates_cp
# id_municipio 7021 does not exist in colonias coordenates_cp
# id_municipio 7022 does not exist in colonias coordenates_cp
# id_municipio 7023 does not exist in colonias coordenates_cp
# id_municipio 7024 does not exist in colonias coordenates_cp
# id_municipio 7025 does not exist in colonias coordenates_cp
# id_municipio 7026 does not exist in colonias coordenates_cp
# id_municipio 7027 does not exist in colonias coordenates_cp
# id_municipio 7028 does not exist in colonias coordenates_cp
# id_municipio 7029 does not exist in colonias coordenates_cp
# id_municipio 7030 does not exist in colonias coordenates_cp
# id_municipio 7031 does not exist in colonias coordenates_cp
# id_municipio 7032 does not exist in colonias coordenates_cp
# id_municipio 7033 does not exist in colonias coordenates_cp
# id_municipio 7034 does not exist in colonias coordenates_cp
# id_municipio 7035 does not exist in colonias coordenates_cp
# id_municipio 7036 does not exist in colonias coordenates_cp
# id_municipio 7037 does not exist in colonias coordenates_cp
# id_municipio 7038 does not exist in colonias coordenates_cp
# id_municipio 7039 does not exist in colonias coordenates_cp
# id_municipio 7040 does not exist in colonias coordenates_cp
# id_municipio 7041 does not exist in colonias coordenates_cp
# id_municipio 7042 does not exist in colonias coordenates_cp
# id_municipio 7043 does not exist in colonias coordenates_cp
# id_municipio 7044 does not exist in colonias coordenates_cp
# id_municipio 7045 does not exist in colonias coordenates_cp
# id_municipio 7046 does not exist in colonias coordenates_cp
# id_municipio 7047 does not exist in colonias coordenates_cp
# id_municipio 7048 does not exist in colonias coordenates_cp
# id_municipio 7049 does not exist in colonias coordenates_cp
# id_municipio 7050 does not exist in colonias coordenates_cp
# id_municipio 7051 does not exist in colonias coordenates_cp
# id_municipio 7052 does not exist in colonias coordenates_cp
# id_municipio 7053 does not exist in colonias coordenates_cp
# id_municipio 7054 does not exist in colonias coordenates_cp
# id_municipio 7055 does not exist in colonias coordenates_cp
# id_municipio 7056 does not exist in colonias coordenates_cp
# id_municipio 7057 does not exist in colonias coordenates_cp
# id_municipio 7058 does not exist in colonias coordenates_cp
# id_municipio 7059 does not exist in colonias coordenates_cp
# id_municipio 7060 does not exist in colonias coordenates_cp
# id_municipio 7061 does not exist in colonias coordenates_cp
# id_municipio 7062 does not exist in colonias coordenates_cp
# id_municipio 7063 does not exist in colonias coordenates_cp
# id_municipio 7064 does not exist in colonias coordenates_cp
# id_municipio 7065 does not exist in colonias coordenates_cp
# id_municipio 7066 does not exist in colonias coordenates_cp
# id_municipio 7067 does not exist in colonias coordenates_cp
# id_municipio 7068 does not exist in colonias coordenates_cp
# id_municipio 7069 does not exist in colonias coordenates_cp
# id_municipio 7070 does not exist in colonias coordenates_cp
# id_municipio 7071 does not exist in colonias coordenates_cp
# id_municipio 7072 does not exist in colonias coordenates_cp
# id_municipio 7073 does not exist in colonias coordenates_cp
# id_municipio 7074 does not exist in colonias coordenates_cp
# id_municipio 7075 does not exist in colonias coordenates_cp
# id_municipio 7076 does not exist in colonias coordenates_cp
# id_municipio 7077 does not exist in colonias coordenates_cp
# id_municipio 7078 does not exist in colonias coordenates_cp
# id_municipio 7079 does not exist in colonias coordenates_cp
# id_municipio 7080 does not exist in colonias coordenates_cp
# id_municipio 7081 does not exist in colonias coordenates_cp
# id_municipio 7082 does not exist in colonias coordenates_cp
# id_municipio 7083 does not exist in colonias coordenates_cp
# id_municipio 7084 does not exist in colonias coordenates_cp
# id_municipio 7085 does not exist in colonias coordenates_cp
# id_municipio 7086 does not exist in colonias coordenates_cp
# id_municipio 7087 does not exist in colonias coordenates_cp
# id_municipio 7088 does not exist in colonias coordenates_cp
# id_municipio 7089 does not exist in colonias coordenates_cp
# id_municipio 7090 does not exist in colonias coordenates_cp
# id_municipio 7091 does not exist in colonias coordenates_cp
# id_municipio 7092 does not exist in colonias coordenates_cp
# id_municipio 7093 does not exist in colonias coordenates_cp
# id_municipio 7094 does not exist in colonias coordenates_cp
# id_municipio 7096 does not exist in colonias coordenates_cp
# id_municipio 7097 does not exist in colonias coordenates_cp
# id_municipio 7098 does not exist in colonias coordenates_cp
# id_municipio 7099 does not exist in colonias coordenates_cp
# id_municipio 7100 does not exist in colonias coordenates_cp
# id_municipio 7101 does not exist in colonias coordenates_cp
# id_municipio 7102 does not exist in colonias coordenates_cp
# id_municipio 7103 does not exist in colonias coordenates_cp
# id_municipio 7104 does not exist in colonias coordenates_cp
# id_municipio 7105 does not exist in colonias coordenates_cp
# id_municipio 7106 does not exist in colonias coordenates_cp
# id_municipio 7107 does not exist in colonias coordenates_cp
# id_municipio 7108 does not exist in colonias coordenates_cp
# id_municipio 7109 does not exist in colonias coordenates_cp
# id_municipio 7110 does not exist in colonias coordenates_cp
# id_municipio 7111 does not exist in colonias coordenates_cp
# id_municipio 7112 does not exist in colonias coordenates_cp
# id_municipio 7113 does not exist in colonias coordenates_cp
# id_municipio 7114 does not exist in colonias coordenates_cp
# id_municipio 7115 does not exist in colonias coordenates_cp
# id_municipio 7116 does not exist in colonias coordenates_cp
# id_municipio 7117 does not exist in colonias coordenates_cp
# id_municipio 7118 does not exist in colonias coordenates_cp
# id_municipio 7119 does not exist in colonias coordenates_cp
# id_municipio 7120 does not exist in colonias coordenates_cp
# id_municipio 7121 does not exist in colonias coordenates_cp
# id_municipio 7122 does not exist in colonias coordenates_cp
# id_municipio 7123 does not exist in colonias coordenates_cp
# id_municipio 7124 does not exist in colonias coordenates_cp
# id_municipio 8001 does not exist in colonias coordenates_cp
# id_municipio 8002 does not exist in colonias coordenates_cp
# id_municipio 8003 does not exist in colonias coordenates_cp
# id_municipio 8004 does not exist in colonias coordenates_cp
# id_municipio 8005 does not exist in colonias coordenates_cp
# id_municipio 8006 does not exist in colonias coordenates_cp
# id_municipio 8007 does not exist in colonias coordenates_cp
# id_municipio 8008 does not exist in colonias coordenates_cp
# id_municipio 8009 does not exist in colonias coordenates_cp
# id_municipio 8010 does not exist in colonias coordenates_cp
# id_municipio 8011 does not exist in colonias coordenates_cp
# id_municipio 8012 does not exist in colonias coordenates_cp
# id_municipio 8013 does not exist in colonias coordenates_cp
# id_municipio 8014 does not exist in colonias coordenates_cp
# id_municipio 8015 does not exist in colonias coordenates_cp
# id_municipio 8016 does not exist in colonias coordenates_cp
# id_municipio 8017 does not exist in colonias coordenates_cp
# id_municipio 8018 does not exist in colonias coordenates_cp
# id_municipio 8019 does not exist in colonias coordenates_cp
# id_municipio 8020 does not exist in colonias coordenates_cp
# id_municipio 8021 does not exist in colonias coordenates_cp
# id_municipio 8022 does not exist in colonias coordenates_cp
# id_municipio 8023 does not exist in colonias coordenates_cp
# id_municipio 8024 does not exist in colonias coordenates_cp
# id_municipio 8025 does not exist in colonias coordenates_cp
# id_municipio 8026 does not exist in colonias coordenates_cp
# id_municipio 8027 does not exist in colonias coordenates_cp
# id_municipio 8028 does not exist in colonias coordenates_cp
# id_municipio 8029 does not exist in colonias coordenates_cp
# id_municipio 8030 does not exist in colonias coordenates_cp
# id_municipio 8031 does not exist in colonias coordenates_cp
# id_municipio 8032 does not exist in colonias coordenates_cp
# id_municipio 8033 does not exist in colonias coordenates_cp
# id_municipio 8034 does not exist in colonias coordenates_cp
# id_municipio 8035 does not exist in colonias coordenates_cp
# id_municipio 8036 does not exist in colonias coordenates_cp
# id_municipio 8037 does not exist in colonias coordenates_cp
# id_municipio 8038 does not exist in colonias coordenates_cp
# id_municipio 8039 does not exist in colonias coordenates_cp
# id_municipio 8040 does not exist in colonias coordenates_cp
# id_municipio 8041 does not exist in colonias coordenates_cp
# id_municipio 8042 does not exist in colonias coordenates_cp
# id_municipio 8043 does not exist in colonias coordenates_cp
# id_municipio 8044 does not exist in colonias coordenates_cp
# id_municipio 8045 does not exist in colonias coordenates_cp
# id_municipio 8046 does not exist in colonias coordenates_cp
# id_municipio 8047 does not exist in colonias coordenates_cp
# id_municipio 8048 does not exist in colonias coordenates_cp
# id_municipio 8049 does not exist in colonias coordenates_cp
# id_municipio 8050 does not exist in colonias coordenates_cp
# id_municipio 8051 does not exist in colonias coordenates_cp
# id_municipio 8052 does not exist in colonias coordenates_cp
# id_municipio 8053 does not exist in colonias coordenates_cp
# id_municipio 8054 does not exist in colonias coordenates_cp
# id_municipio 8055 does not exist in colonias coordenates_cp
# id_municipio 8056 does not exist in colonias coordenates_cp
# id_municipio 8057 does not exist in colonias coordenates_cp
# id_municipio 8058 does not exist in colonias coordenates_cp
# id_municipio 8059 does not exist in colonias coordenates_cp
# id_municipio 8060 does not exist in colonias coordenates_cp
# id_municipio 8061 does not exist in colonias coordenates_cp
# id_municipio 8062 does not exist in colonias coordenates_cp
# id_municipio 8063 does not exist in colonias coordenates_cp
# id_municipio 8064 does not exist in colonias coordenates_cp
# id_municipio 8065 does not exist in colonias coordenates_cp
# id_municipio 8066 does not exist in colonias coordenates_cp
# id_municipio 8067 does not exist in colonias coordenates_cp
# id_municipio 9002 does not exist in colonias coordenates_cp
# id_municipio 9003 does not exist in colonias coordenates_cp
# id_municipio 9004 does not exist in colonias coordenates_cp
# id_municipio 9005 does not exist in colonias coordenates_cp
# id_municipio 9006 does not exist in colonias coordenates_cp
# id_municipio 9007 does not exist in colonias coordenates_cp
# id_municipio 9008 does not exist in colonias coordenates_cp
# id_municipio 9009 does not exist in colonias coordenates_cp
# id_municipio 9010 does not exist in colonias coordenates_cp
# id_municipio 9011 does not exist in colonias coordenates_cp
# id_municipio 9012 does not exist in colonias coordenates_cp
# id_municipio 9013 does not exist in colonias coordenates_cp
# id_municipio 9014 does not exist in colonias coordenates_cp
# id_municipio 9015 does not exist in colonias coordenates_cp
# id_municipio 9016 does not exist in colonias coordenates_cp
# id_municipio 9017 does not exist in colonias coordenates_cp
# id_municipio 10001 does not exist in colonias coordenates_cp
# id_municipio 10002 does not exist in colonias coordenates_cp
# id_municipio 10003 does not exist in colonias coordenates_cp
# id_municipio 10004 does not exist in colonias coordenates_cp
# id_municipio 10005 does not exist in colonias coordenates_cp
# id_municipio 10006 does not exist in colonias coordenates_cp
# id_municipio 10007 does not exist in colonias coordenates_cp
# id_municipio 10008 does not exist in colonias coordenates_cp
# id_municipio 10009 does not exist in colonias coordenates_cp
# id_municipio 10010 does not exist in colonias coordenates_cp
# id_municipio 10011 does not exist in colonias coordenates_cp
# id_municipio 10012 does not exist in colonias coordenates_cp
# id_municipio 10013 does not exist in colonias coordenates_cp
# id_municipio 10014 does not exist in colonias coordenates_cp
# id_municipio 10015 does not exist in colonias coordenates_cp
# id_municipio 10016 does not exist in colonias coordenates_cp
# id_municipio 10017 does not exist in colonias coordenates_cp
# id_municipio 10018 does not exist in colonias coordenates_cp
# id_municipio 10019 does not exist in colonias coordenates_cp
# id_municipio 10020 does not exist in colonias coordenates_cp
# id_municipio 10021 does not exist in colonias coordenates_cp
# id_municipio 10022 does not exist in colonias coordenates_cp
# id_municipio 10023 does not exist in colonias coordenates_cp
# id_municipio 10024 does not exist in colonias coordenates_cp
# id_municipio 10025 does not exist in colonias coordenates_cp
# id_municipio 10026 does not exist in colonias coordenates_cp
# id_municipio 10027 does not exist in colonias coordenates_cp
# id_municipio 10028 does not exist in colonias coordenates_cp
# id_municipio 10029 does not exist in colonias coordenates_cp
# id_municipio 10030 does not exist in colonias coordenates_cp
# id_municipio 10031 does not exist in colonias coordenates_cp
# id_municipio 10032 does not exist in colonias coordenates_cp
# id_municipio 10033 does not exist in colonias coordenates_cp
# id_municipio 10034 does not exist in colonias coordenates_cp
# id_municipio 10035 does not exist in colonias coordenates_cp
# id_municipio 10036 does not exist in colonias coordenates_cp
# id_municipio 10037 does not exist in colonias coordenates_cp
# id_municipio 10038 does not exist in colonias coordenates_cp
# id_municipio 10039 does not exist in colonias coordenates_cp
# id_municipio 11001 does not exist in colonias coordenates_cp
# id_municipio 11002 does not exist in colonias coordenates_cp
# id_municipio 11003 does not exist in colonias coordenates_cp
# id_municipio 11004 does not exist in colonias coordenates_cp
# id_municipio 11005 does not exist in colonias coordenates_cp
# id_municipio 11006 does not exist in colonias coordenates_cp
# id_municipio 11007 does not exist in colonias coordenates_cp
# id_municipio 11008 does not exist in colonias coordenates_cp
# id_municipio 11009 does not exist in colonias coordenates_cp
# id_municipio 11010 does not exist in colonias coordenates_cp
# id_municipio 11011 does not exist in colonias coordenates_cp
# id_municipio 11012 does not exist in colonias coordenates_cp
# id_municipio 11013 does not exist in colonias coordenates_cp
# id_municipio 11014 does not exist in colonias coordenates_cp
# id_municipio 11015 does not exist in colonias coordenates_cp
# id_municipio 11016 does not exist in colonias coordenates_cp
# id_municipio 11017 does not exist in colonias coordenates_cp
# id_municipio 11018 does not exist in colonias coordenates_cp
# id_municipio 11019 does not exist in colonias coordenates_cp
# id_municipio 11020 does not exist in colonias coordenates_cp
# id_municipio 11021 does not exist in colonias coordenates_cp
# id_municipio 11022 does not exist in colonias coordenates_cp
# id_municipio 11023 does not exist in colonias coordenates_cp
# id_municipio 11024 does not exist in colonias coordenates_cp
# id_municipio 11025 does not exist in colonias coordenates_cp
# id_municipio 11026 does not exist in colonias coordenates_cp
# id_municipio 11027 does not exist in colonias coordenates_cp
# id_municipio 11028 does not exist in colonias coordenates_cp
# id_municipio 11029 does not exist in colonias coordenates_cp
# id_municipio 11030 does not exist in colonias coordenates_cp
# id_municipio 11031 does not exist in colonias coordenates_cp
# id_municipio 11032 does not exist in colonias coordenates_cp
# id_municipio 11033 does not exist in colonias coordenates_cp
# id_municipio 11034 does not exist in colonias coordenates_cp
# id_municipio 11035 does not exist in colonias coordenates_cp
# id_municipio 11036 does not exist in colonias coordenates_cp
# id_municipio 11037 does not exist in colonias coordenates_cp
# id_municipio 11038 does not exist in colonias coordenates_cp
# id_municipio 11039 does not exist in colonias coordenates_cp
# id_municipio 11040 does not exist in colonias coordenates_cp
# id_municipio 11041 does not exist in colonias coordenates_cp
# id_municipio 11042 does not exist in colonias coordenates_cp
# id_municipio 11043 does not exist in colonias coordenates_cp
# id_municipio 11044 does not exist in colonias coordenates_cp
# id_municipio 11045 does not exist in colonias coordenates_cp
# id_municipio 11046 does not exist in colonias coordenates_cp
# id_municipio 12001 does not exist in colonias coordenates_cp
# id_municipio 12002 does not exist in colonias coordenates_cp
# id_municipio 12003 does not exist in colonias coordenates_cp
# id_municipio 12004 does not exist in colonias coordenates_cp
# id_municipio 12005 does not exist in colonias coordenates_cp
# id_municipio 12006 does not exist in colonias coordenates_cp
# id_municipio 12007 does not exist in colonias coordenates_cp
# id_municipio 12008 does not exist in colonias coordenates_cp
# id_municipio 12009 does not exist in colonias coordenates_cp
# id_municipio 12010 does not exist in colonias coordenates_cp
# id_municipio 12011 does not exist in colonias coordenates_cp
# id_municipio 12012 does not exist in colonias coordenates_cp
# id_municipio 12013 does not exist in colonias coordenates_cp
# id_municipio 12014 does not exist in colonias coordenates_cp
# id_municipio 12015 does not exist in colonias coordenates_cp
# id_municipio 12016 does not exist in colonias coordenates_cp
# id_municipio 12017 does not exist in colonias coordenates_cp
# id_municipio 12018 does not exist in colonias coordenates_cp
# id_municipio 12019 does not exist in colonias coordenates_cp
# id_municipio 12020 does not exist in colonias coordenates_cp
# id_municipio 12021 does not exist in colonias coordenates_cp
# id_municipio 12022 does not exist in colonias coordenates_cp
# id_municipio 12023 does not exist in colonias coordenates_cp
# id_municipio 12024 does not exist in colonias coordenates_cp
# id_municipio 12025 does not exist in colonias coordenates_cp
# id_municipio 12026 does not exist in colonias coordenates_cp
# id_municipio 12027 does not exist in colonias coordenates_cp
# id_municipio 12028 does not exist in colonias coordenates_cp
# id_municipio 12029 does not exist in colonias coordenates_cp
# id_municipio 12030 does not exist in colonias coordenates_cp
# id_municipio 12031 does not exist in colonias coordenates_cp
# id_municipio 12032 does not exist in colonias coordenates_cp
# id_municipio 12033 does not exist in colonias coordenates_cp
# id_municipio 12034 does not exist in colonias coordenates_cp
# id_municipio 12035 does not exist in colonias coordenates_cp
# id_municipio 12036 does not exist in colonias coordenates_cp
# id_municipio 12037 does not exist in colonias coordenates_cp
# id_municipio 12038 does not exist in colonias coordenates_cp
# id_municipio 12039 does not exist in colonias coordenates_cp
# id_municipio 12040 does not exist in colonias coordenates_cp
# id_municipio 12041 does not exist in colonias coordenates_cp
# id_municipio 12042 does not exist in colonias coordenates_cp
# id_municipio 12043 does not exist in colonias coordenates_cp
# id_municipio 12044 does not exist in colonias coordenates_cp
# id_municipio 12045 does not exist in colonias coordenates_cp
# id_municipio 12046 does not exist in colonias coordenates_cp
# id_municipio 12047 does not exist in colonias coordenates_cp
# id_municipio 12048 does not exist in colonias coordenates_cp
# id_municipio 12049 does not exist in colonias coordenates_cp
# id_municipio 12050 does not exist in colonias coordenates_cp
# id_municipio 12051 does not exist in colonias coordenates_cp
# id_municipio 12052 does not exist in colonias coordenates_cp
# id_municipio 12053 does not exist in colonias coordenates_cp
# id_municipio 12054 does not exist in colonias coordenates_cp
# id_municipio 12055 does not exist in colonias coordenates_cp
# id_municipio 12056 does not exist in colonias coordenates_cp
# id_municipio 12057 does not exist in colonias coordenates_cp
# id_municipio 12058 does not exist in colonias coordenates_cp
# id_municipio 12059 does not exist in colonias coordenates_cp
# id_municipio 12060 does not exist in colonias coordenates_cp
# id_municipio 12061 does not exist in colonias coordenates_cp
# id_municipio 12062 does not exist in colonias coordenates_cp
# id_municipio 12063 does not exist in colonias coordenates_cp
# id_municipio 12064 does not exist in colonias coordenates_cp
# id_municipio 12065 does not exist in colonias coordenates_cp
# id_municipio 12066 does not exist in colonias coordenates_cp
# id_municipio 12067 does not exist in colonias coordenates_cp
# id_municipio 12068 does not exist in colonias coordenates_cp
# id_municipio 12069 does not exist in colonias coordenates_cp
# id_municipio 12070 does not exist in colonias coordenates_cp
# id_municipio 12071 does not exist in colonias coordenates_cp
# id_municipio 12072 does not exist in colonias coordenates_cp
# id_municipio 12073 does not exist in colonias coordenates_cp
# id_municipio 12074 does not exist in colonias coordenates_cp
# id_municipio 12075 does not exist in colonias coordenates_cp
# id_municipio 12076 does not exist in colonias coordenates_cp
# id_municipio 12077 does not exist in colonias coordenates_cp
# id_municipio 12078 does not exist in colonias coordenates_cp
# id_municipio 12079 does not exist in colonias coordenates_cp
# id_municipio 12080 does not exist in colonias coordenates_cp
# id_municipio 12081 does not exist in colonias coordenates_cp
# id_municipio 13001 does not exist in colonias coordenates_cp
# id_municipio 13002 does not exist in colonias coordenates_cp
# id_municipio 13003 does not exist in colonias coordenates_cp
# id_municipio 13004 does not exist in colonias coordenates_cp
# id_municipio 13005 does not exist in colonias coordenates_cp
# id_municipio 13006 does not exist in colonias coordenates_cp
# id_municipio 13007 does not exist in colonias coordenates_cp
# id_municipio 13008 does not exist in colonias coordenates_cp
# id_municipio 13009 does not exist in colonias coordenates_cp
# id_municipio 13010 does not exist in colonias coordenates_cp
# id_municipio 13011 does not exist in colonias coordenates_cp
# id_municipio 13012 does not exist in colonias coordenates_cp
# id_municipio 13013 does not exist in colonias coordenates_cp
# id_municipio 13014 does not exist in colonias coordenates_cp
# id_municipio 13015 does not exist in colonias coordenates_cp
# id_municipio 13016 does not exist in colonias coordenates_cp
# id_municipio 13017 does not exist in colonias coordenates_cp
# id_municipio 13018 does not exist in colonias coordenates_cp
# id_municipio 13019 does not exist in colonias coordenates_cp
# id_municipio 13020 does not exist in colonias coordenates_cp
# id_municipio 13021 does not exist in colonias coordenates_cp
# id_municipio 13022 does not exist in colonias coordenates_cp
# id_municipio 13023 does not exist in colonias coordenates_cp
# id_municipio 13024 does not exist in colonias coordenates_cp
# id_municipio 13025 does not exist in colonias coordenates_cp
# id_municipio 13026 does not exist in colonias coordenates_cp
# id_municipio 13027 does not exist in colonias coordenates_cp
# id_municipio 13028 does not exist in colonias coordenates_cp
# id_municipio 13029 does not exist in colonias coordenates_cp
# id_municipio 13030 does not exist in colonias coordenates_cp
# id_municipio 13031 does not exist in colonias coordenates_cp
# id_municipio 13032 does not exist in colonias coordenates_cp
# id_municipio 13033 does not exist in colonias coordenates_cp
# id_municipio 13034 does not exist in colonias coordenates_cp
# id_municipio 13035 does not exist in colonias coordenates_cp
# id_municipio 13036 does not exist in colonias coordenates_cp
# id_municipio 13037 does not exist in colonias coordenates_cp
# id_municipio 13038 does not exist in colonias coordenates_cp
# id_municipio 13039 does not exist in colonias coordenates_cp
# id_municipio 13040 does not exist in colonias coordenates_cp
# id_municipio 13041 does not exist in colonias coordenates_cp
# id_municipio 13042 does not exist in colonias coordenates_cp
# id_municipio 13043 does not exist in colonias coordenates_cp
# id_municipio 13044 does not exist in colonias coordenates_cp
# id_municipio 13045 does not exist in colonias coordenates_cp
# id_municipio 13046 does not exist in colonias coordenates_cp
# id_municipio 13047 does not exist in colonias coordenates_cp
# id_municipio 13048 does not exist in colonias coordenates_cp
# id_municipio 13049 does not exist in colonias coordenates_cp
# id_municipio 13050 does not exist in colonias coordenates_cp
# id_municipio 13051 does not exist in colonias coordenates_cp
# id_municipio 13052 does not exist in colonias coordenates_cp
# id_municipio 13053 does not exist in colonias coordenates_cp
# id_municipio 13054 does not exist in colonias coordenates_cp
# id_municipio 13055 does not exist in colonias coordenates_cp
# id_municipio 13056 does not exist in colonias coordenates_cp
# id_municipio 13057 does not exist in colonias coordenates_cp
# id_municipio 13058 does not exist in colonias coordenates_cp
# id_municipio 13059 does not exist in colonias coordenates_cp
# id_municipio 13060 does not exist in colonias coordenates_cp
# id_municipio 13061 does not exist in colonias coordenates_cp
# id_municipio 13062 does not exist in colonias coordenates_cp
# id_municipio 13063 does not exist in colonias coordenates_cp
# id_municipio 13064 does not exist in colonias coordenates_cp
# id_municipio 13065 does not exist in colonias coordenates_cp
# id_municipio 13066 does not exist in colonias coordenates_cp
# id_municipio 13067 does not exist in colonias coordenates_cp
# id_municipio 13068 does not exist in colonias coordenates_cp
# id_municipio 13069 does not exist in colonias coordenates_cp
# id_municipio 13070 does not exist in colonias coordenates_cp
# id_municipio 13071 does not exist in colonias coordenates_cp
# id_municipio 13072 does not exist in colonias coordenates_cp
# id_municipio 13073 does not exist in colonias coordenates_cp
# id_municipio 13074 does not exist in colonias coordenates_cp
# id_municipio 13075 does not exist in colonias coordenates_cp
# id_municipio 13076 does not exist in colonias coordenates_cp
# id_municipio 13077 does not exist in colonias coordenates_cp
# id_municipio 13078 does not exist in colonias coordenates_cp
# id_municipio 13079 does not exist in colonias coordenates_cp
# id_municipio 13080 does not exist in colonias coordenates_cp
# id_municipio 13081 does not exist in colonias coordenates_cp
# id_municipio 13082 does not exist in colonias coordenates_cp
# id_municipio 13083 does not exist in colonias coordenates_cp
# id_municipio 13084 does not exist in colonias coordenates_cp
# id_municipio 14001 does not exist in colonias coordenates_cp
# id_municipio 14002 does not exist in colonias coordenates_cp
# id_municipio 14003 does not exist in colonias coordenates_cp
# id_municipio 14004 does not exist in colonias coordenates_cp
# id_municipio 14005 does not exist in colonias coordenates_cp
# id_municipio 14006 does not exist in colonias coordenates_cp
# id_municipio 14007 does not exist in colonias coordenates_cp
# id_municipio 14008 does not exist in colonias coordenates_cp
# id_municipio 14009 does not exist in colonias coordenates_cp
# id_municipio 14010 does not exist in colonias coordenates_cp
# id_municipio 14011 does not exist in colonias coordenates_cp
# id_municipio 14012 does not exist in colonias coordenates_cp
# id_municipio 14013 does not exist in colonias coordenates_cp
# id_municipio 14014 does not exist in colonias coordenates_cp
# id_municipio 14015 does not exist in colonias coordenates_cp
# id_municipio 14016 does not exist in colonias coordenates_cp
# id_municipio 14017 does not exist in colonias coordenates_cp
# id_municipio 14018 does not exist in colonias coordenates_cp
# id_municipio 14019 does not exist in colonias coordenates_cp
# id_municipio 14020 does not exist in colonias coordenates_cp
# id_municipio 14021 does not exist in colonias coordenates_cp
# id_municipio 14022 does not exist in colonias coordenates_cp
# id_municipio 14023 does not exist in colonias coordenates_cp
# id_municipio 14024 does not exist in colonias coordenates_cp
# id_municipio 14025 does not exist in colonias coordenates_cp
# id_municipio 14026 does not exist in colonias coordenates_cp
# id_municipio 14027 does not exist in colonias coordenates_cp
# id_municipio 14028 does not exist in colonias coordenates_cp
# id_municipio 14029 does not exist in colonias coordenates_cp
# id_municipio 14030 does not exist in colonias coordenates_cp
# id_municipio 14031 does not exist in colonias coordenates_cp
# id_municipio 14032 does not exist in colonias coordenates_cp
# id_municipio 14033 does not exist in colonias coordenates_cp
# id_municipio 14034 does not exist in colonias coordenates_cp
# id_municipio 14035 does not exist in colonias coordenates_cp
# id_municipio 14036 does not exist in colonias coordenates_cp
# id_municipio 14037 does not exist in colonias coordenates_cp
# id_municipio 14038 does not exist in colonias coordenates_cp
# id_municipio 14039 does not exist in colonias coordenates_cp
# id_municipio 14040 does not exist in colonias coordenates_cp
# id_municipio 14041 does not exist in colonias coordenates_cp
# id_municipio 14042 does not exist in colonias coordenates_cp
# id_municipio 14043 does not exist in colonias coordenates_cp
# id_municipio 14044 does not exist in colonias coordenates_cp
# id_municipio 14045 does not exist in colonias coordenates_cp
# id_municipio 14046 does not exist in colonias coordenates_cp
# id_municipio 14047 does not exist in colonias coordenates_cp
# id_municipio 14048 does not exist in colonias coordenates_cp
# id_municipio 14049 does not exist in colonias coordenates_cp
# id_municipio 14050 does not exist in colonias coordenates_cp
# id_municipio 14051 does not exist in colonias coordenates_cp
# id_municipio 14052 does not exist in colonias coordenates_cp
# id_municipio 14053 does not exist in colonias coordenates_cp
# id_municipio 14054 does not exist in colonias coordenates_cp
# id_municipio 14055 does not exist in colonias coordenates_cp
# id_municipio 14056 does not exist in colonias coordenates_cp
# id_municipio 14057 does not exist in colonias coordenates_cp
# id_municipio 14058 does not exist in colonias coordenates_cp
# id_municipio 14059 does not exist in colonias coordenates_cp
# id_municipio 14060 does not exist in colonias coordenates_cp
# id_municipio 14061 does not exist in colonias coordenates_cp
# id_municipio 14062 does not exist in colonias coordenates_cp
# id_municipio 14063 does not exist in colonias coordenates_cp
# id_municipio 14064 does not exist in colonias coordenates_cp
# id_municipio 14065 does not exist in colonias coordenates_cp
# id_municipio 14066 does not exist in colonias coordenates_cp
# id_municipio 14067 does not exist in colonias coordenates_cp
# id_municipio 14068 does not exist in colonias coordenates_cp
# id_municipio 14069 does not exist in colonias coordenates_cp
# id_municipio 14070 does not exist in colonias coordenates_cp
# id_municipio 14071 does not exist in colonias coordenates_cp
# id_municipio 14072 does not exist in colonias coordenates_cp
# id_municipio 14073 does not exist in colonias coordenates_cp
# id_municipio 14074 does not exist in colonias coordenates_cp
# id_municipio 14075 does not exist in colonias coordenates_cp
# id_municipio 14076 does not exist in colonias coordenates_cp
# id_municipio 14077 does not exist in colonias coordenates_cp
# id_municipio 14078 does not exist in colonias coordenates_cp
# id_municipio 14079 does not exist in colonias coordenates_cp
# id_municipio 14080 does not exist in colonias coordenates_cp
# id_municipio 14081 does not exist in colonias coordenates_cp
# id_municipio 14082 does not exist in colonias coordenates_cp
# id_municipio 14083 does not exist in colonias coordenates_cp
# id_municipio 14084 does not exist in colonias coordenates_cp
# id_municipio 14085 does not exist in colonias coordenates_cp
# id_municipio 14086 does not exist in colonias coordenates_cp
# id_municipio 14087 does not exist in colonias coordenates_cp
# id_municipio 14088 does not exist in colonias coordenates_cp
# id_municipio 14089 does not exist in colonias coordenates_cp
# id_municipio 14090 does not exist in colonias coordenates_cp
# id_municipio 14091 does not exist in colonias coordenates_cp
# id_municipio 14092 does not exist in colonias coordenates_cp
# id_municipio 14093 does not exist in colonias coordenates_cp
# id_municipio 14094 does not exist in colonias coordenates_cp
# id_municipio 14095 does not exist in colonias coordenates_cp
# id_municipio 14096 does not exist in colonias coordenates_cp
# id_municipio 14097 does not exist in colonias coordenates_cp
# id_municipio 14098 does not exist in colonias coordenates_cp
# id_municipio 14099 does not exist in colonias coordenates_cp
# id_municipio 14100 does not exist in colonias coordenates_cp
# id_municipio 14101 does not exist in colonias coordenates_cp
# id_municipio 14102 does not exist in colonias coordenates_cp
# id_municipio 14103 does not exist in colonias coordenates_cp
# id_municipio 14104 does not exist in colonias coordenates_cp
# id_municipio 14105 does not exist in colonias coordenates_cp
# id_municipio 14106 does not exist in colonias coordenates_cp
# id_municipio 14107 does not exist in colonias coordenates_cp
# id_municipio 14108 does not exist in colonias coordenates_cp
# id_municipio 14109 does not exist in colonias coordenates_cp
# id_municipio 14110 does not exist in colonias coordenates_cp
# id_municipio 14111 does not exist in colonias coordenates_cp
# id_municipio 14112 does not exist in colonias coordenates_cp
# id_municipio 14113 does not exist in colonias coordenates_cp
# id_municipio 14114 does not exist in colonias coordenates_cp
# id_municipio 14115 does not exist in colonias coordenates_cp
# id_municipio 14116 does not exist in colonias coordenates_cp
# id_municipio 14117 does not exist in colonias coordenates_cp
# id_municipio 14118 does not exist in colonias coordenates_cp
# id_municipio 14119 does not exist in colonias coordenates_cp
# id_municipio 14120 does not exist in colonias coordenates_cp
# id_municipio 14121 does not exist in colonias coordenates_cp
# id_municipio 14122 does not exist in colonias coordenates_cp
# id_municipio 14123 does not exist in colonias coordenates_cp
# id_municipio 14124 does not exist in colonias coordenates_cp
# id_municipio 14125 does not exist in colonias coordenates_cp
# id_municipio 15001 does not exist in colonias coordenates_cp
# id_municipio 15002 does not exist in colonias coordenates_cp
# id_municipio 15003 does not exist in colonias coordenates_cp
# id_municipio 15004 does not exist in colonias coordenates_cp
# id_municipio 15005 does not exist in colonias coordenates_cp
# id_municipio 15006 does not exist in colonias coordenates_cp
# id_municipio 15007 does not exist in colonias coordenates_cp
# id_municipio 15008 does not exist in colonias coordenates_cp
# id_municipio 15009 does not exist in colonias coordenates_cp
# id_municipio 15010 does not exist in colonias coordenates_cp
# id_municipio 15011 does not exist in colonias coordenates_cp
# id_municipio 15012 does not exist in colonias coordenates_cp
# id_municipio 15013 does not exist in colonias coordenates_cp
# id_municipio 15014 does not exist in colonias coordenates_cp
# id_municipio 15015 does not exist in colonias coordenates_cp
# id_municipio 15016 does not exist in colonias coordenates_cp
# id_municipio 15017 does not exist in colonias coordenates_cp
# id_municipio 15018 does not exist in colonias coordenates_cp
# id_municipio 15019 does not exist in colonias coordenates_cp
# id_municipio 15020 does not exist in colonias coordenates_cp
# id_municipio 15021 does not exist in colonias coordenates_cp
# id_municipio 15022 does not exist in colonias coordenates_cp
# id_municipio 15023 does not exist in colonias coordenates_cp
# id_municipio 15024 does not exist in colonias coordenates_cp
# id_municipio 15025 does not exist in colonias coordenates_cp
# id_municipio 15026 does not exist in colonias coordenates_cp
# id_municipio 15027 does not exist in colonias coordenates_cp
# id_municipio 15028 does not exist in colonias coordenates_cp
# id_municipio 15029 does not exist in colonias coordenates_cp
# id_municipio 15030 does not exist in colonias coordenates_cp
# id_municipio 15031 does not exist in colonias coordenates_cp
# id_municipio 15032 does not exist in colonias coordenates_cp
# id_municipio 15033 does not exist in colonias coordenates_cp
# id_municipio 15034 does not exist in colonias coordenates_cp
# id_municipio 15035 does not exist in colonias coordenates_cp
# id_municipio 15036 does not exist in colonias coordenates_cp
# id_municipio 15037 does not exist in colonias coordenates_cp
# id_municipio 15038 does not exist in colonias coordenates_cp
# id_municipio 15039 does not exist in colonias coordenates_cp
# id_municipio 15040 does not exist in colonias coordenates_cp
# id_municipio 15041 does not exist in colonias coordenates_cp
# id_municipio 15042 does not exist in colonias coordenates_cp
# id_municipio 15043 does not exist in colonias coordenates_cp
# id_municipio 15044 does not exist in colonias coordenates_cp
# id_municipio 15045 does not exist in colonias coordenates_cp
# id_municipio 15046 does not exist in colonias coordenates_cp
# id_municipio 15047 does not exist in colonias coordenates_cp
# id_municipio 15048 does not exist in colonias coordenates_cp
# id_municipio 15049 does not exist in colonias coordenates_cp
# id_municipio 15050 does not exist in colonias coordenates_cp
# id_municipio 15051 does not exist in colonias coordenates_cp
# id_municipio 15052 does not exist in colonias coordenates_cp
# id_municipio 15053 does not exist in colonias coordenates_cp
# id_municipio 15054 does not exist in colonias coordenates_cp
# id_municipio 15055 does not exist in colonias coordenates_cp
# id_municipio 15056 does not exist in colonias coordenates_cp
# id_municipio 15057 does not exist in colonias coordenates_cp
# id_municipio 15058 does not exist in colonias coordenates_cp
# id_municipio 15059 does not exist in colonias coordenates_cp
# id_municipio 15060 does not exist in colonias coordenates_cp
# id_municipio 15061 does not exist in colonias coordenates_cp
# id_municipio 15062 does not exist in colonias coordenates_cp
# id_municipio 15063 does not exist in colonias coordenates_cp
# id_municipio 15064 does not exist in colonias coordenates_cp
# id_municipio 15065 does not exist in colonias coordenates_cp
# id_municipio 15066 does not exist in colonias coordenates_cp
# id_municipio 15067 does not exist in colonias coordenates_cp
# id_municipio 15068 does not exist in colonias coordenates_cp
# id_municipio 15069 does not exist in colonias coordenates_cp
# id_municipio 15070 does not exist in colonias coordenates_cp
# id_municipio 15071 does not exist in colonias coordenates_cp
# id_municipio 15072 does not exist in colonias coordenates_cp
# id_municipio 15073 does not exist in colonias coordenates_cp
# id_municipio 15074 does not exist in colonias coordenates_cp
# id_municipio 15075 does not exist in colonias coordenates_cp
# id_municipio 15076 does not exist in colonias coordenates_cp
# id_municipio 15077 does not exist in colonias coordenates_cp
# id_municipio 15078 does not exist in colonias coordenates_cp
# id_municipio 15079 does not exist in colonias coordenates_cp
# id_municipio 15080 does not exist in colonias coordenates_cp
# id_municipio 15081 does not exist in colonias coordenates_cp
# id_municipio 15082 does not exist in colonias coordenates_cp
# id_municipio 15083 does not exist in colonias coordenates_cp
# id_municipio 15084 does not exist in colonias coordenates_cp
# id_municipio 15085 does not exist in colonias coordenates_cp
# id_municipio 15086 does not exist in colonias coordenates_cp
# id_municipio 15087 does not exist in colonias coordenates_cp
# id_municipio 15088 does not exist in colonias coordenates_cp
# id_municipio 15089 does not exist in colonias coordenates_cp
# id_municipio 15090 does not exist in colonias coordenates_cp
# id_municipio 15091 does not exist in colonias coordenates_cp
# id_municipio 15092 does not exist in colonias coordenates_cp
# id_municipio 15093 does not exist in colonias coordenates_cp
# id_municipio 15094 does not exist in colonias coordenates_cp
# id_municipio 15095 does not exist in colonias coordenates_cp
# id_municipio 15096 does not exist in colonias coordenates_cp
# id_municipio 15097 does not exist in colonias coordenates_cp
# id_municipio 15098 does not exist in colonias coordenates_cp
# id_municipio 15099 does not exist in colonias coordenates_cp
# id_municipio 15100 does not exist in colonias coordenates_cp
# id_municipio 15101 does not exist in colonias coordenates_cp
# id_municipio 15102 does not exist in colonias coordenates_cp
# id_municipio 15103 does not exist in colonias coordenates_cp
# id_municipio 15104 does not exist in colonias coordenates_cp
# id_municipio 15105 does not exist in colonias coordenates_cp
# id_municipio 15106 does not exist in colonias coordenates_cp
# id_municipio 15107 does not exist in colonias coordenates_cp
# id_municipio 15108 does not exist in colonias coordenates_cp
# id_municipio 15109 does not exist in colonias coordenates_cp
# id_municipio 15110 does not exist in colonias coordenates_cp
# id_municipio 15111 does not exist in colonias coordenates_cp
# id_municipio 15112 does not exist in colonias coordenates_cp
# id_municipio 15113 does not exist in colonias coordenates_cp
# id_municipio 15114 does not exist in colonias coordenates_cp
# id_municipio 15115 does not exist in colonias coordenates_cp
# id_municipio 15116 does not exist in colonias coordenates_cp
# id_municipio 15117 does not exist in colonias coordenates_cp
# id_municipio 15118 does not exist in colonias coordenates_cp
# id_municipio 15119 does not exist in colonias coordenates_cp
# id_municipio 15120 does not exist in colonias coordenates_cp
# id_municipio 15121 does not exist in colonias coordenates_cp
# id_municipio 15122 does not exist in colonias coordenates_cp
# id_municipio 15123 does not exist in colonias coordenates_cp
# id_municipio 15124 does not exist in colonias coordenates_cp
# id_municipio 15125 does not exist in colonias coordenates_cp
# id_municipio 16001 does not exist in colonias coordenates_cp
# id_municipio 16002 does not exist in colonias coordenates_cp
# id_municipio 16003 does not exist in colonias coordenates_cp
# id_municipio 16004 does not exist in colonias coordenates_cp
# id_municipio 16005 does not exist in colonias coordenates_cp
# ...
# id_municipio 30058 does not exist in colonias coordenates_cp
# id_municipio 30059 does not exist in colonias coordenates_cp
# id_municipio 30060 does not exist in colonias coordenates_cp
# id_municipio 30061 does not exist in colonias coordenates_cp
# id_municipio 30062 does not exist in colonias coordenates_cp
# id_municipio 30063 does not exist in colonias coordenates_cp
# id_municipio 30064 does not exist in colonias coordenates_cp
# id_municipio 30065 does not exist in colonias coordenates_cp
# id_municipio 30066 does not exist in colonias coordenates_cp
# id_municipio 30067 does not exist in colonias coordenates_cp
# id_municipio 30068 does not exist in colonias coordenates_cp
# id_municipio 30069 does not exist in colonias coordenates_cp
# id_municipio 30070 does not exist in colonias coordenates_cp
# id_municipio 30071 does not exist in colonias coordenates_cp
# id_municipio 30072 does not exist in colonias coordenates_cp
# id_municipio 30073 does not exist in colonias coordenates_cp
# id_municipio 30074 does not exist in colonias coordenates_cp
# id_municipio 30075 does not exist in colonias coordenates_cp
# id_municipio 30076 does not exist in colonias coordenates_cp
# id_municipio 30077 does not exist in colonias coordenates_cp
# id_municipio 30078 does not exist in colonias coordenates_cp
# id_municipio 30079 does not exist in colonias coordenates_cp
# id_municipio 30080 does not exist in colonias coordenates_cp
# id_municipio 30081 does not exist in colonias coordenates_cp
# id_municipio 30082 does not exist in colonias coordenates_cp
# id_municipio 30083 does not exist in colonias coordenates_cp
# id_municipio 30084 does not exist in colonias coordenates_cp
# id_municipio 30085 does not exist in colonias coordenates_cp
# id_municipio 30086 does not exist in colonias coordenates_cp
# id_municipio 30087 does not exist in colonias coordenates_cp
# id_municipio 30088 does not exist in colonias coordenates_cp
# id_municipio 30089 does not exist in colonias coordenates_cp
# id_municipio 30090 does not exist in colonias coordenates_cp
# id_municipio 30091 does not exist in colonias coordenates_cp
# id_municipio 30092 does not exist in colonias coordenates_cp
# id_municipio 30093 does not exist in colonias coordenates_cp
# id_municipio 30094 does not exist in colonias coordenates_cp
# id_municipio 30095 does not exist in colonias coordenates_cp
# id_municipio 30096 does not exist in colonias coordenates_cp
# id_municipio 30097 does not exist in colonias coordenates_cp
# id_municipio 30098 does not exist in colonias coordenates_cp
# id_municipio 30099 does not exist in colonias coordenates_cp
# id_municipio 30100 does not exist in colonias coordenates_cp
# id_municipio 30101 does not exist in colonias coordenates_cp
# id_municipio 30102 does not exist in colonias coordenates_cp
# id_municipio 30103 does not exist in colonias coordenates_cp
# id_municipio 30104 does not exist in colonias coordenates_cp
# id_municipio 30105 does not exist in colonias coordenates_cp
# id_municipio 30106 does not exist in colonias coordenates_cp
# id_municipio 30107 does not exist in colonias coordenates_cp
# id_municipio 30108 does not exist in colonias coordenates_cp
# id_municipio 30109 does not exist in colonias coordenates_cp
# id_municipio 30110 does not exist in colonias coordenates_cp
# id_municipio 30111 does not exist in colonias coordenates_cp
# id_municipio 30112 does not exist in colonias coordenates_cp
# id_municipio 30113 does not exist in colonias coordenates_cp
# id_municipio 30114 does not exist in colonias coordenates_cp
# id_municipio 30115 does not exist in colonias coordenates_cp
# id_municipio 30116 does not exist in colonias coordenates_cp
# id_municipio 30117 does not exist in colonias coordenates_cp
# id_municipio 30118 does not exist in colonias coordenates_cp
# id_municipio 30119 does not exist in colonias coordenates_cp
# id_municipio 30120 does not exist in colonias coordenates_cp
# id_municipio 30121 does not exist in colonias coordenates_cp
# id_municipio 30122 does not exist in colonias coordenates_cp
# id_municipio 30123 does not exist in colonias coordenates_cp
# id_municipio 30124 does not exist in colonias coordenates_cp
# id_municipio 30125 does not exist in colonias coordenates_cp
# id_municipio 30126 does not exist in colonias coordenates_cp
# id_municipio 30127 does not exist in colonias coordenates_cp
# id_municipio 30128 does not exist in colonias coordenates_cp
# id_municipio 30129 does not exist in colonias coordenates_cp
# id_municipio 30130 does not exist in colonias coordenates_cp
# id_municipio 30131 does not exist in colonias coordenates_cp
# id_municipio 30132 does not exist in colonias coordenates_cp
# id_municipio 30133 does not exist in colonias coordenates_cp
# id_municipio 30134 does not exist in colonias coordenates_cp
# id_municipio 30135 does not exist in colonias coordenates_cp
# id_municipio 30136 does not exist in colonias coordenates_cp
# id_municipio 30137 does not exist in colonias coordenates_cp
# id_municipio 30138 does not exist in colonias coordenates_cp
# id_municipio 30139 does not exist in colonias coordenates_cp
# id_municipio 30140 does not exist in colonias coordenates_cp
# id_municipio 30141 does not exist in colonias coordenates_cp
# id_municipio 30142 does not exist in colonias coordenates_cp
# id_municipio 30143 does not exist in colonias coordenates_cp
# id_municipio 30144 does not exist in colonias coordenates_cp
# id_municipio 30145 does not exist in colonias coordenates_cp
# id_municipio 30146 does not exist in colonias coordenates_cp
# id_municipio 30147 does not exist in colonias coordenates_cp
# id_municipio 30148 does not exist in colonias coordenates_cp
# id_municipio 30149 does not exist in colonias coordenates_cp
# id_municipio 30150 does not exist in colonias coordenates_cp
# id_municipio 30151 does not exist in colonias coordenates_cp
# id_municipio 30152 does not exist in colonias coordenates_cp
# id_municipio 30153 does not exist in colonias coordenates_cp
# id_municipio 30154 does not exist in colonias coordenates_cp
# id_municipio 30155 does not exist in colonias coordenates_cp
# id_municipio 30156 does not exist in colonias coordenates_cp
# id_municipio 30157 does not exist in colonias coordenates_cp
# id_municipio 30158 does not exist in colonias coordenates_cp
# id_municipio 30159 does not exist in colonias coordenates_cp
# id_municipio 30160 does not exist in colonias coordenates_cp
# id_municipio 30161 does not exist in colonias coordenates_cp
# id_municipio 30162 does not exist in colonias coordenates_cp
# id_municipio 30163 does not exist in colonias coordenates_cp
# id_municipio 30164 does not exist in colonias coordenates_cp
# id_municipio 30165 does not exist in colonias coordenates_cp
# id_municipio 30166 does not exist in colonias coordenates_cp
# id_municipio 30167 does not exist in colonias coordenates_cp
# id_municipio 30168 does not exist in colonias coordenates_cp
# id_municipio 30169 does not exist in colonias coordenates_cp
# id_municipio 30170 does not exist in colonias coordenates_cp
# id_municipio 30171 does not exist in colonias coordenates_cp
# id_municipio 30172 does not exist in colonias coordenates_cp
# id_municipio 30173 does not exist in colonias coordenates_cp
# id_municipio 30174 does not exist in colonias coordenates_cp
# id_municipio 30175 does not exist in colonias coordenates_cp
# id_municipio 30176 does not exist in colonias coordenates_cp
# id_municipio 30177 does not exist in colonias coordenates_cp
# id_municipio 30178 does not exist in colonias coordenates_cp
# id_municipio 30179 does not exist in colonias coordenates_cp
# id_municipio 30180 does not exist in colonias coordenates_cp
# id_municipio 30181 does not exist in colonias coordenates_cp
# id_municipio 30182 does not exist in colonias coordenates_cp
# id_municipio 30183 does not exist in colonias coordenates_cp
# id_municipio 30184 does not exist in colonias coordenates_cp
# id_municipio 30185 does not exist in colonias coordenates_cp
# id_municipio 30186 does not exist in colonias coordenates_cp
# id_municipio 30187 does not exist in colonias coordenates_cp
# id_municipio 30188 does not exist in colonias coordenates_cp
# id_municipio 30189 does not exist in colonias coordenates_cp
# id_municipio 30190 does not exist in colonias coordenates_cp
# id_municipio 30191 does not exist in colonias coordenates_cp
# id_municipio 30192 does not exist in colonias coordenates_cp
# id_municipio 30193 does not exist in colonias coordenates_cp
# id_municipio 30194 does not exist in colonias coordenates_cp
# id_municipio 30195 does not exist in colonias coordenates_cp
# id_municipio 30196 does not exist in colonias coordenates_cp
# id_municipio 30197 does not exist in colonias coordenates_cp
# id_municipio 30198 does not exist in colonias coordenates_cp
# id_municipio 30199 does not exist in colonias coordenates_cp
# id_municipio 30200 does not exist in colonias coordenates_cp
# id_municipio 30201 does not exist in colonias coordenates_cp
# id_municipio 30202 does not exist in colonias coordenates_cp
# id_municipio 30203 does not exist in colonias coordenates_cp
# id_municipio 30204 does not exist in colonias coordenates_cp
# id_municipio 30205 does not exist in colonias coordenates_cp
# id_municipio 30206 does not exist in colonias coordenates_cp
# id_municipio 30207 does not exist in colonias coordenates_cp
# id_municipio 30208 does not exist in colonias coordenates_cp
# id_municipio 30209 does not exist in colonias coordenates_cp
# id_municipio 30210 does not exist in colonias coordenates_cp
# id_municipio 30211 does not exist in colonias coordenates_cp
# id_municipio 30212 does not exist in colonias coordenates_cp
# id_municipio 31001 does not exist in colonias coordenates_cp
# id_municipio 31002 does not exist in colonias coordenates_cp
# id_municipio 31003 does not exist in colonias coordenates_cp
# id_municipio 31004 does not exist in colonias coordenates_cp
# id_municipio 31005 does not exist in colonias coordenates_cp
# id_municipio 31006 does not exist in colonias coordenates_cp
# id_municipio 31007 does not exist in colonias coordenates_cp
# id_municipio 31008 does not exist in colonias coordenates_cp
# id_municipio 31009 does not exist in colonias coordenates_cp
# id_municipio 31010 does not exist in colonias coordenates_cp
# id_municipio 31011 does not exist in colonias coordenates_cp
# id_municipio 31012 does not exist in colonias coordenates_cp
# id_municipio 31013 does not exist in colonias coordenates_cp
# id_municipio 31014 does not exist in colonias coordenates_cp
# id_municipio 31015 does not exist in colonias coordenates_cp
# id_municipio 31016 does not exist in colonias coordenates_cp
# id_municipio 31017 does not exist in colonias coordenates_cp
# id_municipio 31018 does not exist in colonias coordenates_cp
# id_municipio 31019 does not exist in colonias coordenates_cp
# id_municipio 31020 does not exist in colonias coordenates_cp
# id_municipio 31021 does not exist in colonias coordenates_cp
# id_municipio 31022 does not exist in colonias coordenates_cp
# id_municipio 31023 does not exist in colonias coordenates_cp
# id_municipio 31024 does not exist in colonias coordenates_cp
# id_municipio 31025 does not exist in colonias coordenates_cp
# id_municipio 31026 does not exist in colonias coordenates_cp
# id_municipio 31027 does not exist in colonias coordenates_cp
# id_municipio 31028 does not exist in colonias coordenates_cp
# id_municipio 31029 does not exist in colonias coordenates_cp
# id_municipio 31030 does not exist in colonias coordenates_cp
# id_municipio 31031 does not exist in colonias coordenates_cp
# id_municipio 31032 does not exist in colonias coordenates_cp
# id_municipio 31033 does not exist in colonias coordenates_cp
# id_municipio 31034 does not exist in colonias coordenates_cp
# id_municipio 31035 does not exist in colonias coordenates_cp
# id_municipio 31036 does not exist in colonias coordenates_cp
# id_municipio 31037 does not exist in colonias coordenates_cp
# id_municipio 31038 does not exist in colonias coordenates_cp
# id_municipio 31039 does not exist in colonias coordenates_cp
# id_municipio 31040 does not exist in colonias coordenates_cp
# id_municipio 31041 does not exist in colonias coordenates_cp
# id_municipio 31042 does not exist in colonias coordenates_cp
# id_municipio 31043 does not exist in colonias coordenates_cp
# id_municipio 31044 does not exist in colonias coordenates_cp
# id_municipio 31045 does not exist in colonias coordenates_cp
# id_municipio 31046 does not exist in colonias coordenates_cp
# id_municipio 31047 does not exist in colonias coordenates_cp
# id_municipio 31048 does not exist in colonias coordenates_cp
# id_municipio 31049 does not exist in colonias coordenates_cp
# id_municipio 31050 does not exist in colonias coordenates_cp
# id_municipio 31051 does not exist in colonias coordenates_cp
# id_municipio 31052 does not exist in colonias coordenates_cp
# id_municipio 31053 does not exist in colonias coordenates_cp
# id_municipio 31054 does not exist in colonias coordenates_cp
# id_municipio 31055 does not exist in colonias coordenates_cp
# id_municipio 31056 does not exist in colonias coordenates_cp
# id_municipio 31057 does not exist in colonias coordenates_cp
# id_municipio 31058 does not exist in colonias coordenates_cp
# id_municipio 31059 does not exist in colonias coordenates_cp
# id_municipio 31060 does not exist in colonias coordenates_cp
# id_municipio 31061 does not exist in colonias coordenates_cp
# id_municipio 31062 does not exist in colonias coordenates_cp
# id_municipio 31063 does not exist in colonias coordenates_cp
# id_municipio 31064 does not exist in colonias coordenates_cp
# id_municipio 31065 does not exist in colonias coordenates_cp
# id_municipio 31066 does not exist in colonias coordenates_cp
# id_municipio 31067 does not exist in colonias coordenates_cp
# id_municipio 31068 does not exist in colonias coordenates_cp
# id_municipio 31069 does not exist in colonias coordenates_cp
# id_municipio 31070 does not exist in colonias coordenates_cp
# id_municipio 31071 does not exist in colonias coordenates_cp
# id_municipio 31072 does not exist in colonias coordenates_cp
# id_municipio 31073 does not exist in colonias coordenates_cp
# id_municipio 31074 does not exist in colonias coordenates_cp
# id_municipio 31075 does not exist in colonias coordenates_cp
# id_municipio 31076 does not exist in colonias coordenates_cp
# id_municipio 31077 does not exist in colonias coordenates_cp
# id_municipio 31078 does not exist in colonias coordenates_cp
# id_municipio 31079 does not exist in colonias coordenates_cp
# id_municipio 31080 does not exist in colonias coordenates_cp
# id_municipio 31081 does not exist in colonias coordenates_cp
# id_municipio 31082 does not exist in colonias coordenates_cp
# id_municipio 31083 does not exist in colonias coordenates_cp
# id_municipio 31084 does not exist in colonias coordenates_cp
# id_municipio 31085 does not exist in colonias coordenates_cp
# id_municipio 31086 does not exist in colonias coordenates_cp
# id_municipio 31087 does not exist in colonias coordenates_cp
# id_municipio 31088 does not exist in colonias coordenates_cp
# id_municipio 31089 does not exist in colonias coordenates_cp
# id_municipio 31090 does not exist in colonias coordenates_cp
# id_municipio 31091 does not exist in colonias coordenates_cp
# id_municipio 31092 does not exist in colonias coordenates_cp
# id_municipio 31093 does not exist in colonias coordenates_cp
# id_municipio 31094 does not exist in colonias coordenates_cp
# id_municipio 31095 does not exist in colonias coordenates_cp
# id_municipio 31096 does not exist in colonias coordenates_cp
# id_municipio 31097 does not exist in colonias coordenates_cp
# id_municipio 31098 does not exist in colonias coordenates_cp
# id_municipio 31099 does not exist in colonias coordenates_cp
# id_municipio 31100 does not exist in colonias coordenates_cp
# id_municipio 31101 does not exist in colonias coordenates_cp
# id_municipio 31102 does not exist in colonias coordenates_cp
# id_municipio 31103 does not exist in colonias coordenates_cp
# id_municipio 31104 does not exist in colonias coordenates_cp
# id_municipio 31105 does not exist in colonias coordenates_cp
# id_municipio 31106 does not exist in colonias coordenates_cp
# id_municipio nan does not exist in coordenates_cp coordenates_cp

# %%
colonias
# Out:
#         código postal                                       asentamiento  \
# 0                1000                                          San Angel
# 1                1010                                          Los Alpes
# 2                1020                                      Guadalupe Inn
# 3                1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4                1029                                          INFONAVIT
# ...               ...                                                ...
# 143219          99993                                            Cuxpala
# 143220          99994                                   Vicente Guerrero
# 143221          99998                                          Palmarejo
# 143222          99998                                        Jesus Maria
# 143223          99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143222     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143223     Rancheria  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip                entidad_municipio  id_municipio  \
# 0          AlvaroObregon  ciudad de mexico-alvaro obregon           NaN
# 1          AlvaroObregon  ciudad de mexico-alvaro obregon           NaN
# 2          AlvaroObregon  ciudad de mexico-alvaro obregon           NaN
# 3          AlvaroObregon  ciudad de mexico-alvaro obregon           NaN
# 4          AlvaroObregon  ciudad de mexico-alvaro obregon           NaN
# ...                  ...                              ...           ...
# 143219  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143220  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143221  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143222  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143223  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
#
#         carpetas   total  crimes_10k  class
# 0            NaN     NaN         NaN    NaN
# 1            NaN     NaN         NaN    NaN
# 2            NaN     NaN         NaN    NaN
# 3            NaN     NaN         NaN    NaN
# 4            NaN     NaN         NaN    NaN
# ...          ...     ...         ...    ...
# 143219       9.0  3947.0   22.802128    2.0
# 143220       9.0  3947.0   22.802128    2.0
# 143221       9.0  3947.0   22.802128    2.0
# 143222       9.0  3947.0   22.802128    2.0
# 143223       9.0  3947.0   22.802128    2.0
#
# [143224 rows x 13 columns]

# %% [markdown]
# Merging colonias with coordenates_cp

# %%
data_map_cp = pd.merge(data_map_municipios.drop(columns=['lat', 'lon']), coordenates_cp, how='right', on='id_municipio')
data_map_cp.head()
# Out:
#    id_municipio         entidad       municipio  carpetas     total  \
# 0          1001  Aguascalientes  Aguascalientes   11091.0  877190.0
# 1          1001  Aguascalientes  Aguascalientes   11091.0  877190.0
# 2          1001  Aguascalientes  Aguascalientes   11091.0  877190.0
# 3          1001  Aguascalientes  Aguascalientes   11091.0  877190.0
# 4          1001  Aguascalientes  Aguascalientes   11091.0  877190.0
#
#    crimes_10k  class  id_entidad               localidad        lat  \
# 0   126.43783    4.0           1          Aguascalientes  21.879823
# 1   126.43783    4.0           1          Granja Adelita  21.871875
# 2   126.43783    4.0           1               Agua Azul  21.883756
# 3   126.43783    4.0           1           Rancho Alegre  21.854599
# 4   126.43783    4.0           1  Los Arbolitos [Rancho]  21.780181
#
#           lon
# 0 -102.296047
# 1 -102.373531
# 2 -102.357122
# 3 -102.372746
# 4 -102.357295

# %% [markdown]
# #### Mapping by zip code

# %%
import folium

data = data_map_cp

#data = data[data['municipio'] == 'Puebla']

data = data.iloc[192200: 192202]

data1 = data

map = folium.Map(location = [data.iloc[0]['lat'], data.iloc[0]['lon']], zoom_start=8)



for localidad in data1['localidad'].unique():
    data = data1[data1['localidad'] == localidad]

    colors = ['forestgreen', 'lime', 'yellow', 'lightcoral', 'firebrick']
    for cluster in range(5):
        color_cluster = colors[cluster]
        for point in range(len(data[data['class']==cluster])):
            folium.CircleMarker(location=[data.iloc[point]['lat'], data.iloc[point]['lon']],
            radius=8,
            color=color_cluster,
            fill_color=color_cluster,
            fill=True
            ).add_to(map)

data = data1

map.save('map_colonias.html')

# %%
# Exporting output
data_map_cp.to_csv('output data/data_map_cp.csv')
