# %% [markdown]
# ## Crimes by municipality Mexico
# Focus crimes: Secuestro, Extorsión, Robo a negocio

# %%
# Importing libraries
import pandas as pd 
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import seaborn as sns
import regex as re

# %matplotlib inline

# %%
# Select if you want to limit the type of crimes
limit_crimes = True
# Select if you want to generate the maps for states
generate_maps = False
# export_databases
export_data = True

# %% [markdown]
# ### 1.- Importing data

# %%
# Database with crimes information
df = pd.read_csv('data/delitos-datos-abiertos.csv')
# Database with population information
pop = pd.read_csv('data/poblaciones_2015.csv', skiprows=4, encoding='latin-1', skipfooter=6, engine='python')
# Database with cp information
cp = pd.read_excel('data/codigos-postales-mexico.xlsx')

# Formatting column names
df.columns = [x.lower().strip() for x in df.columns]
pop.columns = [x.lower().strip() for x in pop.columns]
cp.columns = [x.lower().strip() for x in cp.columns]

# Formatting date columns
df['fecha'] = pd.to_datetime(df['fecha'], infer_datetime_format=True)

# Renaming columns
df.rename(columns={'inegi_entidad': 'id_entidad',
                    'inegi_municipio': 'id_municipio'}, inplace=True)

pop.drop(columns='id_municipio', inplace=True)

pop.rename(columns={'estado': 'entidad',
                    'cve_inegi': 'id_municipio',
                    'id_estado': 'id_entidad'}, inplace=True)
                    
cp.rename(columns={'estado': 'entidad'}, inplace=True)

# limit to only specific crimes
if limit_crimes == True:
    df = df[(df['delito'] == 'Extorsión') |
                     (df['delito'] == 'Robo a negocio') |
                     (df['delito'] == 'Secuestro')]

df.head()
# Out:
#       id_entidad         entidad  id_municipio            municipio  \
# 7371           1  Aguascalientes          1007      Rincon De Romos
# 7372           1  Aguascalientes          1006  Pabellon De Arteaga
# 7373           1  Aguascalientes          1009             Tepezala
# 7374           1  Aguascalientes          1008   San Jose De Gracia
# 7375           1  Aguascalientes          1002             Asientos
#
#       id_delito     delito  carpetas  tasa      fecha
# 7371       2000  Secuestro         0   0.0 2021-01-01
# 7372       2000  Secuestro         0   0.0 2021-01-01
# 7373       2000  Secuestro         0   0.0 2021-01-01
# 7374       2000  Secuestro         0   0.0 2021-01-01
# 7375       2000  Secuestro         0   0.0 2021-01-01

# %%
pop.head()
# Out:
#           entidad       municipio  id_municipio  id_entidad  hombres  mujeres  \
# 0  Aguascalientes  Aguascalientes          1001           1   425731   451459
# 1  Aguascalientes        Asientos          1002           1    22745    23719
# 2  Aguascalientes        Calvillo          1003           1    27298    28750
# 3  Aguascalientes           Cosío          1004           1     7552     8025
# 4  Aguascalientes     Jesús María          1005           1    60135    60270
#
#     total
# 0  877190
# 1   46464
# 2   56048
# 3   15577
# 4  120405

# %%
df.tail()
# Out:
#         id_entidad    entidad  id_municipio  municipio  id_delito  \
# 454540          32  Zacatecas         32025  Luis Moya       4300
# 454541          32  Zacatecas         32018   Huanusco       4300
# 454542          32  Zacatecas         32001     Apozol       4300
# 454543          32  Zacatecas         32040  Sain Alto       4300
# 454544          32  Zacatecas         32023  Juchipila       4300
#
#                 delito  carpetas  tasa      fecha
# 454540  Robo a negocio         0   0.0 2021-12-01
# 454541  Robo a negocio         0   0.0 2021-12-01
# 454542  Robo a negocio         0   0.0 2021-12-01
# 454543  Robo a negocio         0   0.0 2021-12-01
# 454544  Robo a negocio         0   0.0 2021-12-01

# %%
pop.tail()
# Out:
#         entidad                municipio  id_municipio  id_entidad  hombres  \
# 2452  Zacatecas            Villa Hidalgo         32054          32     9433
# 2453  Zacatecas               Villanueva         32055          32    14793
# 2454  Zacatecas                Zacatecas         32056          32    70855
# 2455  Zacatecas                 Trancoso         32057          32     9505
# 2456  Zacatecas  Santa María de la Paz *         32058          32     1305
#
#       mujeres   total
# 2452     9722   19155
# 2453    15447   30240
# 2454    75292  146147
# 2455     9908   19413
# 2456     1351    2656

# %%
cp.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio            ciudad           entidad
# 0  Álvaro Obregón  Ciudad de México  Distrito Federal
# 1  Álvaro Obregón  Ciudad de México  Distrito Federal
# 2  Álvaro Obregón  Ciudad de México  Distrito Federal
# 3  Álvaro Obregón  Ciudad de México  Distrito Federal
# 4  Álvaro Obregón  Ciudad de México  Distrito Federal

# %% [markdown]
# ### 1.1 Cleaning data

# %%
# Cleaning  * from names in pop df
pop['municipio'] = pop['municipio'].replace(' *', '', regex=True)
pop['municipio'] = pop['municipio'].replace('\*', '', regex=True)

# Changing Distrito Federal for CDMX
pop['entidad'] = pop['entidad'].replace('Distrito Federal', 'Ciudad de México')
df['entidad'] = df['entidad'].replace('Distrito Federal', 'Ciudad de México')
cp['entidad'] = cp['entidad'].replace('Distrito Federal', 'Ciudad de México')

pop.tail()
# Out:
#         entidad          municipio  id_municipio  id_entidad  hombres  \
# 2452  Zacatecas       VillaHidalgo         32054          32     9433
# 2453  Zacatecas         Villanueva         32055          32    14793
# 2454  Zacatecas          Zacatecas         32056          32    70855
# 2455  Zacatecas           Trancoso         32057          32     9505
# 2456  Zacatecas  SantaMaríadelaPaz         32058          32     1305
#
#       mujeres   total
# 2452     9722   19155
# 2453    15447   30240
# 2454    75292  146147
# 2455     9908   19413
# 2456     1351    2656

# %%
# Separating words in pop df
string = 'VillaHidalgo'
words = re.findall('[A-Z][a-z]*', string)
string2 = ' '.join(words)
print(string2)

# Deleting spaces
string = 'Villa Hidalgo'
string3 = string.replace(' ', '')
string3
# Out:
# Villa Hidalgo
# 'VillaHidalgo'

# %%
# Applying functions
# pop['municipio_sep'] = pop['municipio'].apply(lambda x: ' '.join(re.findall('[A-Z][a-zÀ-ÿ]*', x)))
cp['municipio_strip'] = cp['municipio'].apply(lambda x: x.replace(' ', ''))

# %%
cp
# Out:
#         código                                       asentamiento  \
# 0         1000                                          San Angel
# 1         1010                                          Los Alpes
# 2         1020                                      Guadalupe Inn
# 3         1028  Secretaria de Contraloría y Desarrollo Adminis...
# 4         1029                                          INFONAVIT
# ...        ...                                                ...
# 143219   99993                                            Cuxpala
# 143220   99994                                   Vicente Guerrero
# 143221   99998                                          Palmarejo
# 143222   99998                                        Jesús Maria
# 143223   99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 1            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 2            Colonia      Álvaro Obregón  Ciudad de México  Ciudad de México
# 3       Gran usuario      Álvaro Obregón  Ciudad de México  Ciudad de México
# 4       Gran usuario      Álvaro Obregón  Ciudad de México  Ciudad de México
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Ranchería  Moyahua de Estrada               NaN         Zacatecas
# 143222     Ranchería  Moyahua de Estrada               NaN         Zacatecas
# 143223     Ranchería  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip
# 0          ÁlvaroObregón
# 1          ÁlvaroObregón
# 2          ÁlvaroObregón
# 3          ÁlvaroObregón
# 4          ÁlvaroObregón
# ...                  ...
# 143219  MoyahuadeEstrada
# 143220  MoyahuadeEstrada
# 143221  MoyahuadeEstrada
# 143222  MoyahuadeEstrada
# 143223  MoyahuadeEstrada
#
# [143224 rows x 7 columns]

# %% [markdown]
# ### 2.- Exploring data

# %% [markdown]
# #### 2.1.- Exploring datatypes

# %%
df.dtypes
# Out:
# id_entidad               int64
# entidad                 object
# id_municipio             int64
# municipio               object
# id_delito                int64
# delito                  object
# carpetas                 int64
# tasa                   float64
# fecha           datetime64[ns]
# dtype: object

# %%
pop.dtypes
# Out:
# entidad         object
# municipio       object
# id_municipio     int64
# id_entidad       int64
# hombres          int64
# mujeres          int64
# total            int64
# dtype: object

# %%
cp.dtypes
# Out:
# código              int64
# asentamiento       object
# tipo               object
# municipio          object
# ciudad             object
# entidad            object
# municipio_strip    object
# dtype: object

# %% [markdown]
# #### 2.2.- Cleaning data to merge

# %% [markdown]
# Checking id_municipio

# %%
# Creating list of unique ids in each dataset
unique_id_df = df['id_municipio'].unique()
unique_id_pop = pop['id_municipio'].unique()

# Len of the lists
len_id_df = len(df['id_municipio'].unique())
len_id_pop = len(pop['id_municipio'].unique())

print(len_id_df)
print(len_id_pop)

for i in unique_id_df:
    if i not in unique_id_pop:
        m = df[df['id_municipio'] == i].iloc[0]['municipio']
        print('id {} ({}) does not exist in pop data'.format(i, m))

print('\n')
# Out:
# 2457
# 2457
# id 7114 (Benemerito De Las Americas) does not exist in pop data
# id 7117 (Montecristo De Guerrero) does not exist in pop data
# id 7116 (Marques De Comillas) does not exist in pop data
# id 7101 (Tuxtla Gutierrez) does not exist in pop data
# id 7112 (San Juan Cancuc) does not exist in pop data
# id 7113 (Aldama) does not exist in pop data
# id 7100 (Tumbala) does not exist in pop data
# id 7104 (Tzimol) does not exist in pop data
# id 7102 (Tuxtla Chico) does not exist in pop data
# id 7110 (San Lucas) does not exist in pop data
# id 7115 (Maravilla Tenejapa) does not exist in pop data
# id 7105 (Union Juarez) does not exist in pop data
# id 7107 (Villa Corzo) does not exist in pop data
# id 7109 (Yajalon) does not exist in pop data
# id 7119 (Santiago El Pinar) does not exist in pop data
# id 7108 (Villaflores) does not exist in pop data
# id 7118 (San Andres Duraznal) does not exist in pop data
# id 7111 (Zinacantan) does not exist in pop data
# id 7106 (Venustiano Carranza) does not exist in pop data
# id 7103 (Tuzantan) does not exist in pop data

# %%
for i in unique_id_pop:
    if i not in unique_id_df:
        m = pop[pop['id_municipio'] == i].iloc[0]['municipio']
        print('id {} ({}) does not exist in crimes data'.format(i, m))
# Out:
# id 70100 (Tumbalá) does not exist in crimes data
# id 70101 (TuxtlaGutiérrez) does not exist in crimes data
# id 70102 (TuxtlaChico) does not exist in crimes data
# id 70103 (Tuzantán) does not exist in crimes data
# id 70104 (Tzimol) does not exist in crimes data
# id 70105 (UniónJuárez) does not exist in crimes data
# id 70106 (VenustianoCarranza) does not exist in crimes data
# id 70107 (VillaCorzo) does not exist in crimes data
# id 70108 (Villaflores) does not exist in crimes data
# id 70109 (Yajalón) does not exist in crimes data
# id 70110 (SanLucas) does not exist in crimes data
# id 70111 (Zinacantán) does not exist in crimes data
# id 70112 (SanJuanCancuc) does not exist in crimes data
# id 70113 (Aldama) does not exist in crimes data
# id 70114 (BeneméritodelasAméricas) does not exist in crimes data
# id 70115 (MaravillaTenejapa) does not exist in crimes data
# id 70116 (MarquésdeComillas) does not exist in crimes data
# id 70117 (MontecristodeGuerrero) does not exist in crimes data
# id 70118 (SanAndrésDuraznal) does not exist in crimes data
# id 70119 (SantiagoelPinar) does not exist in crimes data

# %%
# Fixing misslabeled data
for i in unique_id_pop:
    if i not in unique_id_df:
        to_replace_with = i - 70000 + 7000
        print('{} replaced with {}'.format(i, to_replace_with))
        pop['id_municipio'] = pop['id_municipio'].replace(i, to_replace_with)
# Out:
# 70100 replaced with 7100
# 70101 replaced with 7101
# 70102 replaced with 7102
# 70103 replaced with 7103
# 70104 replaced with 7104
# 70105 replaced with 7105
# 70106 replaced with 7106
# 70107 replaced with 7107
# 70108 replaced with 7108
# 70109 replaced with 7109
# 70110 replaced with 7110
# 70111 replaced with 7111
# 70112 replaced with 7112
# 70113 replaced with 7113
# 70114 replaced with 7114
# 70115 replaced with 7115
# 70116 replaced with 7116
# 70117 replaced with 7117
# 70118 replaced with 7118
# 70119 replaced with 7119

# %%
# Creating list of unique ids in each dataset
unique_id_df = df['id_municipio'].unique()
unique_id_pop = pop['id_municipio'].unique()

# Len of the lists
len_id_df = len(df['id_municipio'].unique())
len_id_pop = len(pop['id_municipio'].unique())

for i in unique_id_pop:
    if i not in unique_id_df:
        print('id {} does not exist in crimes data'.format(i))

for i in unique_id_df:
    if i not in unique_id_pop:
        print('id {} does not exist in crimes data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# Checking municipio column

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {}  does not exist in pop data'.format(i))
# Out:
# 2318
# 2317
# -1
#
#
# Municipio TezoatlándeSegurayLuna  does not exist in pop data
# Municipio SanJuanMixtepec-Dto.08-  does not exist in pop data
# Municipio SanJuanMixtepec-Dto.26-  does not exist in pop data
# Municipio SanPedroMixtepec-Dto.26-  does not exist in pop data
# Municipio SanPedroMixtepec-Dto.22-  does not exist in pop data
# Municipio Medellín  does not exist in pop data

# %%
# Cleaning -Dto.xx- from name in cp database
cp['municipio_strip'] = cp['municipio_strip'].replace('\-.+\..+', '', regex=True)

# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {}  does not exist in pop data'.format(i))
# Out:
# 2316
# 2317
# 1
#
#
# Municipio TezoatlándeSegurayLuna  does not exist in pop data
# Municipio Medellín  does not exist in pop data

# %%
for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {}  does not exist in cp data'.format(i))
# Out:
# Municipio ZacualpandeAmilpas  does not exist in cp data
# Municipio HeroicaVillaTezoatlándeSegurayLuna,CunadelaIndependenciadeOaxaca  does not exist in cp data
# Municipio MedellíndeBravo  does not exist in cp data

# %%
# Replacing values manually
pop['municipio'] = pop['municipio'].replace('HeroicaVillaTezoatlándeSegurayLuna,CunadelaIndependenciadeOaxaca',
                                            'TezoatlándeSegurayLuna')

pop['municipio'] = pop['municipio'].replace('MedellíndeBravo', 'Medellín')

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

print(len_mun_cp)
print(len_mun_pop)
print(len_mun_pop - len_mun_cp)

print('\n')

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {} does not exist in cp data'.format(i))

pop[pop['municipio'] == 'ZacualpandeAmilpas']
# Out:
# 2316
# 2317
# 1
#
#
# Municipio ZacualpandeAmilpas does not exist in cp data
#      entidad           municipio  id_municipio  id_entidad  hombres  mujeres  \
# 925  Morelos  ZacualpandeAmilpas         17032          17     4550     4820
#
#      total
# 925   9370

# %%
# Correcting last value
pop['municipio'] = pop['municipio'].replace('ZacualpandeAmilpas', 'Zacualpan')

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['municipio_strip'].unique()
unique_mun_pop = pop['municipio'].unique()

# Len of the lists
len_mun_cp = len(cp['municipio_strip'].unique())
len_mun_pop = len(pop['municipio'].unique())

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('Municipio {} does not exist in cp data'.format(i))

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('Municipio {} does not exist in cp data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# Checking entidad column

# %%
# Creating list of unique ids in each dataset
unique_mun_cp = cp['entidad'].unique()
unique_mun_pop = pop['entidad'].unique()

# Len of the lists
len_mun_cp = len(cp['entidad'].unique())
len_mun_pop = len(pop['entidad'].unique())

for i in unique_mun_pop:
    if i not in unique_mun_cp:
        print('entidad {} does not exist in cp data'.format(i))

for i in unique_mun_cp:
    if i not in unique_mun_pop:
        print('entidad {} does not exist in pop data'.format(i))

print('No missing values')

if len_id_df == len_id_pop:
    print('Equal lenghts')

print('Ready to merge crimes and pop')
# Out:
# No missing values
# Equal lenghts
# Ready to merge crimes and pop

# %% [markdown]
# ### 3.- Merging

# %% [markdown]
# #### 3.1 Merging zip code and population data

# %%
# Generating column entidad-municipio for pop
pop['entidad_municipio'] = pop['entidad'] + '-' + pop['municipio']

# Generating column entidad-municipio for cp
cp['entidad_municipio'] = cp['entidad'] + '-' + cp['municipio_strip']
cp.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio            ciudad           entidad municipio_strip  \
# 0  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 1  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 2  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 3  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
# 4  Álvaro Obregón  Ciudad de México  Ciudad de México   ÁlvaroObregón
#
#                 entidad_municipio
# 0  Ciudad de México-ÁlvaroObregón
# 1  Ciudad de México-ÁlvaroObregón
# 2  Ciudad de México-ÁlvaroObregón
# 3  Ciudad de México-ÁlvaroObregón
# 4  Ciudad de México-ÁlvaroObregón

# %%
df.head()
# Out:
#       id_entidad         entidad  id_municipio            municipio  \
# 7371           1  Aguascalientes          1007      Rincon De Romos
# 7372           1  Aguascalientes          1006  Pabellon De Arteaga
# 7373           1  Aguascalientes          1009             Tepezala
# 7374           1  Aguascalientes          1008   San Jose De Gracia
# 7375           1  Aguascalientes          1002             Asientos
#
#       id_delito     delito  carpetas  tasa      fecha
# 7371       2000  Secuestro         0   0.0 2021-01-01
# 7372       2000  Secuestro         0   0.0 2021-01-01
# 7373       2000  Secuestro         0   0.0 2021-01-01
# 7374       2000  Secuestro         0   0.0 2021-01-01
# 7375       2000  Secuestro         0   0.0 2021-01-01

# %%
pop.head()
# Out:
#           entidad       municipio  id_municipio  id_entidad  hombres  mujeres  \
# 0  Aguascalientes  Aguascalientes          1001           1   425731   451459
# 1  Aguascalientes        Asientos          1002           1    22745    23719
# 2  Aguascalientes        Calvillo          1003           1    27298    28750
# 3  Aguascalientes           Cosío          1004           1     7552     8025
# 4  Aguascalientes      JesúsMaría          1005           1    60135    60270
#
#     total              entidad_municipio
# 0  877190  Aguascalientes-Aguascalientes
# 1   46464        Aguascalientes-Asientos
# 2   56048        Aguascalientes-Calvillo
# 3   15577           Aguascalientes-Cosío
# 4  120405      Aguascalientes-JesúsMaría

# %%
# Merging pop and cp data
cols_cp = ['código', 'asentamiento', 'tipo', 'municipio', 'entidad_municipio']

cp_pop = pd.merge(cp[cols_cp], pop, how='left', left_on='entidad_municipio', right_on='entidad_municipio')
cp_pop.head()
# Out:
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#       municipio_x               entidad_municipio           entidad  \
# 0  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 1  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 2  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 3  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 4  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
#
#      municipio_y  id_municipio  id_entidad  hombres  mujeres   total
# 0  ÁlvaroObregón          9010           9   355754   394228  749982
# 1  ÁlvaroObregón          9010           9   355754   394228  749982
# 2  ÁlvaroObregón          9010           9   355754   394228  749982
# 3  ÁlvaroObregón          9010           9   355754   394228  749982
# 4  ÁlvaroObregón          9010           9   355754   394228  749982

# %%
len(cp) -len(cp_pop)
# Out:
# -213

# %%
# Difference comes from Districts different cp
cp[cp['municipio'].str.contains('\-.+\..+', regex=True)]
# Out:
#        código                       asentamiento       tipo  \
# 91558   69770                         Las Flores    Colonia
# 91559   69770                    San Miguel Lado     Barrio
# 91560   69770  San Juan Mixtepec - Dto.08 Centro    Colonia
# 91561   69770                 San Pedro Calvario     Barrio
# 91562   69770                           De Jesús     Barrio
# ...       ...                                ...        ...
# 95508   71998                         El Salitre  Ranchería
# 95509   71998                     Cerro Zopilote  Ranchería
# 95510   71998                          El Toledo  Ranchería
# 95511   71998                            Regadío  Ranchería
# 95512   71998                       Río Chiquito  Ranchería
#
#                            municipio ciudad entidad   municipio_strip  \
# 91558   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91559   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91560   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91561   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# 91562   San Juan Mixtepec -Dto. 08 -    NaN  Oaxaca   SanJuanMixtepec
# ...                              ...    ...     ...               ...
# 95508  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95509  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95510  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95511  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
# 95512  San Pedro Mixtepec -Dto. 22 -    NaN  Oaxaca  SanPedroMixtepec
#
#              entidad_municipio
# 91558   Oaxaca-SanJuanMixtepec
# 91559   Oaxaca-SanJuanMixtepec
# 91560   Oaxaca-SanJuanMixtepec
# 91561   Oaxaca-SanJuanMixtepec
# 91562   Oaxaca-SanJuanMixtepec
# ...                        ...
# 95508  Oaxaca-SanPedroMixtepec
# 95509  Oaxaca-SanPedroMixtepec
# 95510  Oaxaca-SanPedroMixtepec
# 95511  Oaxaca-SanPedroMixtepec
# 95512  Oaxaca-SanPedroMixtepec
#
# [213 rows x 8 columns]

# %%
pop[pop['municipio'].str.contains('Mixtepec', regex=True)]
# Out:
#      entidad            municipio  id_municipio  id_entidad  hombres  mujeres  \
# 1045  Oaxaca    MagdalenaMixtepec         20048          20      662      713
# 1120  Oaxaca  SanBernardoMixtepec         20123          20     1313     1428
# 1150  Oaxaca   SanGabrielMixtepec         20153          20     2355     2481
# 1205  Oaxaca      SanJuanMixtepec         20208          20     3113     3567
# 1206  Oaxaca      SanJuanMixtepec         20209          20      285      375
# 1268  Oaxaca    SanMiguelMixtepec         20271          20     1295     1349
# 1315  Oaxaca     SanPedroMixtepec         20318          20    23381    24955
# 1316  Oaxaca     SanPedroMixtepec         20319          20      523      551
# 1375  Oaxaca    SantaCruzMixtepec         20378          20     1624     1801
#
#       total           entidad_municipio
# 1045   1375    Oaxaca-MagdalenaMixtepec
# 1120   2741  Oaxaca-SanBernardoMixtepec
# 1150   4836   Oaxaca-SanGabrielMixtepec
# 1205   6680      Oaxaca-SanJuanMixtepec
# 1206    660      Oaxaca-SanJuanMixtepec
# 1268   2644    Oaxaca-SanMiguelMixtepec
# 1315  48336     Oaxaca-SanPedroMixtepec
# 1316   1074     Oaxaca-SanPedroMixtepec
# 1375   3425    Oaxaca-SantaCruzMixtepec

# %%
# Dropping second repeated municipios
pop.drop([1206, 1316], inplace=True)
pop[pop['municipio'].str.contains('Mixtepec', regex=True)]
# Out:
#      entidad            municipio  id_municipio  id_entidad  hombres  mujeres  \
# 1045  Oaxaca    MagdalenaMixtepec         20048          20      662      713
# 1120  Oaxaca  SanBernardoMixtepec         20123          20     1313     1428
# 1150  Oaxaca   SanGabrielMixtepec         20153          20     2355     2481
# 1205  Oaxaca      SanJuanMixtepec         20208          20     3113     3567
# 1268  Oaxaca    SanMiguelMixtepec         20271          20     1295     1349
# 1315  Oaxaca     SanPedroMixtepec         20318          20    23381    24955
# 1375  Oaxaca    SantaCruzMixtepec         20378          20     1624     1801
#
#       total           entidad_municipio
# 1045   1375    Oaxaca-MagdalenaMixtepec
# 1120   2741  Oaxaca-SanBernardoMixtepec
# 1150   4836   Oaxaca-SanGabrielMixtepec
# 1205   6680      Oaxaca-SanJuanMixtepec
# 1268   2644    Oaxaca-SanMiguelMixtepec
# 1315  48336     Oaxaca-SanPedroMixtepec
# 1375   3425    Oaxaca-SantaCruzMixtepec

# %%
# Merging again
# Merging pop and cp data
cols_cp = ['código', 'asentamiento', 'tipo', 'municipio', 'entidad_municipio']

cp_pop = pd.merge(cp[cols_cp], pop, how='left', left_on='entidad_municipio', right_on='entidad_municipio')
if len(cp) -len(cp_pop) == 0:
    print('Same shapes!')

cp_pop.rename(columns={'municipio_x': 'municipio', 'municipio_y': 'municipio_strip'}, inplace=True)
cp_pop.head()
# Out:
# Same shapes!
#    código                                       asentamiento          tipo  \
# 0    1000                                          San Angel       Colonia
# 1    1010                                          Los Alpes       Colonia
# 2    1020                                      Guadalupe Inn       Colonia
# 3    1028  Secretaria de Contraloría y Desarrollo Adminis...  Gran usuario
# 4    1029                                          INFONAVIT  Gran usuario
#
#         municipio               entidad_municipio           entidad  \
# 0  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 1  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 2  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 3  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
# 4  Álvaro Obregón  Ciudad de México-ÁlvaroObregón  Ciudad de México
#
#   municipio_strip  id_municipio  id_entidad  hombres  mujeres   total
# 0   ÁlvaroObregón          9010           9   355754   394228  749982
# 1   ÁlvaroObregón          9010           9   355754   394228  749982
# 2   ÁlvaroObregón          9010           9   355754   394228  749982
# 3   ÁlvaroObregón          9010           9   355754   394228  749982
# 4   ÁlvaroObregón          9010           9   355754   394228  749982

# %%
# Exporting to csv
if export_data == True:
    cp_pop.to_excel('output data/cp-population.xlsx')

# %% [markdown]
# #### 3.2.- Merging new dataframe with criminality dataframe

# %%
merged = pd.merge(cp_pop, df, on='id_municipio', how='left')

# %%
merged[merged['id_municipio'] == 1001]
# Out:
#         código asentamiento     tipo     municipio_x  \
# 75168    20000  Zona Centro  Colonia  Aguascalientes
# 75169    20000  Zona Centro  Colonia  Aguascalientes
# 75170    20000  Zona Centro  Colonia  Aguascalientes
# 75171    20000  Zona Centro  Colonia  Aguascalientes
# 75172    20000  Zona Centro  Colonia  Aguascalientes
# ...        ...          ...      ...             ...
# 101623   20399  El Turicate  Colonia  Aguascalientes
# 101624   20399  El Turicate  Colonia  Aguascalientes
# 101625   20399  El Turicate  Colonia  Aguascalientes
# 101626   20399  El Turicate  Colonia  Aguascalientes
# 101627   20399  El Turicate  Colonia  Aguascalientes
#
#                     entidad_municipio       entidad_x municipio_strip  \
# 75168   Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 75169   Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 75170   Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 75171   Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 75172   Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# ...                               ...             ...             ...
# 101623  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 101624  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 101625  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 101626  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
# 101627  Aguascalientes-Aguascalientes  Aguascalientes  Aguascalientes
#
#         id_municipio  id_entidad_x  hombres  mujeres   total  id_entidad_y  \
# 75168           1001             1   425731   451459  877190             1
# 75169           1001             1   425731   451459  877190             1
# 75170           1001             1   425731   451459  877190             1
# 75171           1001             1   425731   451459  877190             1
# 75172           1001             1   425731   451459  877190             1
# ...              ...           ...      ...      ...     ...           ...
# 101623          1001             1   425731   451459  877190             1
# 101624          1001             1   425731   451459  877190             1
# 101625          1001             1   425731   451459  877190             1
# 101626          1001             1   425731   451459  877190             1
# 101627          1001             1   425731   451459  877190             1
#
#              entidad_y     municipio_y  id_delito          delito  carpetas  \
# 75168   Aguascalientes  Aguascalientes       2000       Secuestro         0
# 75169   Aguascalientes  Aguascalientes       3000       Extorsión         5
# 75170   Aguascalientes  Aguascalientes       4300  Robo a negocio       115
# 75171   Aguascalientes  Aguascalientes       2000       Secuestro         1
# 75172   Aguascalientes  Aguascalientes       3000       Extorsión         2
# ...                ...             ...        ...             ...       ...
# 101623  Aguascalientes  Aguascalientes       3000       Extorsión         4
# 101624  Aguascalientes  Aguascalientes       4300  Robo a negocio       117
# 101625  Aguascalientes  Aguascalientes       2000       Secuestro         0
# 101626  Aguascalientes  Aguascalientes       3000       Extorsión         7
# 101627  Aguascalientes  Aguascalientes       4300  Robo a negocio       100
#
#              tasa      fecha
# 75168    0.000000 2021-01-01
# 75169    0.539210 2021-01-01
# 75170   12.401836 2021-01-01
# 75171    0.107842 2021-02-01
# 75172    0.215684 2021-02-01
# ...           ...        ...
# 101623   0.431368 2021-11-01
# 101624  12.617521 2021-11-01
# 101625   0.000000 2021-12-01
# 101626   0.754894 2021-12-01
# 101627  10.784205 2021-12-01
#
# [21132 rows x 20 columns]

# %%
# Grouping population information by id_municipio
_ = cp_pop.groupby('id_municipio').agg({'hombres': np.mean,
                                    'mujeres': np.mean,
                                    'total': np.mean})

# Joining
df_pop = pd.merge(df, _, on='id_municipio', how='left')

# %%
df_pop.head()
# Out:
#    id_entidad         entidad  id_municipio            municipio  id_delito  \
# 0           1  Aguascalientes          1007      Rincon De Romos       2000
# 1           1  Aguascalientes          1006  Pabellon De Arteaga       2000
# 2           1  Aguascalientes          1009             Tepezala       2000
# 3           1  Aguascalientes          1008   San Jose De Gracia       2000
# 4           1  Aguascalientes          1002             Asientos       2000
#
#       delito  carpetas  tasa      fecha  hombres  mujeres    total
# 0  Secuestro         0   0.0 2021-01-01  26693.0  27173.0  53866.0
# 1  Secuestro         0   0.0 2021-01-01  22490.0  23983.0  46473.0
# 2  Secuestro         0   0.0 2021-01-01  10197.0  10729.0  20926.0
# 3  Secuestro         0   0.0 2021-01-01   4276.0   4620.0   8896.0
# 4  Secuestro         0   0.0 2021-01-01  22745.0  23719.0  46464.0

# %% [markdown]
# ### 4.- Analysis

# %% [markdown]
# #### Select crimes

# %%
df_pop['delito'].unique()
# Out:
# array(['Secuestro', 'Extorsión', 'Robo a negocio'], dtype=object)

# %%
# Aggregating crimes by id_municipio
crimes_by_municipio = df_pop.groupby('id_municipio').agg({'carpetas': np.sum, 'total': np.mean})

# Generating crimes per 10000 people
crimes_by_municipio['crimes_10k'] = (crimes_by_municipio['carpetas'] / crimes_by_municipio['total']) * 10000

# Adding names of places
crimes_by_municipio = pd.merge(crimes_by_municipio, df[['entidad', 'municipio', 'id_municipio']],
                                how='left', on='id_municipio')

# %%
crimes_by_municipio = crimes_by_municipio.groupby('id_municipio').agg({'carpetas': np.mean, 'total': np.mean,
                                                                        'crimes_10k': np.mean, 'entidad': stats.mode,
                                                                        'municipio':stats.mode})

# %%
# Extracting only value without frequency
crimes_by_municipio['entidad'] = crimes_by_municipio['entidad'].apply(lambda x: x[0][0])
crimes_by_municipio['municipio'] = crimes_by_municipio['municipio'].apply(lambda x: x[0][0])

# %%
# Rearanging columns
crimes_by_municipio = crimes_by_municipio[['entidad', 'municipio', 'carpetas', 'total', 'crimes_10k']]

# %% [markdown]
# #### *Clean dataset aggregated by id_municipio*

# %%
# Clean dataset
crimes_by_municipio
# Out:
#                      entidad              municipio  carpetas     total  \
# id_municipio
# 1001          Aguascalientes         Aguascalientes      1358  877190.0
# 1002          Aguascalientes               Asientos        47   46464.0
# 1003          Aguascalientes               Calvillo        57   56048.0
# 1004          Aguascalientes                  Cosio        28   15577.0
# 1005          Aguascalientes            Jesus Maria       206  120405.0
# ...                      ...                    ...       ...       ...
# 32054              Zacatecas          Villa Hidalgo         4   19155.0
# 32055              Zacatecas             Villanueva         6   30240.0
# 32056              Zacatecas              Zacatecas       154  146147.0
# 32057              Zacatecas               Trancoso        11   19413.0
# 32058              Zacatecas  Santa Maria De La Paz         1    2656.0
#
#               crimes_10k
# id_municipio
# 1001           15.481253
# 1002           10.115358
# 1003           10.169854
# 1004           17.975220
# 1005           17.108924
# ...                  ...
# 32054           2.088228
# 32055           1.984127
# 32056          10.537336
# 32057           5.666306
# 32058           3.765060
#
# [2457 rows x 5 columns]

# %% [markdown]
# ### X.- Coordinates data set

# %%
# Imoorting location lat, lon dataset
locations = pd.read_excel('data/coordenadas_municipios.xlsx')
locations.head()
# Out:
#    id_municipio        lat         lon
# 0          1001  21.879823 -102.296047
# 1          1002  22.238317 -102.089275
# 2          1003  21.846907 -102.718751
# 3          1004  22.366409 -102.300044
# 4          1005  21.961273 -102.343416

# %% [markdown]
# #### Coinciding id values

# %%
# Creating list of unique ids in each dataset
unique_id_crimes_by_municipio = crimes_by_municipio.index.unique()
unique_id_locations = locations['id_municipio'].unique()

# Len of the lists
len_id_crimes_by_municipio = len(crimes_by_municipio.index.unique())
len_id_locations = len(locations['id_municipio'].unique())

for i in unique_id_crimes_by_municipio:
    if i not in unique_id_locations:
        print('id_municipio {} does not exist in locations data'.format(i))

print('No missing values')

if len_id_df == len_id_locations:
    print('Equal lenghts')

print('Ready to merge crimes and locations')
# Out:
# No missing values
# Ready to merge crimes and locations

# %% [markdown]
# #### Merging location information

# %%
crimes_by_municipio = crimes_by_municipio.merge(locations, how='left', on='id_municipio')
crimes_by_municipio
# Out:
#       id_municipio         entidad              municipio  carpetas     total  \
# 0             1001  Aguascalientes         Aguascalientes      1358  877190.0
# 1             1002  Aguascalientes               Asientos        47   46464.0
# 2             1003  Aguascalientes               Calvillo        57   56048.0
# 3             1004  Aguascalientes                  Cosio        28   15577.0
# 4             1005  Aguascalientes            Jesus Maria       206  120405.0
# ...            ...             ...                    ...       ...       ...
# 2452         32054       Zacatecas          Villa Hidalgo         4   19155.0
# 2453         32055       Zacatecas             Villanueva         6   30240.0
# 2454         32056       Zacatecas              Zacatecas       154  146147.0
# 2455         32057       Zacatecas               Trancoso        11   19413.0
# 2456         32058       Zacatecas  Santa Maria De La Paz         1    2656.0
#
#       crimes_10k        lat         lon
# 0      15.481253  21.879823 -102.296047
# 1      10.115358  22.238317 -102.089275
# 2      10.169854  21.846907 -102.718751
# 3      17.975220  22.366409 -102.300044
# 4      17.108924  21.961273 -102.343416
# ...          ...        ...         ...
# 2452    2.088228  22.357088 -101.712599
# 2453    1.984127  22.354259 -102.883726
# 2454   10.537336  22.776096 -102.571836
# 2455    5.666306  22.735389 -102.366038
# 2456    3.765060  21.512178 -103.407042
#
# [2457 rows x 8 columns]

# %% [markdown]
# #### Creating scales

# %%
data_map_municipios = crimes_by_municipio
# Dropping NAs
data_map_municipios = data_map_municipios.dropna()

limits = []

if limit_crimes == False:
    for x in range(0, 101, 20):
        limits.append(np.percentile(data_map_municipios['crimes_10k'], x))

    data_map_municipios['class'] = data_map_municipios['crimes_10k'].apply(lambda x:
                                            0 if (x >= limits[0] and x < limits[1])
                                            else
                                            (1 if (x >= limits[1] and x < limits[2]) 
                                            else 
                                            (2 if (x >= limits[2] and x < limits[3])
                                            else 
                                            (3 if (x >= limits[3] and x < limits[4])
                                            else 4))))
elif limit_crimes == True:
    for x in [0, 50, 63, 75, 87]:
        limits.append(np.percentile(data_map_municipios['crimes_10k'], x))

    data_map_municipios['class'] = data_map_municipios['crimes_10k'].apply(lambda x:
                                            0 if (x >= limits[0] and x < limits[1])
                                            else
                                            (1 if (x >= limits[1] and x < limits[2]) 
                                            else 
                                            (2 if (x >= limits[2] and x < limits[3])
                                            else 
                                            (3 if (x >= limits[3] and x < limits[4])
                                            else 4))))
# Out:
# <ipython-input-271-9f1f23917896>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_map_municipios['class'] = data_map_municipios['crimes_10k'].apply(lambda x:

# %% [markdown]
# #### Map

# %%
import folium

map = folium.Map(location = [20.693943, -100.985880], zoom_start=5.3)

data1 = data_map_municipios

data = data_map_municipios

for state in data1['entidad'].unique():
    data = data1[data1['entidad'] == state]

    colors = ['forestgreen', 'lime', 'yellow', 'lightcoral', 'firebrick']
    for cluster in range(5):
        color_cluster = colors[cluster]
        for point in range(len(data[data['class']==cluster])):
            folium.CircleMarker(location=[data.iloc[point]['lat'], data.iloc[point]['lon']],
            radius=8,
            color=color_cluster,
            fill_color=color_cluster,
            fill=True
            ).add_to(map)



map.save('map_colors.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_297f7590f59648dfa4c56f5ff67e4917%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_297f7590f59648dfa4c56f5ff67e4917%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_297f7590f59648dfa4c56f5ff67e4917%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_297f7590f59648dfa4c56f5ff67e4917%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B20.693943%2C%20-100.98588%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
data_map_municipios[data_map_municipios['class'] == 2]
# Out:
#       id_municipio               entidad            municipio  carpetas  \
# 33            5002  Coahuila de Zaragoza                Acuña        30
# 52            5021  Coahuila de Zaragoza            Nadadores         1
# 58            5027  Coahuila de Zaragoza         Ramos Arizpe        19
# 62            5031  Coahuila de Zaragoza     San Buenaventura         3
# 63            5032  Coahuila de Zaragoza  San Juan De Sabinas         6
# ...            ...                   ...                  ...       ...
# 2432         32034             Zacatecas  Nochistlan De Mejia         4
# 2449         32051             Zacatecas         Villa De Cos         5
# 2450         32052             Zacatecas         Villa Garcia         4
# 2452         32054             Zacatecas        Villa Hidalgo         4
# 2453         32055             Zacatecas           Villanueva         6
#
#          total  crimes_10k        lat         lon  class
# 33    147809.0    2.029646  29.330006 -100.978258      2
# 52      6614.0    1.511944  27.029031 -101.592023      2
# 58     92828.0    2.046796  25.543234 -100.950782      2
# 62     23587.0    1.271887  27.060257 -101.550029      2
# 63     43232.0    1.387861  27.929390 -101.303293      2
# ...        ...         ...        ...         ...    ...
# 2432   27750.0    1.441441  21.363253 -102.847165      2
# 2449   35252.0    1.418359  23.293893 -102.346888      2
# 2450   18745.0    2.133902  22.164898 -101.956319      2
# 2452   19155.0    2.088228  22.357088 -101.712599      2
# 2453   30240.0    1.984127  22.354259 -102.883726      2
#
# [294 rows x 9 columns]

# %%
# Exporting data map to excel
if export_data == True:
    data.to_csv('output data/data_map_mun.csv')

# %% [markdown]
# #### Aggregating on neighborhood scope

# %%
# Importing location of neighborhoods
locations = pd.read_excel('data/codigos-postales-mexico.xlsx')

# Cleaning
# Column names
locations.columns = [x.strip().lower() for x in locations.columns]
locations = locations.rename(columns={'código': 'código postal',
                                        'estado': 'entidad'})

# CDMX for DF
locations = locations.replace('Distrito Federal', 'Ciudad de México')

# Stripping municipio
locations['municipio_strip'] = locations['municipio'].replace(' ', '', regex=True)

# Generating municipio_entidad
locations['entidad_municipio'] = locations['entidad'] + '-' + locations['municipio']

# Converting into lowercase
locations['entidad_municipio'] = locations['entidad_municipio'].apply(lambda x: x.lower())

locations.head()
# Out:
#    código postal                                       asentamiento  \
# 0           1000                                          San Angel
# 1           1010                                          Los Alpes
# 2           1020                                      Guadalupe Inn
# 3           1028  Secretaria de Contraloría y Desarrollo Adminis...
# 4           1029                                          INFONAVIT
#
#            tipo       municipio            ciudad           entidad  \
# 0       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 1       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 2       Colonia  Álvaro Obregón  Ciudad de México  Ciudad de México
# 3  Gran usuario  Álvaro Obregón  Ciudad de México  Ciudad de México
# 4  Gran usuario  Álvaro Obregón  Ciudad de México  Ciudad de México
#
#   municipio_strip                entidad_municipio
# 0   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 1   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 2   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 3   ÁlvaroObregón  ciudad de méxico-álvaro obregón
# 4   ÁlvaroObregón  ciudad de méxico-álvaro obregón

# %% [markdown]
# ## HERE

# %%
# Cleaning data dataset
data = data_map_municipios[['id_municipio', 'entidad', 'municipio', 'carpetas', 'total',
       'crimes_10k', 'class']]

# Changing abbreviations
data = data.replace({'Dr.': 'Doctor',
                    'Gral.': 'General'},
                    regex=True)

data['entidad_municipio'] = data['entidad'] + '-' + data['municipio']

data['entidad_municipio'] = data['entidad_municipio'].apply(lambda x: x.lower())


data
# Out:
#       id_municipio         entidad              municipio  carpetas     total  \
# 0             1001  Aguascalientes         Aguascalientes      1358  877190.0
# 1             1002  Aguascalientes               Asientos        47   46464.0
# 2             1003  Aguascalientes               Calvillo        57   56048.0
# 3             1004  Aguascalientes                  Cosio        28   15577.0
# 4             1005  Aguascalientes            Jesus Maria       206  120405.0
# ...            ...             ...                    ...       ...       ...
# 2452         32054       Zacatecas          Villa Hidalgo         4   19155.0
# 2453         32055       Zacatecas             Villanueva         6   30240.0
# 2454         32056       Zacatecas              Zacatecas       154  146147.0
# 2455         32057       Zacatecas               Trancoso        11   19413.0
# 2456         32058       Zacatecas  Santa Maria De La Paz         1    2656.0
#
#       crimes_10k  class                entidad_municipio
# 0      15.481253      4    aguascalientes-aguascalientes
# 1      10.115358      4          aguascalientes-asientos
# 2      10.169854      4          aguascalientes-calvillo
# 3      17.975220      4             aguascalientes-cosio
# 4      17.108924      4       aguascalientes-jesus maria
# ...          ...    ...                              ...
# 2452    2.088228      2          zacatecas-villa hidalgo
# 2453    1.984127      2             zacatecas-villanueva
# 2454   10.537336      4              zacatecas-zacatecas
# 2455    5.666306      4               zacatecas-trancoso
# 2456    3.765060      3  zacatecas-santa maria de la paz
#
# [2455 rows x 8 columns]

# %% [markdown]
# Coinciding values entidad_municipio

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

#for i in unique_mun_locations:
 #   if i not in unique_mun_data:
  #      print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# entidad_municipio aguascalientes-cosio does not exist in locations data
# entidad_municipio aguascalientes-jesus maria does not exist in locations data
# entidad_municipio aguascalientes-pabellon de arteaga does not exist in locations data
# entidad_municipio aguascalientes-rincon de romos does not exist in locations data
# entidad_municipio aguascalientes-san jose de gracia does not exist in locations data
# entidad_municipio aguascalientes-tepezala does not exist in locations data
# entidad_municipio baja california sur-comondu does not exist in locations data
# entidad_municipio baja california sur-mulege does not exist in locations data
# entidad_municipio campeche-calkini does not exist in locations data
# entidad_municipio campeche-champoton does not exist in locations data
# entidad_municipio campeche-hecelchakan does not exist in locations data
# entidad_municipio campeche-hopelchen does not exist in locations data
# entidad_municipio campeche-escarcega does not exist in locations data
# entidad_municipio coahuila de zaragoza-cuatro cienegas does not exist in locations data
# entidad_municipio coahuila de zaragoza-jimenez does not exist in locations data
# entidad_municipio coahuila de zaragoza-juarez does not exist in locations data
# entidad_municipio coahuila de zaragoza-muzquiz does not exist in locations data
# entidad_municipio coahuila de zaragoza-torreon does not exist in locations data
# entidad_municipio coahuila de zaragoza-villa union does not exist in locations data
# entidad_municipio colima-armeria does not exist in locations data
# entidad_municipio colima-coquimatlan does not exist in locations data
# entidad_municipio colima-cuauhtemoc does not exist in locations data
# entidad_municipio colima-ixtlahuacan does not exist in locations data
# entidad_municipio colima-minatitlan does not exist in locations data
# entidad_municipio colima-tecoman does not exist in locations data
# entidad_municipio colima-villa de alvarez does not exist in locations data
# entidad_municipio chiapas-amatan does not exist in locations data
# entidad_municipio chiapas-berriozabal does not exist in locations data
# entidad_municipio chiapas-cacahoatan does not exist in locations data
# entidad_municipio chiapas-catazaja does not exist in locations data
# entidad_municipio chiapas-comitan de dominguez does not exist in locations data
# entidad_municipio chiapas-copainala does not exist in locations data
# entidad_municipio chiapas-chalchihuitan does not exist in locations data
# entidad_municipio chiapas-chenalho does not exist in locations data
# entidad_municipio chiapas-chicoasen does not exist in locations data
# entidad_municipio chiapas-chilon does not exist in locations data
# entidad_municipio chiapas-francisco leon does not exist in locations data
# entidad_municipio chiapas-huehuetan does not exist in locations data
# entidad_municipio chiapas-huixtan does not exist in locations data
# entidad_municipio chiapas-huitiupan does not exist in locations data
# entidad_municipio chiapas-ixhuatan does not exist in locations data
# entidad_municipio chiapas-ixtacomitan does not exist in locations data
# entidad_municipio chiapas-juarez does not exist in locations data
# entidad_municipio chiapas-larrainzar does not exist in locations data
# entidad_municipio chiapas-mazatan does not exist in locations data
# entidad_municipio chiapas-nicolas ruiz does not exist in locations data
# entidad_municipio chiapas-ostuacan does not exist in locations data
# entidad_municipio chiapas-pantelho does not exist in locations data
# entidad_municipio chiapas-villa comaltitlan does not exist in locations data
# entidad_municipio chiapas-pueblo nuevo solistahuacan does not exist in locations data
# entidad_municipio chiapas-rayon does not exist in locations data
# entidad_municipio chiapas-san cristobal de las casas does not exist in locations data
# entidad_municipio chiapas-sitala does not exist in locations data
# entidad_municipio chiapas-soyalo does not exist in locations data
# entidad_municipio chiapas-tecpatan does not exist in locations data
# entidad_municipio chiapas-tonala does not exist in locations data
# entidad_municipio chiapas-tumbala does not exist in locations data
# entidad_municipio chiapas-tuxtla gutierrez does not exist in locations data
# entidad_municipio chiapas-tuzantan does not exist in locations data
# entidad_municipio chiapas-union juarez does not exist in locations data
# entidad_municipio chiapas-yajalon does not exist in locations data
# entidad_municipio chiapas-zinacantan does not exist in locations data
# entidad_municipio chiapas-benemerito de las americas does not exist in locations data
# entidad_municipio chiapas-marques de comillas does not exist in locations data
# entidad_municipio chiapas-san andres duraznal does not exist in locations data
# entidad_municipio chihuahua-aquiles serdan does not exist in locations data
# entidad_municipio chihuahua-ascension does not exist in locations data
# entidad_municipio chihuahua-bachiniva does not exist in locations data
# entidad_municipio chihuahua-carichi does not exist in locations data
# entidad_municipio chihuahua-cuauhtemoc does not exist in locations data
# entidad_municipio chihuahua-chinipas does not exist in locations data
# entidad_municipio chihuahua-doctor belisario dominguez does not exist in locations data
# entidad_municipio chihuahua-gomez farias does not exist in locations data
# entidad_municipio chihuahua-huejotitan does not exist in locations data
# entidad_municipio chihuahua-jimenez does not exist in locations data
# entidad_municipio chihuahua-juarez does not exist in locations data
# entidad_municipio chihuahua-lopez does not exist in locations data
# entidad_municipio chihuahua-matachi does not exist in locations data
# entidad_municipio chihuahua-santa barbara does not exist in locations data
# entidad_municipio chihuahua-satevo does not exist in locations data
# entidad_municipio chihuahua-temosachic does not exist in locations data
# entidad_municipio ciudad de méxico-coyoacan does not exist in locations data
# entidad_municipio ciudad de méxico-alvaro obregon does not exist in locations data
# entidad_municipio ciudad de méxico-tlahuac does not exist in locations data
# entidad_municipio ciudad de méxico-benito juarez does not exist in locations data
# entidad_municipio ciudad de méxico-cuauhtemoc does not exist in locations data
# entidad_municipio durango-canatlan does not exist in locations data
# entidad_municipio durango-cuencame does not exist in locations data
# entidad_municipio durango-general simon bolivar does not exist in locations data
# entidad_municipio durango-gomez palacio does not exist in locations data
# entidad_municipio durango-guanacevi does not exist in locations data
# entidad_municipio durango-inde does not exist in locations data
# entidad_municipio durango-mapimi does not exist in locations data
# entidad_municipio durango-otaez does not exist in locations data
# entidad_municipio durango-panuco de coronado does not exist in locations data
# entidad_municipio durango-peñon blanco does not exist in locations data
# entidad_municipio durango-san juan del rio does not exist in locations data
# entidad_municipio durango-suchil does not exist in locations data
# entidad_municipio guanajuato-acambaro does not exist in locations data
# entidad_municipio guanajuato-cueramaro does not exist in locations data
# entidad_municipio guanajuato-huanimaro does not exist in locations data
# entidad_municipio guanajuato-jerecuaro does not exist in locations data
# entidad_municipio guanajuato-leon does not exist in locations data
# entidad_municipio guanajuato-moroleon does not exist in locations data
# entidad_municipio guanajuato-penjamo does not exist in locations data
# entidad_municipio guanajuato-purisima del rincon does not exist in locations data
# entidad_municipio guanajuato-san diego de la union does not exist in locations data
# entidad_municipio guanajuato-san francisco del rincon does not exist in locations data
# entidad_municipio guanajuato-san jose iturbide does not exist in locations data
# entidad_municipio guanajuato-santiago maravatio does not exist in locations data
# entidad_municipio guanajuato-silao does not exist in locations data
# entidad_municipio guanajuato-villagran does not exist in locations data
# entidad_municipio guanajuato-xichu does not exist in locations data
# entidad_municipio guerrero-acapulco de juarez does not exist in locations data
# entidad_municipio guerrero-ajuchitlan del progreso does not exist in locations data
# entidad_municipio guerrero-atenango del rio does not exist in locations data
# entidad_municipio guerrero-atoyac de alvarez does not exist in locations data
# entidad_municipio guerrero-azoyu does not exist in locations data
# entidad_municipio guerrero-benito juarez does not exist in locations data
# entidad_municipio guerrero-buenavista de cuellar does not exist in locations data
# entidad_municipio guerrero-coahuayutla de jose maria izazaga does not exist in locations data
# entidad_municipio guerrero-coyuca de benitez does not exist in locations data
# entidad_municipio guerrero-coyuca de catalan does not exist in locations data
# entidad_municipio guerrero-cualac does not exist in locations data
# entidad_municipio guerrero-cutzamala de pinzon does not exist in locations data
# entidad_municipio guerrero-chilapa de alvarez does not exist in locations data
# entidad_municipio guerrero-huamuxtitlan does not exist in locations data
# entidad_municipio guerrero-ixcateopan de cuauhtemoc does not exist in locations data
# entidad_municipio guerrero-martir de cuilapan does not exist in locations data
# entidad_municipio guerrero-metlatonoc does not exist in locations data
# entidad_municipio guerrero-mochitlan does not exist in locations data
# entidad_municipio guerrero-olinala does not exist in locations data
# entidad_municipio guerrero-petatlan does not exist in locations data
# entidad_municipio guerrero-san luis acatlan does not exist in locations data
# entidad_municipio guerrero-taxco de alarcon does not exist in locations data
# entidad_municipio guerrero-tecpan de galeana does not exist in locations data
# entidad_municipio guerrero-la union de isidoro montes de oca does not exist in locations data
# entidad_municipio guerrero-xalpatlahuac does not exist in locations data
# entidad_municipio guerrero-xochihuehuetlan does not exist in locations data
# entidad_municipio guerrero-zapotitlan tablas does not exist in locations data
# entidad_municipio guerrero-zirandaro does not exist in locations data
# entidad_municipio guerrero-jose joaquin de herrera does not exist in locations data
# entidad_municipio guerrero-juchitan does not exist in locations data
# entidad_municipio hidalgo-acatlan does not exist in locations data
# entidad_municipio hidalgo-acaxochitlan does not exist in locations data
# entidad_municipio hidalgo-chapulhuacan does not exist in locations data
# entidad_municipio hidalgo-eloxochitlan does not exist in locations data
# entidad_municipio hidalgo-jaltocan does not exist in locations data
# entidad_municipio hidalgo-juarez hidalgo does not exist in locations data
# entidad_municipio hidalgo-san agustin metzquititlan does not exist in locations data
# entidad_municipio hidalgo-metztitlan does not exist in locations data
# entidad_municipio hidalgo-la mision does not exist in locations data
# entidad_municipio hidalgo-mixquiahuala de juarez does not exist in locations data
# entidad_municipio hidalgo-nicolas flores does not exist in locations data
# entidad_municipio hidalgo-nopala de villagran does not exist in locations data
# entidad_municipio hidalgo-omitlan de juarez does not exist in locations data
# entidad_municipio hidalgo-san felipe orizatlan does not exist in locations data
# entidad_municipio hidalgo-progreso de obregon does not exist in locations data
# entidad_municipio hidalgo-san agustin tlaxiaca does not exist in locations data
# entidad_municipio hidalgo-tepehuacan de guerrero does not exist in locations data
# entidad_municipio hidalgo-tepeji del rio de ocampo does not exist in locations data
# entidad_municipio hidalgo-tepetitlan does not exist in locations data
# entidad_municipio hidalgo-xochicoatlan does not exist in locations data
# entidad_municipio hidalgo-zacualtipan de angeles does not exist in locations data
# entidad_municipio hidalgo-zapotlan de juarez does not exist in locations data
# entidad_municipio hidalgo-zimapan does not exist in locations data
# entidad_municipio jalisco-acatlan de juarez does not exist in locations data
# entidad_municipio jalisco-amatitan does not exist in locations data
# entidad_municipio jalisco-autlan de navarro does not exist in locations data
# entidad_municipio jalisco-ayotlan does not exist in locations data
# entidad_municipio jalisco-cihuatlan does not exist in locations data
# entidad_municipio jalisco-zapotlan el grande does not exist in locations data
# entidad_municipio jalisco-colotlan does not exist in locations data
# entidad_municipio jalisco-concepcion de buenos aires does not exist in locations data
# entidad_municipio jalisco-cuautitlan de garcia barragan does not exist in locations data
# entidad_municipio jalisco-cuquio does not exist in locations data
# entidad_municipio jalisco-chimaltitan does not exist in locations data
# entidad_municipio jalisco-chiquilistlan does not exist in locations data
# entidad_municipio jalisco-encarnacion de diaz does not exist in locations data
# entidad_municipio jalisco-etzatlan does not exist in locations data
# entidad_municipio jalisco-huejucar does not exist in locations data
# entidad_municipio jalisco-ixtlahuacan de los membrillos does not exist in locations data
# entidad_municipio jalisco-ixtlahuacan del rio does not exist in locations data
# entidad_municipio jalisco-jalostotitlan does not exist in locations data
# entidad_municipio jalisco-jesus maria does not exist in locations data
# entidad_municipio jalisco-jilotlan de los dolores does not exist in locations data
# entidad_municipio jalisco-juanacatlan does not exist in locations data
# entidad_municipio jalisco-juchitlan does not exist in locations data
# entidad_municipio jalisco-el limon does not exist in locations data
# entidad_municipio jalisco-santa maria del oro does not exist in locations data
# entidad_municipio jalisco-mexticacan does not exist in locations data
# entidad_municipio jalisco-mixtlan does not exist in locations data
# entidad_municipio jalisco-ocotlan does not exist in locations data
# entidad_municipio jalisco-poncitlan does not exist in locations data
# entidad_municipio jalisco-villa purificacion does not exist in locations data
# entidad_municipio jalisco-san cristobal de la barranca does not exist in locations data
# entidad_municipio jalisco-san diego de alejandria does not exist in locations data
# entidad_municipio jalisco-san julian does not exist in locations data
# entidad_municipio jalisco-san martin de bolaños does not exist in locations data
# entidad_municipio jalisco-san martin hidalgo does not exist in locations data
# entidad_municipio jalisco-gomez farias does not exist in locations data
# entidad_municipio jalisco-san sebastian del oeste does not exist in locations data
# entidad_municipio jalisco-santa maria de los angeles does not exist in locations data
# entidad_municipio jalisco-tecalitlan does not exist in locations data
# entidad_municipio jalisco-tecolotlan does not exist in locations data
# entidad_municipio jalisco-tenamaxtlan does not exist in locations data
# entidad_municipio jalisco-teocuitatlan de corona does not exist in locations data
# entidad_municipio jalisco-tepatitlan de morelos does not exist in locations data
# entidad_municipio jalisco-teuchitlan does not exist in locations data
# entidad_municipio jalisco-tizapan el alto does not exist in locations data
# entidad_municipio jalisco-tlajomulco de zuñiga does not exist in locations data
# entidad_municipio jalisco-tlaquepaque does not exist in locations data
# entidad_municipio jalisco-toliman does not exist in locations data
# entidad_municipio jalisco-tomatlan does not exist in locations data
# entidad_municipio jalisco-tonala does not exist in locations data
# entidad_municipio jalisco-tototlan does not exist in locations data
# entidad_municipio jalisco-union de san antonio does not exist in locations data
# entidad_municipio jalisco-union de tula does not exist in locations data
# entidad_municipio jalisco-valle de juarez does not exist in locations data
# entidad_municipio jalisco-cañadas de obregon does not exist in locations data
# entidad_municipio jalisco-yahualica de gonzalez gallo does not exist in locations data
# entidad_municipio jalisco-zapotitlan de vadillo does not exist in locations data
# entidad_municipio jalisco-zapotlan del rey does not exist in locations data
# entidad_municipio méxico-acambay does not exist in locations data
# entidad_municipio méxico-almoloya de juarez does not exist in locations data
# entidad_municipio méxico-almoloya del rio does not exist in locations data
# entidad_municipio méxico-atizapan does not exist in locations data
# entidad_municipio méxico-atizapan de zaragoza does not exist in locations data
# entidad_municipio méxico-coacalco de berriozabal does not exist in locations data
# entidad_municipio méxico-cocotitlan does not exist in locations data
# entidad_municipio méxico-cuautitlan does not exist in locations data
# entidad_municipio méxico-chimalhuacan does not exist in locations data
# entidad_municipio méxico-jocotitlan does not exist in locations data
# entidad_municipio méxico-naucalpan de juarez does not exist in locations data
# entidad_municipio méxico-nezahualcoyotl does not exist in locations data
# entidad_municipio méxico-nicolas romero does not exist in locations data
# entidad_municipio méxico-polotitlan does not exist in locations data
# entidad_municipio méxico-rayon does not exist in locations data
# entidad_municipio méxico-san martin de las piramides does not exist in locations data
# entidad_municipio méxico-san simon de guerrero does not exist in locations data
# entidad_municipio méxico-santo tomas does not exist in locations data
# entidad_municipio méxico-soyaniquilpan de juarez does not exist in locations data
# entidad_municipio méxico-tecamac does not exist in locations data
# entidad_municipio méxico-teotihuacan does not exist in locations data
# entidad_municipio méxico-tepotzotlan does not exist in locations data
# entidad_municipio méxico-texcaltitlan does not exist in locations data
# entidad_municipio méxico-tultitlan does not exist in locations data
# entidad_municipio méxico-villa del carbon does not exist in locations data
# entidad_municipio méxico-xonacatlan does not exist in locations data
# entidad_municipio méxico-zumpahuacan does not exist in locations data
# entidad_municipio méxico-cuautitlan izcalli does not exist in locations data
# entidad_municipio méxico-san jose del rincon does not exist in locations data
# entidad_municipio michoacán de ocampo-alvaro obregon does not exist in locations data
# entidad_municipio michoacán de ocampo-apatzingan does not exist in locations data
# entidad_municipio michoacán de ocampo-caracuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-coalcoman de vazquez pallares does not exist in locations data
# entidad_municipio michoacán de ocampo-copandaro does not exist in locations data
# entidad_municipio michoacán de ocampo-cheran does not exist in locations data
# entidad_municipio michoacán de ocampo-chucandiro does not exist in locations data
# entidad_municipio michoacán de ocampo-erongaricuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-ixtlan does not exist in locations data
# entidad_municipio michoacán de ocampo-jimenez does not exist in locations data
# entidad_municipio michoacán de ocampo-juarez does not exist in locations data
# entidad_municipio michoacán de ocampo-maravatio does not exist in locations data
# entidad_municipio michoacán de ocampo-lazaro cardenas does not exist in locations data
# entidad_municipio michoacán de ocampo-mugica does not exist in locations data
# entidad_municipio michoacán de ocampo-nocupetaro does not exist in locations data
# entidad_municipio michoacán de ocampo-numaran does not exist in locations data
# entidad_municipio michoacán de ocampo-pajacuaran does not exist in locations data
# entidad_municipio michoacán de ocampo-panindicuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-paracuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-patzcuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-periban does not exist in locations data
# entidad_municipio michoacán de ocampo-purepero does not exist in locations data
# entidad_municipio michoacán de ocampo-puruandiro does not exist in locations data
# entidad_municipio michoacán de ocampo-querendaro does not exist in locations data
# entidad_municipio michoacán de ocampo-cojumatlan de regules does not exist in locations data
# entidad_municipio michoacán de ocampo-tacambaro does not exist in locations data
# entidad_municipio michoacán de ocampo-tancitaro does not exist in locations data
# entidad_municipio michoacán de ocampo-tangancicuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-tarimbaro does not exist in locations data
# entidad_municipio michoacán de ocampo-tingüindin does not exist in locations data
# entidad_municipio michoacán de ocampo-tiquicheo de nicolas romero does not exist in locations data
# entidad_municipio michoacán de ocampo-tumbiscatio does not exist in locations data
# entidad_municipio michoacán de ocampo-yurecuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-zinaparo does not exist in locations data
# entidad_municipio michoacán de ocampo-zinapecuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-zitacuaro does not exist in locations data
# entidad_municipio michoacán de ocampo-jose sixto verduzco does not exist in locations data
# entidad_municipio morelos-coatlan del rio does not exist in locations data
# entidad_municipio morelos-miacatlan does not exist in locations data
# entidad_municipio morelos-tepoztlan does not exist in locations data
# entidad_municipio morelos-tetela del volcan does not exist in locations data
# entidad_municipio morelos-tlaltizapan does not exist in locations data
# entidad_municipio nayarit-ahuacatlan does not exist in locations data
# entidad_municipio nayarit-amatlan de cañas does not exist in locations data
# entidad_municipio nayarit-ixtlan del rio does not exist in locations data
# entidad_municipio nayarit-ruiz does not exist in locations data
# entidad_municipio nayarit-santa maria del oro does not exist in locations data
# entidad_municipio nayarit-bahia de banderas does not exist in locations data
# entidad_municipio nuevo león-anahuac does not exist in locations data
# entidad_municipio nuevo león-cadereyta jimenez does not exist in locations data
# entidad_municipio nuevo león-carmen does not exist in locations data
# entidad_municipio nuevo león-cienega de flores does not exist in locations data
# entidad_municipio nuevo león-doctor gonzalez does not exist in locations data
# entidad_municipio nuevo león-garcia does not exist in locations data
# entidad_municipio nuevo león-san pedro garza garcia does not exist in locations data
# entidad_municipio nuevo león-general teran does not exist in locations data
# entidad_municipio nuevo león-juarez does not exist in locations data
# entidad_municipio nuevo león-marin does not exist in locations data
# entidad_municipio nuevo león-paras does not exist in locations data
# entidad_municipio nuevo león-pesqueria does not exist in locations data
# entidad_municipio nuevo león-san nicolas de los garza does not exist in locations data
# entidad_municipio oaxaca-acatlan de perez figueroa does not exist in locations data
# entidad_municipio oaxaca-asuncion cacalotepec does not exist in locations data
# entidad_municipio oaxaca-asuncion cuyotepeji does not exist in locations data
# entidad_municipio oaxaca-asuncion ixtaltepec does not exist in locations data
# entidad_municipio oaxaca-asuncion nochixtlan does not exist in locations data
# entidad_municipio oaxaca-asuncion ocotlan does not exist in locations data
# entidad_municipio oaxaca-asuncion tlacolulita does not exist in locations data
# entidad_municipio oaxaca-calihuala does not exist in locations data
# entidad_municipio oaxaca-cienega de zimatlan does not exist in locations data
# entidad_municipio oaxaca-coicoyan de las flores does not exist in locations data
# entidad_municipio oaxaca-la compañia does not exist in locations data
# entidad_municipio oaxaca-concepcion buenavista does not exist in locations data
# entidad_municipio oaxaca-concepcion papalo does not exist in locations data
# entidad_municipio oaxaca-cuilapam de guerrero does not exist in locations data
# entidad_municipio oaxaca-chiquihuitlan de benito juarez does not exist in locations data
# entidad_municipio oaxaca-eloxochitlan de flores magon does not exist in locations data
# entidad_municipio oaxaca-tamazulapam del espiritu santo does not exist in locations data
# entidad_municipio oaxaca-guadalupe de ramirez does not exist in locations data
# entidad_municipio oaxaca-guelatao de juarez does not exist in locations data
# entidad_municipio oaxaca-heroica ciudad de huajuapan de leon does not exist in locations data
# entidad_municipio oaxaca-huautla de jimenez does not exist in locations data
# entidad_municipio oaxaca-ixtlan de juarez does not exist in locations data
# entidad_municipio oaxaca-heroica ciudad de juchitan de zaragoza does not exist in locations data
# entidad_municipio oaxaca-santa magdalena jicotlan does not exist in locations data
# entidad_municipio oaxaca-magdalena ocotlan does not exist in locations data
# entidad_municipio oaxaca-magdalena tequisistlan does not exist in locations data
# entidad_municipio oaxaca-magdalena zahuatlan does not exist in locations data
# entidad_municipio oaxaca-mariscala de juarez does not exist in locations data
# entidad_municipio oaxaca-martires de tacubaya does not exist in locations data
# entidad_municipio oaxaca-matias romero avendaño does not exist in locations data
# entidad_municipio oaxaca-mazatlan villa de flores does not exist in locations data
# entidad_municipio oaxaca-miahuatlan de porfirio diaz does not exist in locations data
# entidad_municipio oaxaca-mixistlan de la reforma does not exist in locations data
# entidad_municipio oaxaca-oaxaca de juarez does not exist in locations data
# entidad_municipio oaxaca-ocotlan de morelos does not exist in locations data
# entidad_municipio oaxaca-san jose del progreso does not exist in locations data
# entidad_municipio oaxaca-rojas de cuauhtemoc does not exist in locations data
# entidad_municipio oaxaca-san agustin amatengo does not exist in locations data
# entidad_municipio oaxaca-san agustin atenango does not exist in locations data
# entidad_municipio oaxaca-san agustin chayuco does not exist in locations data
# entidad_municipio oaxaca-san agustin de las juntas does not exist in locations data
# entidad_municipio oaxaca-san agustin etla does not exist in locations data
# entidad_municipio oaxaca-san agustin loxicha does not exist in locations data
# entidad_municipio oaxaca-san agustin tlacotepec does not exist in locations data
# entidad_municipio oaxaca-san agustin yatareni does not exist in locations data
# entidad_municipio oaxaca-san andres cabecera nueva does not exist in locations data
# entidad_municipio oaxaca-san andres dinicuiti does not exist in locations data
# entidad_municipio oaxaca-san andres huaxpaltepec does not exist in locations data
# entidad_municipio oaxaca-san andres huayapam does not exist in locations data
# entidad_municipio oaxaca-san andres ixtlahuaca does not exist in locations data
# entidad_municipio oaxaca-san andres lagunas does not exist in locations data
# entidad_municipio oaxaca-san andres nuxiño does not exist in locations data
# entidad_municipio oaxaca-san andres paxtlan does not exist in locations data
# entidad_municipio oaxaca-san andres sinaxtla does not exist in locations data
# entidad_municipio oaxaca-san andres solaga does not exist in locations data
# entidad_municipio oaxaca-san andres teotilalpam does not exist in locations data
# entidad_municipio oaxaca-san andres tepetlapa does not exist in locations data
# entidad_municipio oaxaca-san andres yaa does not exist in locations data
# entidad_municipio oaxaca-san andres zabache does not exist in locations data
# entidad_municipio oaxaca-san andres zautla does not exist in locations data
# entidad_municipio oaxaca-san antonio nanahuatipam does not exist in locations data
# entidad_municipio oaxaca-san baltazar chichicapam does not exist in locations data
# entidad_municipio oaxaca-san bartolome ayautla does not exist in locations data
# entidad_municipio oaxaca-san bartolome loxicha does not exist in locations data
# entidad_municipio oaxaca-san bartolome quialana does not exist in locations data
# entidad_municipio oaxaca-san bartolome yucuañe does not exist in locations data
# entidad_municipio oaxaca-san bartolome zoogocho does not exist in locations data
# entidad_municipio oaxaca-san cristobal amatlan does not exist in locations data
# entidad_municipio oaxaca-san cristobal amoltepec does not exist in locations data
# entidad_municipio oaxaca-san cristobal lachirioag does not exist in locations data
# entidad_municipio oaxaca-san cristobal suchixtlahuaca does not exist in locations data
# entidad_municipio oaxaca-san dionisio ocotlan does not exist in locations data
# entidad_municipio oaxaca-san felipe jalapa de diaz does not exist in locations data
# entidad_municipio oaxaca-san felipe tejalapam does not exist in locations data
# entidad_municipio oaxaca-san francisco cahuacua does not exist in locations data
# entidad_municipio oaxaca-san francisco chindua does not exist in locations data
# entidad_municipio oaxaca-san francisco huehuetlan does not exist in locations data
# entidad_municipio oaxaca-san francisco ixhuatan does not exist in locations data
# entidad_municipio oaxaca-san francisco lachigolo does not exist in locations data
# entidad_municipio oaxaca-san ildefonso amatlan does not exist in locations data
# entidad_municipio oaxaca-san jeronimo coatlan does not exist in locations data
# entidad_municipio oaxaca-san jeronimo silacayoapilla does not exist in locations data
# entidad_municipio oaxaca-san jeronimo sosola does not exist in locations data
# entidad_municipio oaxaca-san jeronimo taviche does not exist in locations data
# entidad_municipio oaxaca-san jeronimo tecoatl does not exist in locations data
# entidad_municipio oaxaca-san jose ayuquila does not exist in locations data
# entidad_municipio oaxaca-san jose chiltepec does not exist in locations data
# entidad_municipio oaxaca-san jose del peñasco does not exist in locations data
# entidad_municipio oaxaca-san jose estancia grande does not exist in locations data
# entidad_municipio oaxaca-san jose independencia does not exist in locations data
# entidad_municipio oaxaca-san jose lachiguiri does not exist in locations data
# entidad_municipio oaxaca-san jose tenango does not exist in locations data
# entidad_municipio oaxaca-animas trujano does not exist in locations data
# entidad_municipio oaxaca-san juan bautista cuicatlan does not exist in locations data
# entidad_municipio oaxaca-san juan bautista jayacatlan does not exist in locations data
# entidad_municipio oaxaca-san juan coatzospam does not exist in locations data
# entidad_municipio oaxaca-san juan cotzocon does not exist in locations data
# entidad_municipio oaxaca-san juan chicomezuchil does not exist in locations data
# entidad_municipio oaxaca-san juan del rio does not exist in locations data
# entidad_municipio oaxaca-san juan guelavia does not exist in locations data
# entidad_municipio oaxaca-san juan de los cues does not exist in locations data
# entidad_municipio oaxaca-san juan mazatlan does not exist in locations data
# entidad_municipio oaxaca-san juan ñumi does not exist in locations data
# entidad_municipio oaxaca-san juan tabaa does not exist in locations data
# entidad_municipio oaxaca-san juan yaee does not exist in locations data
# entidad_municipio oaxaca-san lorenzo texmelucan does not exist in locations data
# entidad_municipio oaxaca-san lucas camotlan does not exist in locations data
# entidad_municipio oaxaca-san lucas ojitlan does not exist in locations data
# entidad_municipio oaxaca-san lucas quiavini does not exist in locations data
# entidad_municipio oaxaca-san lucas zoquiapam does not exist in locations data
# entidad_municipio oaxaca-san luis amatlan does not exist in locations data
# entidad_municipio oaxaca-san martin de los cansecos does not exist in locations data
# entidad_municipio oaxaca-san martin huamelulpam does not exist in locations data
# entidad_municipio oaxaca-san martin itunyoso does not exist in locations data
# entidad_municipio oaxaca-san martin lachila does not exist in locations data
# entidad_municipio oaxaca-san martin peras does not exist in locations data
# entidad_municipio oaxaca-san martin tilcajete does not exist in locations data
# entidad_municipio oaxaca-san martin toxpalan does not exist in locations data
# entidad_municipio oaxaca-san martin zacatepec does not exist in locations data
# entidad_municipio oaxaca-capulalpam de mendez does not exist in locations data
# entidad_municipio oaxaca-san mateo yoloxochitlan does not exist in locations data
# entidad_municipio oaxaca-san mateo nejapam does not exist in locations data
# entidad_municipio oaxaca-san mateo rio hondo does not exist in locations data
# entidad_municipio oaxaca-san miguel ahuehuetitlan does not exist in locations data
# entidad_municipio oaxaca-san miguel aloapam does not exist in locations data
# entidad_municipio oaxaca-san miguel amatitlan does not exist in locations data
# entidad_municipio oaxaca-san miguel amatlan does not exist in locations data
# entidad_municipio oaxaca-san miguel coatlan does not exist in locations data
# entidad_municipio oaxaca-san miguel del rio does not exist in locations data
# entidad_municipio oaxaca-san miguel tecomatlan does not exist in locations data
# entidad_municipio oaxaca-san miguel tilquiapam does not exist in locations data
# entidad_municipio oaxaca-san nicolas does not exist in locations data
# entidad_municipio oaxaca-san nicolas hidalgo does not exist in locations data
# entidad_municipio oaxaca-san pablo coatlan does not exist in locations data
# entidad_municipio oaxaca-san pedro apostol does not exist in locations data
# entidad_municipio oaxaca-san pedro coxcaltepec cantaros does not exist in locations data
# entidad_municipio oaxaca-san pedro ixcatlan does not exist in locations data
# entidad_municipio oaxaca-san pedro jicayan does not exist in locations data
# entidad_municipio oaxaca-san pedro martir does not exist in locations data
# entidad_municipio oaxaca-san pedro martir quiechapa does not exist in locations data
# entidad_municipio oaxaca-san pedro martir yucuxaco does not exist in locations data
# entidad_municipio oaxaca-san pedro sochiapam does not exist in locations data
# entidad_municipio oaxaca-san pedro tidaa does not exist in locations data
# entidad_municipio oaxaca-san pedro totolapam does not exist in locations data
# entidad_municipio oaxaca-san pedro yolox does not exist in locations data
# entidad_municipio oaxaca-san sebastian abasolo does not exist in locations data
# entidad_municipio oaxaca-san sebastian coatlan does not exist in locations data
# entidad_municipio oaxaca-san sebastian ixcapa does not exist in locations data
# entidad_municipio oaxaca-san sebastian nicananduta does not exist in locations data
# entidad_municipio oaxaca-san sebastian rio hondo does not exist in locations data
# entidad_municipio oaxaca-san sebastian tecomaxtlahuaca does not exist in locations data
# entidad_municipio oaxaca-san sebastian teitipac does not exist in locations data
# entidad_municipio oaxaca-san sebastian tutla does not exist in locations data
# entidad_municipio oaxaca-san simon almolongas does not exist in locations data
# entidad_municipio oaxaca-san simon zahuatlan does not exist in locations data
# entidad_municipio oaxaca-santa ana cuauhtemoc does not exist in locations data
# entidad_municipio oaxaca-santa catalina quieri does not exist in locations data
# entidad_municipio oaxaca-santa catarina mechoacan does not exist in locations data
# entidad_municipio oaxaca-santa catarina quiane does not exist in locations data
# entidad_municipio oaxaca-santa catarina ticua does not exist in locations data
# entidad_municipio oaxaca-santa catarina yosonotu does not exist in locations data
# entidad_municipio oaxaca-santa cruz xoxocotlan does not exist in locations data
# entidad_municipio oaxaca-santa ines del monte does not exist in locations data
# entidad_municipio oaxaca-santa ines yatzeche does not exist in locations data
# entidad_municipio oaxaca-santa lucia del camino does not exist in locations data
# entidad_municipio oaxaca-santa lucia miahuatlan does not exist in locations data
# entidad_municipio oaxaca-santa lucia monteverde does not exist in locations data
# entidad_municipio oaxaca-santa lucia ocotlan does not exist in locations data
# entidad_municipio oaxaca-santa maria alotepec does not exist in locations data
# entidad_municipio oaxaca-santa maria apazco does not exist in locations data
# entidad_municipio oaxaca-santa maria la asuncion does not exist in locations data
# entidad_municipio oaxaca-santa maria atzompa does not exist in locations data
# entidad_municipio oaxaca-santa maria camotlan does not exist in locations data
# entidad_municipio oaxaca-santa maria colotepec does not exist in locations data
# entidad_municipio oaxaca-santa maria cortijo does not exist in locations data
# entidad_municipio oaxaca-santa maria coyotepec does not exist in locations data
# entidad_municipio oaxaca-santa maria chachoapam does not exist in locations data
# entidad_municipio oaxaca-villa de chilapa de diaz does not exist in locations data
# entidad_municipio oaxaca-santa maria chilchotla does not exist in locations data
# entidad_municipio oaxaca-santa maria chimalapa does not exist in locations data
# entidad_municipio oaxaca-santa maria del rosario does not exist in locations data
# entidad_municipio oaxaca-santa maria del tule does not exist in locations data
# entidad_municipio oaxaca-santa maria ecatepec does not exist in locations data
# entidad_municipio oaxaca-santa maria guelace does not exist in locations data
# entidad_municipio oaxaca-santa maria guienagati does not exist in locations data
# entidad_municipio oaxaca-santa maria huatulco does not exist in locations data
# entidad_municipio oaxaca-santa maria huazolotitlan does not exist in locations data
# entidad_municipio oaxaca-santa maria ipalapa does not exist in locations data
# entidad_municipio oaxaca-santa maria ixcatlan does not exist in locations data
# entidad_municipio oaxaca-santa maria jacatepec does not exist in locations data
# entidad_municipio oaxaca-santa maria jalapa del marques does not exist in locations data
# entidad_municipio oaxaca-santa maria jaltianguis does not exist in locations data
# entidad_municipio oaxaca-santa maria lachixio does not exist in locations data
# entidad_municipio oaxaca-santa maria mixtequilla does not exist in locations data
# entidad_municipio oaxaca-santa maria nativitas does not exist in locations data
# entidad_municipio oaxaca-santa maria nduayaco does not exist in locations data
# entidad_municipio oaxaca-santa maria ozolotepec does not exist in locations data
# entidad_municipio oaxaca-santa maria papalo does not exist in locations data
# entidad_municipio oaxaca-santa maria peñoles does not exist in locations data
# entidad_municipio oaxaca-santa maria petapa does not exist in locations data
# entidad_municipio oaxaca-santa maria quiegolani does not exist in locations data
# entidad_municipio oaxaca-santa maria sola does not exist in locations data
# entidad_municipio oaxaca-santa maria tataltepec does not exist in locations data
# entidad_municipio oaxaca-santa maria tecomavaca does not exist in locations data
# entidad_municipio oaxaca-santa maria temaxcalapa does not exist in locations data
# entidad_municipio oaxaca-santa maria temaxcaltepec does not exist in locations data
# entidad_municipio oaxaca-santa maria teopoxco does not exist in locations data
# entidad_municipio oaxaca-santa maria tepantlali does not exist in locations data
# entidad_municipio oaxaca-santa maria texcatitlan does not exist in locations data
# entidad_municipio oaxaca-santa maria tlahuitoltepec does not exist in locations data
# entidad_municipio oaxaca-santa maria tlalixtac does not exist in locations data
# entidad_municipio oaxaca-santa maria tonameca does not exist in locations data
# entidad_municipio oaxaca-santa maria totolapilla does not exist in locations data
# entidad_municipio oaxaca-santa maria xadani does not exist in locations data
# entidad_municipio oaxaca-santa maria yalina does not exist in locations data
# entidad_municipio oaxaca-santa maria yavesia does not exist in locations data
# entidad_municipio oaxaca-santa maria yolotepec does not exist in locations data
# entidad_municipio oaxaca-santa maria yosoyua does not exist in locations data
# entidad_municipio oaxaca-santa maria yucuhiti does not exist in locations data
# entidad_municipio oaxaca-santa maria zacatepec does not exist in locations data
# entidad_municipio oaxaca-santa maria zaniza does not exist in locations data
# entidad_municipio oaxaca-santa maria zoquitlan does not exist in locations data
# entidad_municipio oaxaca-santiago apostol does not exist in locations data
# entidad_municipio oaxaca-santiago atitlan does not exist in locations data
# entidad_municipio oaxaca-santiago camotlan does not exist in locations data
# entidad_municipio oaxaca-santiago choapam does not exist in locations data
# entidad_municipio oaxaca-santiago del rio does not exist in locations data
# entidad_municipio oaxaca-santiago huajolotitlan does not exist in locations data
# entidad_municipio oaxaca-santiago ihuitlan plumas does not exist in locations data
# entidad_municipio oaxaca-santiago matatlan does not exist in locations data
# entidad_municipio oaxaca-santiago nuyoo does not exist in locations data
# entidad_municipio oaxaca-villa tejupam de la union does not exist in locations data
# entidad_municipio oaxaca-santiago textitlan does not exist in locations data
# entidad_municipio oaxaca-santiago xiacui does not exist in locations data
# entidad_municipio oaxaca-santiago yolomecatl does not exist in locations data
# entidad_municipio oaxaca-santiago yosondua does not exist in locations data
# entidad_municipio oaxaca-nuevo zoquiapam does not exist in locations data
# entidad_municipio oaxaca-santo domingo chihuitan does not exist in locations data
# entidad_municipio oaxaca-santo domingo ixcatlan does not exist in locations data
# entidad_municipio oaxaca-santo domingo nuxaa does not exist in locations data
# entidad_municipio oaxaca-santo domingo tlatayapam does not exist in locations data
# entidad_municipio oaxaca-santo domingo tonala does not exist in locations data
# entidad_municipio oaxaca-santo domingo xagacia does not exist in locations data
# entidad_municipio oaxaca-santo domingo yanhuitlan does not exist in locations data
# entidad_municipio oaxaca-santos reyes papalo does not exist in locations data
# entidad_municipio oaxaca-santos reyes yucuna does not exist in locations data
# entidad_municipio oaxaca-santo tomas jalieza does not exist in locations data
# entidad_municipio oaxaca-santo tomas mazaltepec does not exist in locations data
# entidad_municipio oaxaca-santo tomas ocotepec does not exist in locations data
# entidad_municipio oaxaca-santo tomas tamazulapan does not exist in locations data
# entidad_municipio oaxaca-san vicente coatlan does not exist in locations data
# entidad_municipio oaxaca-san vicente lachixio does not exist in locations data
# entidad_municipio oaxaca-san vicente nuñu does not exist in locations data
# entidad_municipio oaxaca-silacayoapam does not exist in locations data
# entidad_municipio oaxaca-villa de tamazulapam del progreso does not exist in locations data
# entidad_municipio oaxaca-tataltepec de valdes does not exist in locations data
# entidad_municipio oaxaca-teococuilco de marcos perez does not exist in locations data
# entidad_municipio oaxaca-teotitlan de flores magon does not exist in locations data
# entidad_municipio oaxaca-teotitlan del valle does not exist in locations data
# entidad_municipio oaxaca-tezoatlan de segura y luna does not exist in locations data
# entidad_municipio oaxaca-san jeronimo tlacochahuaya does not exist in locations data
# entidad_municipio oaxaca-union hidalgo does not exist in locations data
# entidad_municipio oaxaca-villa diaz ordaz does not exist in locations data
# entidad_municipio oaxaca-magdalena yodocono de porfirio diaz does not exist in locations data
# entidad_municipio oaxaca-zapotitlan del rio does not exist in locations data
# entidad_municipio oaxaca-zapotitlan lagunas does not exist in locations data
# entidad_municipio oaxaca-zapotitlan palmas does not exist in locations data
# entidad_municipio oaxaca-santa ines de zaragoza does not exist in locations data
# entidad_municipio oaxaca-zimatlan de alvarez does not exist in locations data
# entidad_municipio puebla-acatlan does not exist in locations data
# entidad_municipio puebla-ahuacatlan does not exist in locations data
# entidad_municipio puebla-ahuatlan does not exist in locations data
# entidad_municipio puebla-amixtlan does not exist in locations data
# entidad_municipio puebla-atzitzihuacan does not exist in locations data
# entidad_municipio puebla-coxcatlan does not exist in locations data
# entidad_municipio puebla-cuautinchan does not exist in locations data
# entidad_municipio puebla-chigmecatitlan does not exist in locations data
# entidad_municipio puebla-eloxochitlan does not exist in locations data
# entidad_municipio puebla-epatlan does not exist in locations data
# entidad_municipio puebla-general felipe angeles does not exist in locations data
# entidad_municipio puebla-huehuetlan el chico does not exist in locations data
# entidad_municipio puebla-huitzilan de serdan does not exist in locations data
# entidad_municipio puebla-ixtacamaxtitlan does not exist in locations data
# entidad_municipio puebla-izucar de matamoros does not exist in locations data
# entidad_municipio puebla-juan n. mendez does not exist in locations data
# entidad_municipio puebla-mazapiltepec de juarez does not exist in locations data
# entidad_municipio puebla-nicolas bravo does not exist in locations data
# entidad_municipio puebla-pahuatlan does not exist in locations data
# entidad_municipio puebla-quimixtlan does not exist in locations data
# entidad_municipio puebla-los reyes de juarez does not exist in locations data
# entidad_municipio puebla-san andres cholula does not exist in locations data
# entidad_municipio puebla-san felipe tepatlan does not exist in locations data
# entidad_municipio puebla-san jeronimo tecuanipan does not exist in locations data
# entidad_municipio puebla-san jeronimo xayacatlan does not exist in locations data
# entidad_municipio puebla-san jose chiapa does not exist in locations data
# entidad_municipio puebla-san jose miahuatlan does not exist in locations data
# entidad_municipio puebla-san martin texmelucan does not exist in locations data
# entidad_municipio puebla-san martin totoltepec does not exist in locations data
# entidad_municipio puebla-san matias tlalancaleca does not exist in locations data
# entidad_municipio puebla-san miguel ixitlan does not exist in locations data
# entidad_municipio puebla-san nicolas buenos aires does not exist in locations data
# entidad_municipio puebla-san nicolas de los ranchos does not exist in locations data
# entidad_municipio puebla-san sebastian tlacotepec does not exist in locations data
# entidad_municipio puebla-santa ines ahuatempan does not exist in locations data
# entidad_municipio puebla-santiago miahuatlan does not exist in locations data
# entidad_municipio puebla-huehuetlan el grande does not exist in locations data
# entidad_municipio puebla-santo tomas hueyotlipan does not exist in locations data
# entidad_municipio puebla-tecomatlan does not exist in locations data
# entidad_municipio puebla-tehuacan does not exist in locations data
# entidad_municipio puebla-teopantlan does not exist in locations data
# ...
# entidad_municipio querétaro-queretaro does not exist in locations data
# entidad_municipio querétaro-san joaquin does not exist in locations data
# entidad_municipio querétaro-san juan del rio does not exist in locations data
# entidad_municipio querétaro-toliman does not exist in locations data
# entidad_municipio quintana roo-othon p. blanco does not exist in locations data
# entidad_municipio quintana roo-benito juarez does not exist in locations data
# entidad_municipio quintana roo-jose maria morelos does not exist in locations data
# entidad_municipio quintana roo-lazaro cardenas does not exist in locations data
# entidad_municipio san luis potosí-aquismon does not exist in locations data
# entidad_municipio san luis potosí-cardenas does not exist in locations data
# entidad_municipio san luis potosí-ciudad del maiz does not exist in locations data
# entidad_municipio san luis potosí-ciudad fernandez does not exist in locations data
# entidad_municipio san luis potosí-coxcatlan does not exist in locations data
# entidad_municipio san luis potosí-guadalcazar does not exist in locations data
# entidad_municipio san luis potosí-huehuetlan does not exist in locations data
# entidad_municipio san luis potosí-rayon does not exist in locations data
# entidad_municipio san luis potosí-san luis potosi does not exist in locations data
# entidad_municipio san luis potosí-san martin chalchicuautla does not exist in locations data
# entidad_municipio san luis potosí-san nicolas tolentino does not exist in locations data
# entidad_municipio san luis potosí-santa maria del rio does not exist in locations data
# entidad_municipio san luis potosí-soledad de graciano sanchez does not exist in locations data
# entidad_municipio san luis potosí-tampacan does not exist in locations data
# entidad_municipio san luis potosí-tampamolon corona does not exist in locations data
# entidad_municipio san luis potosí-tamuin does not exist in locations data
# entidad_municipio san luis potosí-tanlajas does not exist in locations data
# entidad_municipio san luis potosí-tanquian de escobedo does not exist in locations data
# entidad_municipio san luis potosí-villa juarez does not exist in locations data
# entidad_municipio sinaloa-cosala does not exist in locations data
# entidad_municipio sinaloa-culiacan does not exist in locations data
# entidad_municipio sinaloa-mazatlan does not exist in locations data
# entidad_municipio sonora-bacadehuachi does not exist in locations data
# entidad_municipio sonora-bacum does not exist in locations data
# entidad_municipio sonora-banamichi does not exist in locations data
# entidad_municipio sonora-baviacora does not exist in locations data
# entidad_municipio sonora-benjamin hill does not exist in locations data
# entidad_municipio sonora-carbo does not exist in locations data
# entidad_municipio sonora-huasabas does not exist in locations data
# entidad_municipio sonora-huepac does not exist in locations data
# entidad_municipio sonora-mazatan does not exist in locations data
# entidad_municipio sonora-nacori chico does not exist in locations data
# entidad_municipio sonora-nacozari de garcia does not exist in locations data
# entidad_municipio sonora-rayon does not exist in locations data
# entidad_municipio sonora-san felipe de jesus does not exist in locations data
# entidad_municipio sonora-san luis rio colorado does not exist in locations data
# entidad_municipio sonora-saric does not exist in locations data
# entidad_municipio sonora-yecora does not exist in locations data
# entidad_municipio sonora-general plutarco elias calles does not exist in locations data
# entidad_municipio sonora-benito juarez does not exist in locations data
# entidad_municipio sonora-san ignacio rio muerto does not exist in locations data
# entidad_municipio tabasco-balancan does not exist in locations data
# entidad_municipio tabasco-cardenas does not exist in locations data
# entidad_municipio tabasco-cunduacan does not exist in locations data
# entidad_municipio tabasco-jalpa de mendez does not exist in locations data
# entidad_municipio tabasco-paraiso does not exist in locations data
# entidad_municipio tamaulipas-gomez farias does not exist in locations data
# entidad_municipio tamaulipas-gonzalez does not exist in locations data
# entidad_municipio tamaulipas-güemez does not exist in locations data
# entidad_municipio tamaulipas-gustavo diaz ordaz does not exist in locations data
# entidad_municipio tamaulipas-jimenez does not exist in locations data
# entidad_municipio tamaulipas-mendez does not exist in locations data
# entidad_municipio tamaulipas-miguel aleman does not exist in locations data
# entidad_municipio tamaulipas-rio bravo does not exist in locations data
# entidad_municipio tamaulipas-san nicolas does not exist in locations data
# entidad_municipio tamaulipas-villagran does not exist in locations data
# entidad_municipio tamaulipas-xicotencatl does not exist in locations data
# entidad_municipio tlaxcala-apetatitlan de antonio carvajal does not exist in locations data
# entidad_municipio tlaxcala-mazatecochco de jose maria morelos does not exist in locations data
# entidad_municipio tlaxcala-tepetitla de lardizabal does not exist in locations data
# entidad_municipio tlaxcala-sanctorum de lazaro cardenas does not exist in locations data
# entidad_municipio tlaxcala-nativitas does not exist in locations data
# entidad_municipio tlaxcala-tocatlan does not exist in locations data
# entidad_municipio tlaxcala-ziltlaltepec de trinidad sanchez santos does not exist in locations data
# entidad_municipio tlaxcala-papalotla de xicohtencatl does not exist in locations data
# entidad_municipio tlaxcala-benito juarez does not exist in locations data
# entidad_municipio tlaxcala-lazaro cardenas does not exist in locations data
# entidad_municipio tlaxcala-san damian texoloc does not exist in locations data
# entidad_municipio tlaxcala-san jeronimo zacualpan does not exist in locations data
# entidad_municipio tlaxcala-san jose teacalco does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-acatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-camaron de tejeda does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-alpatlahuac does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-alto lucero de gutierrez barrios does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-amatitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-naranjos amatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-amatlan de los reyes does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-benito juarez does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-boca del rio does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-citlaltepetl does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-coahuitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-cordoba does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-cosautlan de carvajal does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-cuitlahuac does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-chocaman does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-chumatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-fortin does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-gutierrez zamora does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-hidalgotitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-huiloapan de cuauhtemoc does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ilamatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ixhuacan de los reyes does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ixhuatlan del cafe does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ixhuatlan del sureste does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ixhuatlan de madero does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ixtaczoquitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-jaltipan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-jesus carranza does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-juan rodriguez clara does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-martinez de la torre does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-mecatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-medellin does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-miahuatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-minatitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-moloacan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-otatitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-panuco does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-platon sanchez does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-las vigas de ramirez does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-rio blanco does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-san andres tenejapan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-san andres tuxtla does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-sayula de aleman does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tamalin does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-alamo temapache does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tenochtitlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tepetlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-jose azueta does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-texhuacan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tihuatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tlacotepec de mejia does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tomatlan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tonayan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-ursulo galvan does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-zontecomatlan de lopez y fuentes does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-nanchital de lazaro cardenas del rio does not exist in locations data
# entidad_municipio veracruz de ignacio de la llave-tatahuicapan de juarez does not exist in locations data
# entidad_municipio yucatán-abala does not exist in locations data
# entidad_municipio yucatán-bokoba does not exist in locations data
# entidad_municipio yucatán-cacalchen does not exist in locations data
# entidad_municipio yucatán-celestun does not exist in locations data
# entidad_municipio yucatán-cuzama does not exist in locations data
# entidad_municipio yucatán-chacsinkin does not exist in locations data
# entidad_municipio yucatán-chichimila does not exist in locations data
# entidad_municipio yucatán-chochola does not exist in locations data
# entidad_municipio yucatán-dzan does not exist in locations data
# entidad_municipio yucatán-dzidzantun does not exist in locations data
# entidad_municipio yucatán-dzilam gonzalez does not exist in locations data
# entidad_municipio yucatán-dzitas does not exist in locations data
# entidad_municipio yucatán-halacho does not exist in locations data
# entidad_municipio yucatán-hocaba does not exist in locations data
# entidad_municipio yucatán-hoctun does not exist in locations data
# entidad_municipio yucatán-homun does not exist in locations data
# entidad_municipio yucatán-huhi does not exist in locations data
# entidad_municipio yucatán-hunucma does not exist in locations data
# entidad_municipio yucatán-kanasin does not exist in locations data
# entidad_municipio yucatán-kopoma does not exist in locations data
# entidad_municipio yucatán-mani does not exist in locations data
# entidad_municipio yucatán-maxcanu does not exist in locations data
# entidad_municipio yucatán-mayapan does not exist in locations data
# entidad_municipio yucatán-merida does not exist in locations data
# entidad_municipio yucatán-mococha does not exist in locations data
# entidad_municipio yucatán-opichen does not exist in locations data
# entidad_municipio yucatán-panaba does not exist in locations data
# entidad_municipio yucatán-rio lagartos does not exist in locations data
# entidad_municipio yucatán-seye does not exist in locations data
# entidad_municipio yucatán-sinanche does not exist in locations data
# entidad_municipio yucatán-sucila does not exist in locations data
# entidad_municipio yucatán-tahdziu does not exist in locations data
# entidad_municipio yucatán-tekanto does not exist in locations data
# entidad_municipio yucatán-temozon does not exist in locations data
# entidad_municipio yucatán-tepakan does not exist in locations data
# entidad_municipio yucatán-tixpehual does not exist in locations data
# entidad_municipio yucatán-tizimin does not exist in locations data
# entidad_municipio yucatán-tunkas does not exist in locations data
# entidad_municipio yucatán-ucu does not exist in locations data
# entidad_municipio yucatán-uman does not exist in locations data
# entidad_municipio yucatán-yaxcaba does not exist in locations data
# entidad_municipio yucatán-yobain does not exist in locations data
# entidad_municipio zacatecas-benito juarez does not exist in locations data
# entidad_municipio zacatecas-concepcion del oro does not exist in locations data
# entidad_municipio zacatecas-cuauhtemoc does not exist in locations data
# entidad_municipio zacatecas-trinidad garcia de la cadena does not exist in locations data
# entidad_municipio zacatecas-general francisco r. murguia does not exist in locations data
# entidad_municipio zacatecas-el plateado de joaquin amaro does not exist in locations data
# entidad_municipio zacatecas-general panfilo natera does not exist in locations data
# entidad_municipio zacatecas-jimenez del teul does not exist in locations data
# entidad_municipio zacatecas-nochistlan de mejia does not exist in locations data
# entidad_municipio zacatecas-noria de angeles does not exist in locations data
# entidad_municipio zacatecas-panuco does not exist in locations data
# entidad_municipio zacatecas-rio grande does not exist in locations data
# entidad_municipio zacatecas-susticacan does not exist in locations data
# entidad_municipio zacatecas-tepechitlan does not exist in locations data
# entidad_municipio zacatecas-teul de gonzalez ortega does not exist in locations data
# entidad_municipio zacatecas-tlaltenango de sanchez roman does not exist in locations data
# entidad_municipio zacatecas-valparaiso does not exist in locations data
# entidad_municipio zacatecas-villa garcia does not exist in locations data
# entidad_municipio zacatecas-villa gonzalez ortega does not exist in locations data
# entidad_municipio zacatecas-santa maria de la paz does not exist in locations data
# No missing values
# Ready to merge crimes and data

# %%
# Cleaning acentos
locations = locations.replace({'Á': 'A', 'á': 'a',
                    'É': 'E', 'é': 'e',
                    'Í': 'I', 'í': 'i',
                    'Ó': 'O', 'ó': 'o',
                    'Ú': 'U', 'ú': 'u'},
                    regex=True)

data = data.replace({'Á': 'A', 'á': 'a',
                    'É': 'E', 'é': 'e',
                    'Í': 'I', 'í': 'i',
                    'Ó': 'O', 'ó': 'o',
                    'Ú': 'U', 'ú': 'u'},
                    regex=True)
locations
# Out:
#         código postal                                       asentamiento  \
# 0                1000                                          San Angel
# 1                1010                                          Los Alpes
# 2                1020                                      Guadalupe Inn
# 3                1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4                1029                                          INFONAVIT
# ...               ...                                                ...
# 143219          99993                                            Cuxpala
# 143220          99994                                   Vicente Guerrero
# 143221          99998                                          Palmarejo
# 143222          99998                                        Jesus Maria
# 143223          99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143222     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143223     Rancheria  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip                entidad_municipio
# 0          AlvaroObregon  ciudad de mexico-alvaro obregon
# 1          AlvaroObregon  ciudad de mexico-alvaro obregon
# 2          AlvaroObregon  ciudad de mexico-alvaro obregon
# 3          AlvaroObregon  ciudad de mexico-alvaro obregon
# 4          AlvaroObregon  ciudad de mexico-alvaro obregon
# ...                  ...                              ...
# 143219  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143220  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143221  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143222  MoyahuadeEstrada     zacatecas-moyahua de estrada
# 143223  MoyahuadeEstrada     zacatecas-moyahua de estrada
#
# [143224 rows x 8 columns]

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

#for i in unique_mun_locations:
 #   if i not in unique_mun_data:
  #      print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# entidad_municipio chihuahua-doctor belisario dominguez does not exist in locations data
# entidad_municipio guanajuato-silao does not exist in locations data
# entidad_municipio jalisco-tlaquepaque does not exist in locations data
# entidad_municipio mexico-acambay does not exist in locations data
# entidad_municipio morelos-tlaltizapan does not exist in locations data
# entidad_municipio nuevo leon-carmen does not exist in locations data
# entidad_municipio oaxaca-zapotitlan del rio does not exist in locations data
# No missing values
# Ready to merge crimes and data

# %%
# Replacing data mannually
locations['entidad_municipio'] = locations['entidad_municipio'].replace({
                                                                        'guanajuato-silao de la victoria': 'guanajuato-silao',
                                                                        'jalisco-san pedro tlaquepaque': 'jalisco-tlaquepaque',
                                                                        'mexico-acambay de ruiz castañeda': 'mexico-acambay',
                                                                        'morelos-tlaltizapan de zapata': 'morelos-tlaltizapan',
                                                                        'chihuahua-dr. belisario dominguez': 'chihuahua-doctor belisario dominguez',
                                                                        'nuevo leon-el carmen': 'nuevo leon-carmen'
                                                                        })

# %%
# Creating list of unique ids in each dataset
unique_mun_locations = locations['entidad_municipio'].unique()
unique_mun_data = data['entidad_municipio'].unique()

# Len of the lists
len_mun_locations = len(locations['entidad_municipio'].unique())
len_mun_data = len(data['entidad_municipio'].unique())

for i in unique_mun_data:
    if i not in unique_mun_locations:
        print('entidad_municipio {} does not exist in locations data'.format(i))

for i in unique_mun_locations:
    if i not in unique_mun_data:
        print('entidad_municipio {} does not exist in data data'.format(i))

print('No missing values')

if len_mun_locations == len_mun_data:
    print('Equal lenghts')

print('Ready to merge crimes and data')
# Out:
# entidad_municipio oaxaca-zapotitlan del rio does not exist in locations data
# entidad_municipio oaxaca-san juan mixtepec -dto. 26 - does not exist in data data
# entidad_municipio oaxaca-san pedro mixtepec -dto. 26 - does not exist in data data
# entidad_municipio oaxaca-san mateo yucutindoo does not exist in data data
# No missing values
# Ready to merge crimes and data

# %%
data[data['entidad_municipio'].str.contains('oaxaca-zapotitlan')]
# Out:
#       id_municipio entidad           municipio  carpetas   total  crimes_10k  \
# 1563         20566  Oaxaca  Zapotitlan Del Rio         0  3010.0         0.0
# 1564         20567  Oaxaca  Zapotitlan Lagunas         0  3142.0         0.0
# 1565         20568  Oaxaca   Zapotitlan Palmas         0  1431.0         0.0
#
#       class          entidad_municipio
# 1563      0  oaxaca-zapotitlan del rio
# 1564      0  oaxaca-zapotitlan lagunas
# 1565      0   oaxaca-zapotitlan palmas

# %%
locations[locations['entidad_municipio'].str.contains('oaxaca-zapotitlan')]
# Out:
#        código postal                      asentamiento       tipo  \
# 91154          69060                 Zapotitlan Palmas  Rancheria
# 91176          69120                Zapotitlan Lagunas     Pueblo
# 91177          69123                  Cerro los Cuates  Rancheria
# 91178          69123                        El Naranjo  Rancheria
# 91179          69123                 Barrio San Isidro     Barrio
# 91180          69123                   El Palmon Largo  Rancheria
# 91181          69123                        La Soledad  Rancheria
# 91182          69123            San Pedro Cuaxoxocatla  Rancheria
# 91183          69123                San Miguel Hidalgo  Rancheria
# 91184          69123            Guadalupe Buenos Aires  Rancheria
# 91185          69124          Santa Cruz Vista Hermosa  Rancheria
# 91186          69126                 Falda del Tepeyac  Rancheria
# 91187          69126              Guadalupe del Recreo     Pueblo
# 91188          69126             Paraje la Cruz Blanca  Rancheria
# 91189          69126             San Jose el Huamuchil  Rancheria
# 91190          69127                Tlacotepec Lagunas  Rancheria
# 91191          69127  Santa Cruz Soledad (Las Casitas)  Rancheria
#
#                 municipio ciudad entidad    municipio_strip  \
# 91154   Zapotitlan Palmas    NaN  Oaxaca   ZapotitlanPalmas
# 91176  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91177  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91178  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91179  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91180  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91181  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91182  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91183  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91184  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91185  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91186  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91187  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91188  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91189  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91190  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
# 91191  Zapotitlan Lagunas    NaN  Oaxaca  ZapotitlanLagunas
#
#                entidad_municipio
# 91154   oaxaca-zapotitlan palmas
# 91176  oaxaca-zapotitlan lagunas
# 91177  oaxaca-zapotitlan lagunas
# 91178  oaxaca-zapotitlan lagunas
# 91179  oaxaca-zapotitlan lagunas
# 91180  oaxaca-zapotitlan lagunas
# 91181  oaxaca-zapotitlan lagunas
# 91182  oaxaca-zapotitlan lagunas
# 91183  oaxaca-zapotitlan lagunas
# 91184  oaxaca-zapotitlan lagunas
# 91185  oaxaca-zapotitlan lagunas
# 91186  oaxaca-zapotitlan lagunas
# 91187  oaxaca-zapotitlan lagunas
# 91188  oaxaca-zapotitlan lagunas
# 91189  oaxaca-zapotitlan lagunas
# 91190  oaxaca-zapotitlan lagunas
# 91191  oaxaca-zapotitlan lagunas

# %%
# Merging
colonias = pd.merge(locations, data, how='left', on='entidad_municipio')
# CLeaning columns
colonias.drop(columns=['entidad_y', 'municipio_y'], inplace=True)
colonias.rename(columns={'entidad_x': 'entidad', 'municipio_x': 'municipio'}, inplace=True)
colonias.head()
# Out:
#    código postal                                       asentamiento  \
# 0           1000                                          San Angel
# 1           1010                                          Los Alpes
# 2           1020                                      Guadalupe Inn
# 3           1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4           1029                                          INFONAVIT
#
#            tipo       municipio            ciudad           entidad  \
# 0       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2       Colonia  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3  Gran usuario  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4  Gran usuario  Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
#
#   municipio_strip                entidad_municipio  id_municipio  carpetas  \
# 0   AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0    1001.0
# 1   AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0    1001.0
# 2   AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0    1001.0
# 3   AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0    1001.0
# 4   AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0    1001.0
#
#       total  crimes_10k  class
# 0  749982.0   13.346987    4.0
# 1  749982.0   13.346987    4.0
# 2  749982.0   13.346987    4.0
# 3  749982.0   13.346987    4.0
# 4  749982.0   13.346987    4.0

# %%
if export_data == True:
    colonias.to_csv('output data/data_by_neighborhood.csv', encoding='latin1')

# %% [markdown]
# Adding coordenates for every zip code

# %%
# Importing data
coordenates_cp = pd.read_csv('data/coordenates_colonias.csv', usecols=[0,3,6,8,9])
# Cleaning columns
coordenates_cp.columns = ['id_entidad', 'id_municipio', 'localidad', 'lat', 'lon']
coordenates_cp.columns = [x.lower().strip() for x in coordenates_cp.columns]
# Generating id_municipio full
coordenates_cp['id_municipio'] = coordenates_cp['id_entidad']*1000 + coordenates_cp['id_municipio']
coordenates_cp
# Out:
#         id_entidad  id_municipio               localidad        lat  \
# 0                1          1001          Aguascalientes  21.879823
# 1                1          1001          Granja Adelita  21.871875
# 2                1          1001               Agua Azul  21.883756
# 3                1          1001           Rancho Alegre  21.854599
# 4                1          1001  Los Arbolitos [Rancho]  21.780181
# ...            ...           ...                     ...        ...
# 304216          32         32058              San Isidro  21.486425
# 304217          32         32058                San José  21.516539
# 304218          32         32058   San Miguel Tepetitlán  21.504213
# 304219          32         32058              San Rafael  21.527595
# 304220          32         32058                Santa Fe  21.528992
#
#                lon
# 0      -102.296047
# 1      -102.373531
# 2      -102.357122
# 3      -102.372746
# 4      -102.357295
# ...            ...
# 304216 -103.337268
# 304217 -103.456568
# 304218 -103.335932
# 304219 -103.372259
# 304220 -103.385095
#
# [304221 rows x 5 columns]

# %%
# Creating list of unique ids in each coordenates_cpset
unique_mun_colonias = colonias['id_municipio'].unique()
unique_mun_coordenates_cp = coordenates_cp['id_municipio'].unique()

# Len of the lists
len_mun_colonias = len(colonias['id_municipio'].unique())
len_mun_coordenates_cp = len(coordenates_cp['id_municipio'].unique())

for i in unique_mun_coordenates_cp:
    if i not in unique_mun_colonias:
        print('id_municipio {} does not exist in colonias coordenates_cp'.format(i))

for i in unique_mun_colonias:
    if i not in unique_mun_coordenates_cp:
        print('id_municipio {} does not exist in coordenates_cp coordenates_cp'.format(i))


if len_mun_colonias == len_mun_coordenates_cp:
    print('Equal lenghts')
# Out:
# id_municipio 7120 does not exist in colonias coordenates_cp
# id_municipio 7121 does not exist in colonias coordenates_cp
# id_municipio 7122 does not exist in colonias coordenates_cp
# id_municipio 7123 does not exist in colonias coordenates_cp
# id_municipio 7124 does not exist in colonias coordenates_cp
# id_municipio 20209 does not exist in colonias coordenates_cp
# id_municipio 20319 does not exist in colonias coordenates_cp
# id_municipio 20566 does not exist in colonias coordenates_cp
# id_municipio 23011 does not exist in colonias coordenates_cp
# id_municipio nan does not exist in coordenates_cp coordenates_cp

# %%
colonias
# Out:
#         código postal                                       asentamiento  \
# 0                1000                                          San Angel
# 1                1010                                          Los Alpes
# 2                1020                                      Guadalupe Inn
# 3                1028  Secretaria de Contraloria y Desarrollo Adminis...
# 4                1029                                          INFONAVIT
# ...               ...                                                ...
# 143219          99993                                            Cuxpala
# 143220          99994                                   Vicente Guerrero
# 143221          99998                                          Palmarejo
# 143222          99998                                        Jesus Maria
# 143223          99998                              San Jose de Palmarejo
#
#                 tipo           municipio            ciudad           entidad  \
# 0            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 1            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 2            Colonia      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 3       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# 4       Gran usuario      Alvaro Obregon  Ciudad de Mexico  Ciudad de Mexico
# ...              ...                 ...               ...               ...
# 143219        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143220        Pueblo  Moyahua de Estrada               NaN         Zacatecas
# 143221     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143222     Rancheria  Moyahua de Estrada               NaN         Zacatecas
# 143223     Rancheria  Moyahua de Estrada               NaN         Zacatecas
#
#          municipio_strip                entidad_municipio  id_municipio  \
# 0          AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0
# 1          AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0
# 2          AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0
# 3          AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0
# 4          AlvaroObregon  ciudad de mexico-alvaro obregon        9010.0
# ...                  ...                              ...           ...
# 143219  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143220  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143221  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143222  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
# 143223  MoyahuadeEstrada     zacatecas-moyahua de estrada       32033.0
#
#         carpetas     total  crimes_10k  class
# 0         1001.0  749982.0   13.346987    4.0
# 1         1001.0  749982.0   13.346987    4.0
# 2         1001.0  749982.0   13.346987    4.0
# 3         1001.0  749982.0   13.346987    4.0
# 4         1001.0  749982.0   13.346987    4.0
# ...          ...       ...         ...    ...
# 143219       0.0    3947.0    0.000000    0.0
# 143220       0.0    3947.0    0.000000    0.0
# 143221       0.0    3947.0    0.000000    0.0
# 143222       0.0    3947.0    0.000000    0.0
# 143223       0.0    3947.0    0.000000    0.0
#
# [143224 rows x 13 columns]

# %% [markdown]
# Merging colonias with coordenates_cp

# %%
data_map_cp = pd.merge(data_map_municipios.drop(columns=['lat', 'lon']), coordenates_cp, how='right', on='id_municipio')
data_map_cp.head()
# Out:
#    id_municipio         entidad       municipio  carpetas     total  \
# 0          1001  Aguascalientes  Aguascalientes    1358.0  877190.0
# 1          1001  Aguascalientes  Aguascalientes    1358.0  877190.0
# 2          1001  Aguascalientes  Aguascalientes    1358.0  877190.0
# 3          1001  Aguascalientes  Aguascalientes    1358.0  877190.0
# 4          1001  Aguascalientes  Aguascalientes    1358.0  877190.0
#
#    crimes_10k  class  id_entidad               localidad        lat  \
# 0   15.481253    4.0           1          Aguascalientes  21.879823
# 1   15.481253    4.0           1          Granja Adelita  21.871875
# 2   15.481253    4.0           1               Agua Azul  21.883756
# 3   15.481253    4.0           1           Rancho Alegre  21.854599
# 4   15.481253    4.0           1  Los Arbolitos [Rancho]  21.780181
#
#           lon
# 0 -102.296047
# 1 -102.373531
# 2 -102.357122
# 3 -102.372746
# 4 -102.357295

# %% [markdown]
# #### Mapping by zip code

# %%
# Function to map neighborhoods of any state
def map_state(state, scope='total'):
    import folium

    data = data_map_cp

    data = data[data['entidad'] == state]

    #data = data.iloc[192200: 192202]

    data1 = data

    map = folium.Map(location = [data.iloc[0]['lat'], data.iloc[0]['lon']], zoom_start=8)



    for localidad in data1['localidad'].unique():
        data = data1[data1['localidad'] == localidad]

        colors = ['forestgreen', 'lime', 'yellow', 'lightcoral', 'firebrick']
        for cluster in range(5):
            color_cluster = colors[cluster]
            for point in range(len(data[data['class']==cluster])):
                folium.CircleMarker(location=[data.iloc[point]['lat'], data.iloc[point]['lon']],
                radius=3,
                color=color_cluster,
                fill_color=color_cluster,
                fill=True
                ).add_to(map)

    data = data1

    file_path = 'maps/map_{}_{}.html'.format(state.lower().replace(' ', '_'), scope.lower())

    map.save(file_path)

# %%
# Creating maps for every state
if generate_maps == True:
    states = ['Aguascalientes', 'Baja California', 'Baja California Sur',
       'Campeche', 'Coahuila de Zaragoza', 'Colima', 'Chiapas',
       'Chihuahua', 'Ciudad de México', 'Durango', 'Guanajuato',
       'Guerrero', 'Hidalgo', 'Jalisco', 'México', 'Michoacán de Ocampo',
       'Morelos', 'Nayarit', 'Nuevo León', 'Oaxaca', 'Puebla',
       'Querétaro', 'Quintana Roo', 'San Luis Potosí', 'Sinaloa',
       'Sonora', 'Tabasco', 'Tamaulipas', 'Tlaxcala',
       'Veracruz de Ignacio de la Llave', 'Yucatán', 'Zacatecas']

    if limit_crimes == False:
        scope_selection = 'total'
    else:
        scope_selection = 'specific'
    for s in states:
        map_state(state= s, scope=scope_selection)

# %%
# Exporting output
if export_data == True:
    data_map_cp.to_csv('output data/data_map_cp.csv')

# %%
data_map_cp[data_map_cp['class'] != 4]
# Out:
#         id_municipio    entidad              municipio  carpetas    total  \
# 14988           4001   Campeche                Calkini       5.0  56537.0
# 14989           4001   Campeche                Calkini       5.0  56537.0
# 14990           4001   Campeche                Calkini       5.0  56537.0
# 14991           4001   Campeche                Calkini       5.0  56537.0
# 14992           4001   Campeche                Calkini       5.0  56537.0
# ...              ...        ...                    ...       ...      ...
# 304216         32058  Zacatecas  Santa Maria De La Paz       1.0   2656.0
# 304217         32058  Zacatecas  Santa Maria De La Paz       1.0   2656.0
# 304218         32058  Zacatecas  Santa Maria De La Paz       1.0   2656.0
# 304219         32058  Zacatecas  Santa Maria De La Paz       1.0   2656.0
# 304220         32058  Zacatecas  Santa Maria De La Paz       1.0   2656.0
#
#         crimes_10k  class  id_entidad              localidad        lat  \
# 14988     0.884377    1.0           4                Calkiní  20.371226
# 14989     0.884377    1.0           4             Isla Arena  20.690499
# 14990     0.884377    1.0           4              Bacabchén  20.288867
# 14991     0.884377    1.0           4                  Bécal  20.442539
# 14992     0.884377    1.0           4             Concepción  20.316658
# ...            ...    ...         ...                    ...        ...
# 304216    3.765060    3.0          32             San Isidro  21.486425
# 304217    3.765060    3.0          32               San José  21.516539
# 304218    3.765060    3.0          32  San Miguel Tepetitlán  21.504213
# 304219    3.765060    3.0          32             San Rafael  21.527595
# 304220    3.765060    3.0          32               Santa Fe  21.528992
#
#                lon
# 14988   -90.050739
# 14989   -90.452459
# 14990   -90.055998
# 14991   -90.028074
# 14992   -90.180665
# ...            ...
# 304216 -103.337268
# 304217 -103.456568
# 304218 -103.335932
# 304219 -103.372259
# 304220 -103.385095
#
# [245900 rows x 11 columns]

# %%
data_map_cp[(data_map_cp['entidad'] == 'Aguascalientes') & (data_map_cp['class'] == 3)]['municipio'].unique()
# Out:
# array([], dtype=object)

# %%
# CDMX, Jalisco, Nuevo León, EdoMex, Puebla, Guanajuato, QRO, Tlaxcala, Coahuila, Aguascalientes
